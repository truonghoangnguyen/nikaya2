# %%
import re
import os
# 01 read thichminhcau as base json {}
def parse_markdown_file(filepath):
    """
    đọc title thichminhchau
     "title": title,
    "sutta": sutta_name,
    "file1": filename

    Reads a markdown file and extracts the title, Sutta name, and filename.

    Args:
        filepath: The path to the markdown file.

    Returns:
        A dictionary containing the title, Sutta name, and filename, or None
        if the file cannot be read or if the necessary information is not found.
    """
    try:
        with open(filepath, 'r', encoding='utf-8') as f:
            content = f.read()
    except FileNotFoundError:
        print(f"Error: File not found: {filepath}")
        return None
    except Exception as e:
        print(f"Error reading file {filepath}: {e}")
        return None


    # Extract title (from the first h1 heading)
    title_match = re.search(r"^#\s+(.+)", content)
    # id = title_match.group(0).strip() if title_match else None
    title = title_match.group(1).strip() if title_match else None

    # Extract Sutta name (from the line starting with "***")
    sutta_match = re.search(r"^\*\*\*\((.+?)\)\*\*\*", content, re.MULTILINE)
    sutta_name = sutta_match.group(1).strip() if sutta_match else None

    # Another way to find title and sutta name
    title_match = re.search(r"# (.*?)\n", content)
    if title_match:
      title = title_match.group(1).strip()

    lines = content.split('\n')
    for line in lines:
       match = re.search(r'\*\*\*\((.*)\)\*\*\*',line) #search in line
       if match:
        sutta_name = match.group(1).strip()
        break

    # Get filename
    filename = filepath

    if title and sutta_name:
        return {
            "title": title,
            "sutta": sutta_name,
            "file1": filename
        }
    else:
        print(f"Warning: Could not extract all information from {filepath}")
        print(f"  Title found: {title}")
        print(f"  Sutta Name found: {sutta_name}")
        return {  # Return what we have, even if incomplete.
            "title": title,
            "sutta": sutta_name,
            "file1": filename
        }


# Example usage:
# filepath = '../kinhtrungbo/thichminhchau/002-kinh-tat-ca-cac-lau-hoac.md' # Replace with your actual file path




# result = parse_markdown_file(filepath)

# if result:
#     print(result)
# else:
#     print("Could not extract information from the file.")

# %%
# 1/4 list all tile of thich minh chau as base
def list_files_in_folder(folder_path):

    return sorted(['../kinhtrungbo/thichminhchau/'+f for f in os.listdir(folder_path) if f.endswith('.md')])


# thich minh chau
folder_path = '/Users/ng/projects/n5/docs/kinhtrungbo/thichminhchau'
file_list = list_files_in_folder(folder_path)
tmc_title = []
for file in file_list:
    result = parse_markdown_file(file)
    result['file1'] = result['file1'][2:]
    tmc_title.append(result)

print(tmc_title)

# folder_path = '/Users/ng/projects/n5/docs/kinhtrungbo/nanamoli-bodhi'
# file_list = list_files_in_folder(folder_path)
# results = []
# for file in file_list:
#     result = parse_markdown_file(filepath)
#     result['file1'] = result['file1'][2:]
#     results.append(result)

# print(results)
# Out:
# Warning: Could not extract all information from ../kinhtrungbo/thichminhchau/g1.md
#   Title found: 1. Lời Nói Ðầu
#   Sutta Name found: None
# Warning: Could not extract all information from ../kinhtrungbo/thichminhchau/index.md
#   Title found: Kinh Trung Bộ
#   Sutta Name found: None
# [{'title': '1. KINH PHÁP MÔN CĂN BẢN', 'sutta': 'Mùlapariyàya Sutta', 'file1': '/kinhtrungbo/thichminhchau/001-kinh-phap-mon-can-ban.md'}, {'title': '2. KINH TẤT CẢ CÁC LẬU HOẶC', 'sutta': 'Sabbàsava Sutta', 'file1': '/kinhtrungbo/thichminhchau/002-kinh-tat-ca-cac-lau-hoac.md'}, {'title': '3. KINH THỪA TỰ PHÁP', 'sutta': 'Dhammadàyàda Sutta', 'file1': '/kinhtrungbo/thichminhchau/003-kinh-thua-tu-phap.md'}, {'title': '4. KINH SỢ HÃI KHIẾP ÐẢM', 'sutta': 'Bhayabherava Sutta', 'file1': '/kinhtrungbo/thichminhchau/004-kinh-so-hai-khiep-dam.md'}, {'title': '5. KINH KHÔNG UẾ NHIỄM', 'sutta': 'Anangana Sutta', 'file1': '/kinhtrungbo/thichminhchau/005-kinh-khong-ue-nhiem.md'}, {'title': '6. KINH ƯỚC NGUYỆN', 'sutta': 'Akankheyya Sutta', 'file1': '/kinhtrungbo/thichminhchau/006-kinh-uoc-nguyen.md'}, {'title': '7. KINH VÍ DỤ TẤM VẢI', 'sutta': 'Vatthùpama Sutta', 'file1': '/kinhtrungbo/thichminhchau/007-kinh-vi-du-tam-vai.md'}, {'title': '8. KINH ÐOẠN GIẢM', 'sutta': 'Sallekha Sutta', 'file1': '/kinhtrungbo/thichminhchau/008-kinh-doan-giam.md'}, {'title': '9. KINH CHÁNH TRI KIẾN', 'sutta': 'Sammàditthi Sutta', 'file1': '/kinhtrungbo/thichminhchau/009-kinh-chanh-tri-kien.md'}, {'title': '10. KINH NIỆM XỨ', 'sutta': 'Satipatthàna Sutta', 'file1': '/kinhtrungbo/thichminhchau/010-kinh-niem-xu.md'}, {'title': '11. TIỂU KINH SƯ TỬ HỐNG', 'sutta': 'Cùlasìhanàda Sutta', 'file1': '/kinhtrungbo/thichminhchau/011-tieu-kinh-su-tu-hong.md'}, {'title': '12. ÐẠI KINH SƯ TỬ HỐNG', 'sutta': 'Mahàsìhanàda Sutta', 'file1': '/kinhtrungbo/thichminhchau/012-dai-kinh-su-tu-hong.md'}, {'title': '13. ÐẠI KINH KHỔ UẨN', 'sutta': 'Mahàdukkhakkhanda Sutta', 'file1': '/kinhtrungbo/thichminhchau/013-dai-kinh-kho-uan.md'}, {'title': '14. TIỂU KINH KHỔ UẨN', 'sutta': 'Cùladukkhakkhanda Sutta', 'file1': '/kinhtrungbo/thichminhchau/014-tieu-kinh-kho-uan.md'}, {'title': '15. KINH TƯ LƯỢNG', 'sutta': 'Anumàna Sutta', 'file1': '/kinhtrungbo/thichminhchau/015-kinh-tu-luong.md'}, {'title': '16. KINH TÂM HOANG VU', 'sutta': 'Cetokhila Sutta', 'file1': '/kinhtrungbo/thichminhchau/016-kinh-tam-hoang-vu.md'}, {'title': '17. KINH KHU RỪNG', 'sutta': 'Vanapattha Sutta', 'file1': '/kinhtrungbo/thichminhchau/017-kinh-khu-rung.md'}, {'title': '18. KINH MẬT HOÀN', 'sutta': 'Madhupindika Sutta', 'file1': '/kinhtrungbo/thichminhchau/018-kinh-mat-hoan.md'}, {'title': '19. KINH SONG TẦM', 'sutta': 'Dvedhàvitakka Sutta', 'file1': '/kinhtrungbo/thichminhchau/019-kinh-song-tam.md'}, {'title': '20. KINH AN TRÚ TẦM', 'sutta': 'Vtakkasanthàna Sutta', 'file1': '/kinhtrungbo/thichminhchau/020-kinh-an-tru-tam.md'}, {'title': '21. KINH VÍ DỤ CÁI CƯA', 'sutta': 'Kakacùpama Sutta', 'file1': '/kinhtrungbo/thichminhchau/021-kinh-vi-du-cai-cua.md'}, {'title': '22. KINH VÍ DỤ CON RẮN', 'sutta': 'Alagaddùpama Sutta', 'file1': '/kinhtrungbo/thichminhchau/022-kinh-vi-du-con-ran.md'}, {'title': '23. KINH GÒ MỐI', 'sutta': 'Vammika Sutta', 'file1': '/kinhtrungbo/thichminhchau/023-kinh-go-moi.md'}, {'title': '24. KINH TRẠM XE', 'sutta': 'Rathavinìta Sutta', 'file1': '/kinhtrungbo/thichminhchau/024-kinh-tram-xe.md'}, {'title': '25. KINH BẪY MỒI', 'sutta': 'Nivàpa Sutta', 'file1': '/kinhtrungbo/thichminhchau/025-kinh-bay-moi.md'}, {'title': '26. KINH THÁNH CẦU', 'sutta': 'Ariyapariyesanà Sutta', 'file1': '/kinhtrungbo/thichminhchau/026-kinh-thanh-cau.md'}, {'title': '27. TIỂU KINH DỤ DẤU CHÂN VOI', 'sutta': 'Cùlahatthipadopama Sutta', 'file1': '/kinhtrungbo/thichminhchau/027-tieu-kinh-du-dau-chan-voi.md'}, {'title': '28. ÐẠI KINH DỤ DẤU CHÂN VOI', 'sutta': 'Mahàhatthipadopama Sutta', 'file1': '/kinhtrungbo/thichminhchau/028-dai-kinh-du-dau-chan-voi.md'}, {'title': '29. ÐẠI KINH THÍ DỤ LÕI CÂY', 'sutta': 'Mahasaropama-Sutta', 'file1': '/kinhtrungbo/thichminhchau/029-dai-kinh-thi-du-loi-cay.md'}, {'title': '30. TIỂU KINH DỤ LÕI CÂY', 'sutta': 'Cùlasàropama Sutta', 'file1': '/kinhtrungbo/thichminhchau/030-tieu-kinh-du-loi-cay.md'}, {'title': '31. TIỂU KINH RỪNG SỪNG BÒ', 'sutta': 'Cùlagosinga Sutta', 'file1': '/kin ...

# %%
# 2/4 get list of 2nd docs
nanamoli_title = sorted(['/kinhtrungbo/nanamoli-bodhi-vi/'+f for f in os.listdir('../kinhtrungbo/nanamoli-bodhi-vi') if f.endswith('.md')])
print(len(nanamoli_title))
# Out:
# 50

# %%
# 3/4 combine 1st + 2nd list
def combine_lists(list_a, list_b):
  """
  Combines two lists to create a new list with the specified format.

  Args:
      list_a: The first list (A).
      list_b: The second list (B).

  Returns:
      A new list with the combined data.  Returns an empty list if the input
      lists have different lengths.
  """

  if len(list_a) != len(list_b):
    print("Error: Lists A and B must have the same length.")
    return []

  combined_list = []
  for i in range(len(list_a)):
    a_item = list_a[i]
    b_item = list_b[i]

    # Extract filename without extension and leading path.  Handle potential errors.
    try:
      filename = a_item['file1'].split('/')[-1].replace('.md', '')
      slug_prefix = "tmc-mn-bodhi-"
      slug = slug_prefix + filename

    except (KeyError, IndexError) as e:
        print(f"Error processing item {i}: {e}.  Skipping this item.")
        continue # Skip to the next iteration if an error occurs

    combined_item = {
        "params": {
            "slug": slug,
            "data": {
                "title": a_item['title'],
                "left": b_item,
                "right": a_item['file1'],  # Corrected placement
                "leftTitle": "Nanamoli-Bodhi",
                "rightTitle": "Thích Minh Châu",
                "notePath": ""
            }
        }
    }
    combined_list.append(combined_item)

  return combined_list

A = tmc_title[:50]
B = nanamoli_title


combined_result = combine_lists(A, B)
# Nicely print the result using json.dumps for readability
import json
print(json.dumps(combined_result, indent=2, ensure_ascii=False))
# Out:
# [
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-001-kinh-phap-mon-can-ban",
#       "data": {
#         "title": "1. KINH PHÁP MÔN CĂN BẢN",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/001-the-root-of-all-things.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/001-kinh-phap-mon-can-ban.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-002-kinh-tat-ca-cac-lau-hoac",
#       "data": {
#         "title": "2. KINH TẤT CẢ CÁC LẬU HOẶC",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/002-all-the-taints.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/002-kinh-tat-ca-cac-lau-hoac.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-003-kinh-thua-tu-phap",
#       "data": {
#         "title": "3. KINH THỪA TỰ PHÁP",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/003-heirs-in-dhamma.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/003-kinh-thua-tu-phap.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-004-kinh-so-hai-khiep-dam",
#       "data": {
#         "title": "4. KINH SỢ HÃI KHIẾP ÐẢM",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/004-fear-and-dread.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/004-kinh-so-hai-khiep-dam.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-005-kinh-khong-ue-nhiem",
#       "data": {
#         "title": "5. KINH KHÔNG UẾ NHIỄM",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/005-without-blemishes.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/005-kinh-khong-ue-nhiem.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-006-kinh-uoc-nguyen",
#       "data": {
#         "title": "6. KINH ƯỚC NGUYỆN",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/006-if-a-bhikkhu-should-wish.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/006-kinh-uoc-nguyen.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-007-kinh-vi-du-tam-vai",
#       "data": {
#         "title": "7. KINH VÍ DỤ TẤM VẢI",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/007-the-simile-of-the-cloth.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/007-kinh-vi-du-tam-vai.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-008-kinh-doan-giam",
#       "data": {
#         "title": "8. KINH ÐOẠN GIẢM",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/008-effacement.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/008-kinh-doan-giam.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-009-kinh-chanh-tri-kien",
#       "data": {
#         "title": "9. KINH CHÁNH TRI KIẾN",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/009-right-view.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/009-kinh-chanh-tri-kien.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-010-kinh-niem-xu",
#       "data": {
#         "title": "10. KINH NIỆM XỨ",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/010-the-foundations-of-mindfulness.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/010-kinh-niem-xu.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-011-tieu-kinh-su-tu-hong",
#       "data": {
#         "title": "11. TIỂU KINH SƯ TỬ HỐNG",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/011-the-shorter-discourse-on-the-lion-s-roar.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/011-tieu-kinh-su-tu-hong.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-012-dai-kinh-su-tu-hong",
#       "data": {
#         "title": "12. ÐẠI KINH SƯ TỬ HỐNG",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/012-the-greater-discourse-on-the-lion-s-roar.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/012-dai-kinh-su-tu-hong.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-013-dai-kinh-kho-uan",
#       "data": {
#         "title": "13. ÐẠI KINH KHỔ UẨN",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/013-the-greater-discourse-on-the-mass-of-suffering.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/013-dai-kinh-kho-uan.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-014-tieu-kinh-kho-uan",
#       "data": {
#         "title": "14. TIỂU KINH KHỔ UẨN",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/014-the-shorter-discourse-on-the-mass-of-suffering.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/014-tieu-kinh-kho-uan.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-015-kinh-tu-luong",
#       "data": {
#         "title": "15. KINH TƯ LƯỢNG",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/016-the-wilderness-in-the-heart.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/015-kinh-tu-luong.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-016-kinh-tam-hoang-vu",
#       "data": {
#         "title": "16. KINH TÂM HOANG VU",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/017-jungle-thickets.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/016-kinh-tam-hoang-vu.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-017-kinh-khu-rung",
#       "data": {
#         "title": "17. KINH KHU RỪNG",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/018-the-honeyball.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/017-kinh-khu-rung.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-018-kinh-mat-hoan",
#       "data": {
#         "title": "18. KINH MẬT HOÀN",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/019-two-kinds-of-thought.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/018-kinh-mat-hoan.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-019-kinh-song-tam",
#       "data": {
#         "title": "19. KINH SONG TẦM",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/020-the-removal-of-distracting-thoughts.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/019-kinh-song-tam.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-020-kinh-an-tru-tam",
#       "data": {
#         "title": "20. KINH AN TRÚ TẦM",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/021-the-simile-of-the-saw.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/020-kinh-an-tru-tam.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-021-kinh-vi-du-cai-cua",
#       "data": {
#         "title": "21. KINH VÍ DỤ CÁI CƯA",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/022-the-simile-of-the-snake.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/021-kinh-vi-du-cai-cua.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-022-kinh-vi-du-con-ran",
#       "data": {
#         "title": "22. KINH VÍ DỤ CON RẮN",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/023-the-ant-hill.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/022-kinh-vi-du-con-ran.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-023-kinh-go-moi",
#       "data": {
#         "title": "23. KINH GÒ MỐI",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/024-the-relay-chariots.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/023-kinh-go-moi.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-024-kinh-tram-xe",
#       "data": {
#         "title": "24. KINH TRẠM XE",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/025-the-bait.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/024-kinh-tram-xe.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-025-kinh-bay-moi",
#       "data": {
#         "title": "25. KINH BẪY MỒI",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/026-the-noble-search.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/025-kinh-bay-moi.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-026-kinh-thanh-cau",
#       "data": {
#         "title": "26. KINH THÁNH CẦU",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/027-the-shorter-discourse-on-the-simile-of-the-elephant-s.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/026-kinh-thanh-cau.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-027-tieu-kinh-du-dau-chan-voi",
#       "data": {
#         "title": "27. TIỂU KINH DỤ DẤU CHÂN VOI",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/028-the-greater-discourse-on-the-simile-of-the-elephant-s.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/027-tieu-kinh-du-dau-chan-voi.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-028-dai-kinh-du-dau-chan-voi",
#       "data": {
#         "title": "28. ÐẠI KINH DỤ DẤU CHÂN VOI",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/029-the-greater-discourse-on-the-simile-of-the-heartwood.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/028-dai-kinh-du-dau-chan-voi.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-029-dai-kinh-thi-du-loi-cay",
#       "data": {
#         "title": "29. ÐẠI KINH THÍ DỤ LÕI CÂY",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/030-the-shorter-discourse-on-the-simile-of-the-heartwood.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/029-dai-kinh-thi-du-loi-cay.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-030-tieu-kinh-du-loi-cay",
#       "data": {
#         "title": "30. TIỂU KINH DỤ LÕI CÂY",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/031-the-shorter-discourse-in-gosinga.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/030-tieu-kinh-du-loi-cay.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-031-tieu-kinh-rung-sung-bo",
#       "data": {
#         "title": "31. TIỂU KINH RỪNG SỪNG BÒ",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/032-the-greater-discourse-in-gosinga.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/031-tieu-kinh-rung-sung-bo.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-032-dai-kinh-rung-sung-bo",
#       "data": {
#         "title": "32. ÐẠI KINH RỪNG SỪNG BÒ",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/033-the-greater-discourse-on-the-cowherd.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/032-dai-kinh-rung-sung-bo.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-033-dai-kinh-nguoi-chan-bo",
#       "data": {
#         "title": "33. ÐẠI KINH NGƯỜI CHĂN BÒ",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/034-the-shorter-discourse-on-the-cowherd.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/033-dai-kinh-nguoi-chan-bo.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-034-tieu-kinh-nguoi-chan-bo",
#       "data": {
#         "title": "34. TIỂU KINH NGƯỜI CHĂN BÒ",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/035-the-shorter-discourse-to-saccaka.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/034-tieu-kinh-nguoi-chan-bo.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-035-tieu-kinh-saccaka",
#       "data": {
#         "title": "35. TIỂU KINH SACCAKA",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/036-the-greater-discourse-to-saccaka.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/035-tieu-kinh-saccaka.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-036-dai-kinh-saccaka",
#       "data": {
#         "title": "36. ÐẠI KINH SACCAKA",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/037-the-shorter-discourse-on-the-destruction-of-craving.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/036-dai-kinh-saccaka.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-037-tieu-kinh-doan-tan-ai",
#       "data": {
#         "title": "37. TIỂU KINH ÐOẠN TẬN ÁI",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/038-the-greater-discourse-on-the-destruction-of-craving.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/037-tieu-kinh-doan-tan-ai.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-038-dai-kinh-doan-tan-ai",
#       "data": {
#         "title": "38. ÐẠI KINH ÐOẠN TẬN ÁI",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/039-the-greater-discourse-at-assapura.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/038-dai-kinh-doan-tan-ai.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-039-dai-kinh-xom-ngua",
#       "data": {
#         "title": "39. ÐẠI KINH XÓM NGỰA",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/040-the-shorter-discourse-at-assapura.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/039-dai-kinh-xom-ngua.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-040-tieu-kinh-xom-ngua",
#       "data": {
#         "title": "40. TIỂU KINH XÓM NGỰA",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/041-the-brahmins-of-sala.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/040-tieu-kinh-xom-ngua.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-041-kinh-saleyyaka",
#       "data": {
#         "title": "41. KINH SÀLEYYAKA",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/042-the-brahmins-of-veranja.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/041-kinh-saleyyaka.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-042-kinh-veranjaka",
#       "data": {
#         "title": "42. KINH VERANJAKA",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/043-the-greater-series-of-questions-and-answers.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/042-kinh-veranjaka.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-043-dai-kinh-phuong-quang",
#       "data": {
#         "title": "43. ÐẠI KINH PHƯƠNG QUẢNG",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/044-the-shorter-series-of-questions-and-answers.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/043-dai-kinh-phuong-quang.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-044-tieu-kinh-phuong-quang",
#       "data": {
#         "title": "44. TIỂU KINH PHƯƠNG QUẢNG",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/045-the-shorter-discourse-on-ways-of-undertaking-things.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/044-tieu-kinh-phuong-quang.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-045-tieu-kinh-phap-hanh",
#       "data": {
#         "title": "45. TIỂU KINH PHÁP HÀNH",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/046-the-greater-discourse-on-ways-of-undertaking-things.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/045-tieu-kinh-phap-hanh.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-046-dai-kinh-phap-hanh",
#       "data": {
#         "title": "46. ÐẠI KINH PHÁP HÀNH",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/047-the-inquirer.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/046-dai-kinh-phap-hanh.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-047-kinh-tu-sat",
#       "data": {
#         "title": "47. KINH TƯ SÁT",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/048-the-kosambians.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/047-kinh-tu-sat.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-048-kinh-kosambiya",
#       "data": {
#         "title": "48. KINH KOSAMBIYA",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/049-the-invitation-of-a-brahma.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/048-kinh-kosambiya.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-049-kinh-pham-thien-cau-thinh",
#       "data": {
#         "title": "49. KINH PHẠM THIÊN CẦU THỈNH",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/050-the-rebuke-to-mara.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/049-kinh-pham-thien-cau-thinh.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-050-kinh-hang-ma",
#       "data": {
#         "title": "50. KINH HÀNG MA",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/index.md",
#         "right": "/kinhtrungbo/thichminhchau/050-kinh-hang-ma.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": ""
#       }
#     }
#   }
# ]

# %%
# 4/4 add nextlink, backlink
def generate_link(index, item):
  """Generates the link object for nextlink and backlink."""
  return {
      "text": item['params']['data']['title'],
      "link": f"/kinhtrungbo/c-nm-tmc-vi/{item['params']['slug']}"
  }
def add_links(data):
    """Adds nextlink and backlink to each element in the data list."""
    for i in range(len(data)):
        # Backlink
        if i > 0:
            data[i]["params"]["data"]["backlink"] = generate_link(i - 1, data[i - 1])
        else:
            data[i]["params"]["data"]["backlink"] = False

        # Nextlink
        if i < len(data) - 1:
             data[i]["params"]["data"]["nextlink"] = generate_link(i + 1, data[i+1])
        else:
            data[i]["params"]["data"]["nextlink"] = False

    return data

updated_data = add_links(combined_result)

# Print the updated data (for verification)
import json
print(json.dumps(updated_data, indent=2, ensure_ascii=False))
# Out:
# [
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-001-kinh-phap-mon-can-ban",
#       "data": {
#         "title": "1. KINH PHÁP MÔN CĂN BẢN",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/001-the-root-of-all-things.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/001-kinh-phap-mon-can-ban.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": false,
#         "nextlink": {
#           "text": "2. KINH TẤT CẢ CÁC LẬU HOẶC",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-002-kinh-tat-ca-cac-lau-hoac"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-002-kinh-tat-ca-cac-lau-hoac",
#       "data": {
#         "title": "2. KINH TẤT CẢ CÁC LẬU HOẶC",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/002-all-the-taints.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/002-kinh-tat-ca-cac-lau-hoac.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "1. KINH PHÁP MÔN CĂN BẢN",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-001-kinh-phap-mon-can-ban"
#         },
#         "nextlink": {
#           "text": "3. KINH THỪA TỰ PHÁP",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-003-kinh-thua-tu-phap"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-003-kinh-thua-tu-phap",
#       "data": {
#         "title": "3. KINH THỪA TỰ PHÁP",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/003-heirs-in-dhamma.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/003-kinh-thua-tu-phap.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "2. KINH TẤT CẢ CÁC LẬU HOẶC",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-002-kinh-tat-ca-cac-lau-hoac"
#         },
#         "nextlink": {
#           "text": "4. KINH SỢ HÃI KHIẾP ÐẢM",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-004-kinh-so-hai-khiep-dam"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-004-kinh-so-hai-khiep-dam",
#       "data": {
#         "title": "4. KINH SỢ HÃI KHIẾP ÐẢM",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/004-fear-and-dread.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/004-kinh-so-hai-khiep-dam.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "3. KINH THỪA TỰ PHÁP",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-003-kinh-thua-tu-phap"
#         },
#         "nextlink": {
#           "text": "5. KINH KHÔNG UẾ NHIỄM",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-005-kinh-khong-ue-nhiem"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-005-kinh-khong-ue-nhiem",
#       "data": {
#         "title": "5. KINH KHÔNG UẾ NHIỄM",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/005-without-blemishes.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/005-kinh-khong-ue-nhiem.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "4. KINH SỢ HÃI KHIẾP ÐẢM",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-004-kinh-so-hai-khiep-dam"
#         },
#         "nextlink": {
#           "text": "6. KINH ƯỚC NGUYỆN",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-006-kinh-uoc-nguyen"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-006-kinh-uoc-nguyen",
#       "data": {
#         "title": "6. KINH ƯỚC NGUYỆN",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/006-if-a-bhikkhu-should-wish.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/006-kinh-uoc-nguyen.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "5. KINH KHÔNG UẾ NHIỄM",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-005-kinh-khong-ue-nhiem"
#         },
#         "nextlink": {
#           "text": "7. KINH VÍ DỤ TẤM VẢI",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-007-kinh-vi-du-tam-vai"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-007-kinh-vi-du-tam-vai",
#       "data": {
#         "title": "7. KINH VÍ DỤ TẤM VẢI",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/007-the-simile-of-the-cloth.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/007-kinh-vi-du-tam-vai.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "6. KINH ƯỚC NGUYỆN",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-006-kinh-uoc-nguyen"
#         },
#         "nextlink": {
#           "text": "8. KINH ÐOẠN GIẢM",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-008-kinh-doan-giam"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-008-kinh-doan-giam",
#       "data": {
#         "title": "8. KINH ÐOẠN GIẢM",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/008-effacement.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/008-kinh-doan-giam.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "7. KINH VÍ DỤ TẤM VẢI",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-007-kinh-vi-du-tam-vai"
#         },
#         "nextlink": {
#           "text": "9. KINH CHÁNH TRI KIẾN",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-009-kinh-chanh-tri-kien"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-009-kinh-chanh-tri-kien",
#       "data": {
#         "title": "9. KINH CHÁNH TRI KIẾN",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/009-right-view.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/009-kinh-chanh-tri-kien.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "8. KINH ÐOẠN GIẢM",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-008-kinh-doan-giam"
#         },
#         "nextlink": {
#           "text": "10. KINH NIỆM XỨ",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-010-kinh-niem-xu"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-010-kinh-niem-xu",
#       "data": {
#         "title": "10. KINH NIỆM XỨ",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/010-the-foundations-of-mindfulness.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/010-kinh-niem-xu.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "9. KINH CHÁNH TRI KIẾN",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-009-kinh-chanh-tri-kien"
#         },
#         "nextlink": {
#           "text": "11. TIỂU KINH SƯ TỬ HỐNG",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-011-tieu-kinh-su-tu-hong"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-011-tieu-kinh-su-tu-hong",
#       "data": {
#         "title": "11. TIỂU KINH SƯ TỬ HỐNG",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/011-the-shorter-discourse-on-the-lion-s-roar.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/011-tieu-kinh-su-tu-hong.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "10. KINH NIỆM XỨ",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-010-kinh-niem-xu"
#         },
#         "nextlink": {
#           "text": "12. ÐẠI KINH SƯ TỬ HỐNG",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-012-dai-kinh-su-tu-hong"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-012-dai-kinh-su-tu-hong",
#       "data": {
#         "title": "12. ÐẠI KINH SƯ TỬ HỐNG",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/012-the-greater-discourse-on-the-lion-s-roar.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/012-dai-kinh-su-tu-hong.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "11. TIỂU KINH SƯ TỬ HỐNG",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-011-tieu-kinh-su-tu-hong"
#         },
#         "nextlink": {
#           "text": "13. ÐẠI KINH KHỔ UẨN",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-013-dai-kinh-kho-uan"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-013-dai-kinh-kho-uan",
#       "data": {
#         "title": "13. ÐẠI KINH KHỔ UẨN",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/013-the-greater-discourse-on-the-mass-of-suffering.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/013-dai-kinh-kho-uan.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "12. ÐẠI KINH SƯ TỬ HỐNG",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-012-dai-kinh-su-tu-hong"
#         },
#         "nextlink": {
#           "text": "14. TIỂU KINH KHỔ UẨN",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-014-tieu-kinh-kho-uan"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-014-tieu-kinh-kho-uan",
#       "data": {
#         "title": "14. TIỂU KINH KHỔ UẨN",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/014-the-shorter-discourse-on-the-mass-of-suffering.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/014-tieu-kinh-kho-uan.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "13. ÐẠI KINH KHỔ UẨN",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-013-dai-kinh-kho-uan"
#         },
#         "nextlink": {
#           "text": "15. KINH TƯ LƯỢNG",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-015-kinh-tu-luong"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-015-kinh-tu-luong",
#       "data": {
#         "title": "15. KINH TƯ LƯỢNG",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/016-the-wilderness-in-the-heart.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/015-kinh-tu-luong.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "14. TIỂU KINH KHỔ UẨN",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-014-tieu-kinh-kho-uan"
#         },
#         "nextlink": {
#           "text": "16. KINH TÂM HOANG VU",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-016-kinh-tam-hoang-vu"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-016-kinh-tam-hoang-vu",
#       "data": {
#         "title": "16. KINH TÂM HOANG VU",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/017-jungle-thickets.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/016-kinh-tam-hoang-vu.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "15. KINH TƯ LƯỢNG",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-015-kinh-tu-luong"
#         },
#         "nextlink": {
#           "text": "17. KINH KHU RỪNG",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-017-kinh-khu-rung"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-017-kinh-khu-rung",
#       "data": {
#         "title": "17. KINH KHU RỪNG",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/018-the-honeyball.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/017-kinh-khu-rung.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "16. KINH TÂM HOANG VU",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-016-kinh-tam-hoang-vu"
#         },
#         "nextlink": {
#           "text": "18. KINH MẬT HOÀN",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-018-kinh-mat-hoan"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-018-kinh-mat-hoan",
#       "data": {
#         "title": "18. KINH MẬT HOÀN",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/019-two-kinds-of-thought.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/018-kinh-mat-hoan.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "17. KINH KHU RỪNG",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-017-kinh-khu-rung"
#         },
#         "nextlink": {
#           "text": "19. KINH SONG TẦM",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-019-kinh-song-tam"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-019-kinh-song-tam",
#       "data": {
#         "title": "19. KINH SONG TẦM",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/020-the-removal-of-distracting-thoughts.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/019-kinh-song-tam.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "18. KINH MẬT HOÀN",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-018-kinh-mat-hoan"
#         },
#         "nextlink": {
#           "text": "20. KINH AN TRÚ TẦM",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-020-kinh-an-tru-tam"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-020-kinh-an-tru-tam",
#       "data": {
#         "title": "20. KINH AN TRÚ TẦM",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/021-the-simile-of-the-saw.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/020-kinh-an-tru-tam.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "19. KINH SONG TẦM",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-019-kinh-song-tam"
#         },
#         "nextlink": {
#           "text": "21. KINH VÍ DỤ CÁI CƯA",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-021-kinh-vi-du-cai-cua"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-021-kinh-vi-du-cai-cua",
#       "data": {
#         "title": "21. KINH VÍ DỤ CÁI CƯA",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/022-the-simile-of-the-snake.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/021-kinh-vi-du-cai-cua.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "20. KINH AN TRÚ TẦM",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-020-kinh-an-tru-tam"
#         },
#         "nextlink": {
#           "text": "22. KINH VÍ DỤ CON RẮN",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-022-kinh-vi-du-con-ran"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-022-kinh-vi-du-con-ran",
#       "data": {
#         "title": "22. KINH VÍ DỤ CON RẮN",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/023-the-ant-hill.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/022-kinh-vi-du-con-ran.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "21. KINH VÍ DỤ CÁI CƯA",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-021-kinh-vi-du-cai-cua"
#         },
#         "nextlink": {
#           "text": "23. KINH GÒ MỐI",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-023-kinh-go-moi"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-023-kinh-go-moi",
#       "data": {
#         "title": "23. KINH GÒ MỐI",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/024-the-relay-chariots.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/023-kinh-go-moi.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "22. KINH VÍ DỤ CON RẮN",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-022-kinh-vi-du-con-ran"
#         },
#         "nextlink": {
#           "text": "24. KINH TRẠM XE",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-024-kinh-tram-xe"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-024-kinh-tram-xe",
#       "data": {
#         "title": "24. KINH TRẠM XE",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/025-the-bait.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/024-kinh-tram-xe.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "23. KINH GÒ MỐI",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-023-kinh-go-moi"
#         },
#         "nextlink": {
#           "text": "25. KINH BẪY MỒI",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-025-kinh-bay-moi"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-025-kinh-bay-moi",
#       "data": {
#         "title": "25. KINH BẪY MỒI",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/026-the-noble-search.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/025-kinh-bay-moi.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "24. KINH TRẠM XE",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-024-kinh-tram-xe"
#         },
#         "nextlink": {
#           "text": "26. KINH THÁNH CẦU",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-026-kinh-thanh-cau"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-026-kinh-thanh-cau",
#       "data": {
#         "title": "26. KINH THÁNH CẦU",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/027-the-shorter-discourse-on-the-simile-of-the-elephant-s.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/026-kinh-thanh-cau.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "25. KINH BẪY MỒI",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-025-kinh-bay-moi"
#         },
#         "nextlink": {
#           "text": "27. TIỂU KINH DỤ DẤU CHÂN VOI",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-027-tieu-kinh-du-dau-chan-voi"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-027-tieu-kinh-du-dau-chan-voi",
#       "data": {
#         "title": "27. TIỂU KINH DỤ DẤU CHÂN VOI",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/028-the-greater-discourse-on-the-simile-of-the-elephant-s.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/027-tieu-kinh-du-dau-chan-voi.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "26. KINH THÁNH CẦU",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-026-kinh-thanh-cau"
#         },
#         "nextlink": {
#           "text": "28. ÐẠI KINH DỤ DẤU CHÂN VOI",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-028-dai-kinh-du-dau-chan-voi"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-028-dai-kinh-du-dau-chan-voi",
#       "data": {
#         "title": "28. ÐẠI KINH DỤ DẤU CHÂN VOI",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/029-the-greater-discourse-on-the-simile-of-the-heartwood.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/028-dai-kinh-du-dau-chan-voi.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "27. TIỂU KINH DỤ DẤU CHÂN VOI",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-027-tieu-kinh-du-dau-chan-voi"
#         },
#         "nextlink": {
#           "text": "29. ÐẠI KINH THÍ DỤ LÕI CÂY",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-029-dai-kinh-thi-du-loi-cay"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-029-dai-kinh-thi-du-loi-cay",
#       "data": {
#         "title": "29. ÐẠI KINH THÍ DỤ LÕI CÂY",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/030-the-shorter-discourse-on-the-simile-of-the-heartwood.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/029-dai-kinh-thi-du-loi-cay.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "28. ÐẠI KINH DỤ DẤU CHÂN VOI",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-028-dai-kinh-du-dau-chan-voi"
#         },
#         "nextlink": {
#           "text": "30. TIỂU KINH DỤ LÕI CÂY",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-030-tieu-kinh-du-loi-cay"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-030-tieu-kinh-du-loi-cay",
#       "data": {
#         "title": "30. TIỂU KINH DỤ LÕI CÂY",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/031-the-shorter-discourse-in-gosinga.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/030-tieu-kinh-du-loi-cay.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "29. ÐẠI KINH THÍ DỤ LÕI CÂY",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-029-dai-kinh-thi-du-loi-cay"
#         },
#         "nextlink": {
#           "text": "31. TIỂU KINH RỪNG SỪNG BÒ",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-031-tieu-kinh-rung-sung-bo"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-031-tieu-kinh-rung-sung-bo",
#       "data": {
#         "title": "31. TIỂU KINH RỪNG SỪNG BÒ",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/032-the-greater-discourse-in-gosinga.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/031-tieu-kinh-rung-sung-bo.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "30. TIỂU KINH DỤ LÕI CÂY",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-030-tieu-kinh-du-loi-cay"
#         },
#         "nextlink": {
#           "text": "32. ÐẠI KINH RỪNG SỪNG BÒ",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-032-dai-kinh-rung-sung-bo"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-032-dai-kinh-rung-sung-bo",
#       "data": {
#         "title": "32. ÐẠI KINH RỪNG SỪNG BÒ",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/033-the-greater-discourse-on-the-cowherd.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/032-dai-kinh-rung-sung-bo.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "31. TIỂU KINH RỪNG SỪNG BÒ",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-031-tieu-kinh-rung-sung-bo"
#         },
#         "nextlink": {
#           "text": "33. ÐẠI KINH NGƯỜI CHĂN BÒ",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-033-dai-kinh-nguoi-chan-bo"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-033-dai-kinh-nguoi-chan-bo",
#       "data": {
#         "title": "33. ÐẠI KINH NGƯỜI CHĂN BÒ",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/034-the-shorter-discourse-on-the-cowherd.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/033-dai-kinh-nguoi-chan-bo.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "32. ÐẠI KINH RỪNG SỪNG BÒ",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-032-dai-kinh-rung-sung-bo"
#         },
#         "nextlink": {
#           "text": "34. TIỂU KINH NGƯỜI CHĂN BÒ",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-034-tieu-kinh-nguoi-chan-bo"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-034-tieu-kinh-nguoi-chan-bo",
#       "data": {
#         "title": "34. TIỂU KINH NGƯỜI CHĂN BÒ",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/035-the-shorter-discourse-to-saccaka.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/034-tieu-kinh-nguoi-chan-bo.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "33. ÐẠI KINH NGƯỜI CHĂN BÒ",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-033-dai-kinh-nguoi-chan-bo"
#         },
#         "nextlink": {
#           "text": "35. TIỂU KINH SACCAKA",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-035-tieu-kinh-saccaka"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-035-tieu-kinh-saccaka",
#       "data": {
#         "title": "35. TIỂU KINH SACCAKA",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/036-the-greater-discourse-to-saccaka.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/035-tieu-kinh-saccaka.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "34. TIỂU KINH NGƯỜI CHĂN BÒ",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-034-tieu-kinh-nguoi-chan-bo"
#         },
#         "nextlink": {
#           "text": "36. ÐẠI KINH SACCAKA",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-036-dai-kinh-saccaka"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-036-dai-kinh-saccaka",
#       "data": {
#         "title": "36. ÐẠI KINH SACCAKA",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/037-the-shorter-discourse-on-the-destruction-of-craving.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/036-dai-kinh-saccaka.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "35. TIỂU KINH SACCAKA",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-035-tieu-kinh-saccaka"
#         },
#         "nextlink": {
#           "text": "37. TIỂU KINH ÐOẠN TẬN ÁI",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-037-tieu-kinh-doan-tan-ai"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-037-tieu-kinh-doan-tan-ai",
#       "data": {
#         "title": "37. TIỂU KINH ÐOẠN TẬN ÁI",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/038-the-greater-discourse-on-the-destruction-of-craving.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/037-tieu-kinh-doan-tan-ai.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "36. ÐẠI KINH SACCAKA",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-036-dai-kinh-saccaka"
#         },
#         "nextlink": {
#           "text": "38. ÐẠI KINH ÐOẠN TẬN ÁI",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-038-dai-kinh-doan-tan-ai"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-038-dai-kinh-doan-tan-ai",
#       "data": {
#         "title": "38. ÐẠI KINH ÐOẠN TẬN ÁI",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/039-the-greater-discourse-at-assapura.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/038-dai-kinh-doan-tan-ai.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "37. TIỂU KINH ÐOẠN TẬN ÁI",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-037-tieu-kinh-doan-tan-ai"
#         },
#         "nextlink": {
#           "text": "39. ÐẠI KINH XÓM NGỰA",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-039-dai-kinh-xom-ngua"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-039-dai-kinh-xom-ngua",
#       "data": {
#         "title": "39. ÐẠI KINH XÓM NGỰA",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/040-the-shorter-discourse-at-assapura.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/039-dai-kinh-xom-ngua.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "38. ÐẠI KINH ÐOẠN TẬN ÁI",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-038-dai-kinh-doan-tan-ai"
#         },
#         "nextlink": {
#           "text": "40. TIỂU KINH XÓM NGỰA",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-040-tieu-kinh-xom-ngua"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-040-tieu-kinh-xom-ngua",
#       "data": {
#         "title": "40. TIỂU KINH XÓM NGỰA",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/041-the-brahmins-of-sala.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/040-tieu-kinh-xom-ngua.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "39. ÐẠI KINH XÓM NGỰA",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-039-dai-kinh-xom-ngua"
#         },
#         "nextlink": {
#           "text": "41. KINH SÀLEYYAKA",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-041-kinh-saleyyaka"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-041-kinh-saleyyaka",
#       "data": {
#         "title": "41. KINH SÀLEYYAKA",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/042-the-brahmins-of-veranja.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/041-kinh-saleyyaka.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "40. TIỂU KINH XÓM NGỰA",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-040-tieu-kinh-xom-ngua"
#         },
#         "nextlink": {
#           "text": "42. KINH VERANJAKA",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-042-kinh-veranjaka"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-042-kinh-veranjaka",
#       "data": {
#         "title": "42. KINH VERANJAKA",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/043-the-greater-series-of-questions-and-answers.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/042-kinh-veranjaka.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "41. KINH SÀLEYYAKA",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-041-kinh-saleyyaka"
#         },
#         "nextlink": {
#           "text": "43. ÐẠI KINH PHƯƠNG QUẢNG",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-043-dai-kinh-phuong-quang"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-043-dai-kinh-phuong-quang",
#       "data": {
#         "title": "43. ÐẠI KINH PHƯƠNG QUẢNG",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/044-the-shorter-series-of-questions-and-answers.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/043-dai-kinh-phuong-quang.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "42. KINH VERANJAKA",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-042-kinh-veranjaka"
#         },
#         "nextlink": {
#           "text": "44. TIỂU KINH PHƯƠNG QUẢNG",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-044-tieu-kinh-phuong-quang"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-044-tieu-kinh-phuong-quang",
#       "data": {
#         "title": "44. TIỂU KINH PHƯƠNG QUẢNG",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/045-the-shorter-discourse-on-ways-of-undertaking-things.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/044-tieu-kinh-phuong-quang.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "43. ÐẠI KINH PHƯƠNG QUẢNG",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-043-dai-kinh-phuong-quang"
#         },
#         "nextlink": {
#           "text": "45. TIỂU KINH PHÁP HÀNH",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-045-tieu-kinh-phap-hanh"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-045-tieu-kinh-phap-hanh",
#       "data": {
#         "title": "45. TIỂU KINH PHÁP HÀNH",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/046-the-greater-discourse-on-ways-of-undertaking-things.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/045-tieu-kinh-phap-hanh.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "44. TIỂU KINH PHƯƠNG QUẢNG",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-044-tieu-kinh-phuong-quang"
#         },
#         "nextlink": {
#           "text": "46. ÐẠI KINH PHÁP HÀNH",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-046-dai-kinh-phap-hanh"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-046-dai-kinh-phap-hanh",
#       "data": {
#         "title": "46. ÐẠI KINH PHÁP HÀNH",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/047-the-inquirer.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/046-dai-kinh-phap-hanh.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "45. TIỂU KINH PHÁP HÀNH",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-045-tieu-kinh-phap-hanh"
#         },
#         "nextlink": {
#           "text": "47. KINH TƯ SÁT",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-047-kinh-tu-sat"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-047-kinh-tu-sat",
#       "data": {
#         "title": "47. KINH TƯ SÁT",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/048-the-kosambians.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/047-kinh-tu-sat.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "46. ÐẠI KINH PHÁP HÀNH",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-046-dai-kinh-phap-hanh"
#         },
#         "nextlink": {
#           "text": "48. KINH KOSAMBIYA",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-048-kinh-kosambiya"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-048-kinh-kosambiya",
#       "data": {
#         "title": "48. KINH KOSAMBIYA",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/049-the-invitation-of-a-brahma.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/048-kinh-kosambiya.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "47. KINH TƯ SÁT",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-047-kinh-tu-sat"
#         },
#         "nextlink": {
#           "text": "49. KINH PHẠM THIÊN CẦU THỈNH",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-049-kinh-pham-thien-cau-thinh"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-049-kinh-pham-thien-cau-thinh",
#       "data": {
#         "title": "49. KINH PHẠM THIÊN CẦU THỈNH",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/050-the-rebuke-to-mara.vi.md",
#         "right": "/kinhtrungbo/thichminhchau/049-kinh-pham-thien-cau-thinh.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "48. KINH KOSAMBIYA",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-048-kinh-kosambiya"
#         },
#         "nextlink": {
#           "text": "50. KINH HÀNG MA",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-050-kinh-hang-ma"
#         }
#       }
#     }
#   },
#   {
#     "params": {
#       "slug": "tmc-mn-bodhi-050-kinh-hang-ma",
#       "data": {
#         "title": "50. KINH HÀNG MA",
#         "left": "/kinhtrungbo/nanamoli-bodhi-vi/index.md",
#         "right": "/kinhtrungbo/thichminhchau/050-kinh-hang-ma.md",
#         "leftTitle": "Nanamoli-Bodhi",
#         "rightTitle": "Thích Minh Châu",
#         "notePath": "",
#         "backlink": {
#           "text": "49. KINH PHẠM THIÊN CẦU THỈNH",
#           "link": "/kinhtrungbo/c-nm-tmc-vi/tmc-mn-bodhi-049-kinh-pham-thien-cau-thinh"
#         },
#         "nextlink": false
#       }
#     }
#   }
# ]
