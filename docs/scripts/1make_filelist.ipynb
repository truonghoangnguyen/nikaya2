# %%
import os
import re

def generate_filelist(folder_path, listname, folder_out):
    """
    filelist.js using for generate next/back button config in config.js
    mucluc.md using for generate table of contents

    Generates a JavaScript filelist from Markdown files in a folder.

    Args:
        folder_path: The path to the folder containing the Markdown files.
        listname: The name to use for the JavaScript constant and export.

    Returns:
        None.  Writes the output to a file named 'filelist.js' in the input folder.
    """

    file_list = []
    _lst = sorted([f for f in os.listdir(folder_path) if f.endswith('.md')])
    for filename in _lst:
        # print(filename)
        file_path = os.path.join(folder_path, filename)
        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                first_line = f.readline().strip()
                # Match lines starting with '#' followed by a space and capture the rest.
                match = re.match(r"^#\s+(.*)", first_line)
                if match:
                    title = match.group(1).strip()
                    # Create file_item dict and handle exceptions
                    file_item = {
                        "text": title,
                        "link": os.path.join(folder_out, filename).replace("\\", "/")  # handle Windows path
                    }
                    file_list.append(file_item)
                    print(file_item)
                else:
                        print(f"Warning: No title found in {filename}")


        except FileNotFoundError:
            print(f"Error: File not found: {file_path}")
        except Exception as e:
            print(f"Error reading or processing {filename}: {e}")

    # Sort the file list alphabetically by 'text'
    # file_list.sort(key=lambda x: x['text'])

    # Generate the JavaScript code.
    js_code = f"const {listname} = [\n"
    for item in file_list:
        js_code += f'  {{ text: "{item["text"]}", link: "{item["link"]}" }},\n'
    js_code += "];\n"
    js_code += f"export default {listname};\n"

    # Write the JavaScript code to filelist.js
    output_file_path = os.path.join(folder_path, "filelist.js")
    try:
        with open(output_file_path, 'w', encoding='utf-8') as outfile:
            outfile.write(js_code)
        print(f"Successfully generated filelist.js in {folder_path}")
    except Exception as e:
        print(f"Error writing to filelist.js: {e}")

    # Generate the Markdown table of contents (mucluc.md)
    md_toc = ""
    for item in file_list:
        md_toc += f'- [{item["text"]}]({item["link"]})\n'

    # Write the Markdown TOC to mucluc.md
    output_md_path = os.path.join(folder_path, "mucluc.md")
    try:
        with open(output_md_path, 'w', encoding='utf-8') as outfile:
            outfile.write(md_toc)
        print(f"Successfully generated mucluc.md in {folder_path}")
    except Exception as e:
        print(f"Error writing to mucluc.md: {e}")


def main():
    """
    Main function to get inputs and call generate_filelist.
    """
    folder_path = "../kinhtrungbo/nanamoli-bodhi-vi"
    listname = "nanamoli_bodhi_vi"
    folder_out = '../kinhtrungbo/nanamoli-bodhi-vi'

    if not os.path.isdir(folder_path):
        print(f"Error: The provided folder path '{folder_path}' is not a valid directory.")
        return

    generate_filelist(folder_path, listname, folder_out)

if __name__ == "__main__":
    main()
# Out:
# {'text': '1 Gốc Rễ của Mọi Sự Vật', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/001-the-root-of-all-things.md'}
# {'text': '2 Tất Cả Các Lậu Hoặc', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/002-all-the-taints.md'}
# {'text': '3 Heirs in Dhamma', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/003-heirs-in-dhamma.md'}
# {'text': '4 Fear and Dread', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/004-fear-and-dread.md'}
# {'text': '5 Without Blemishes', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/005-without-blemishes.md'}
# {'text': '6 If a Bhikkhu Should Wish', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/006-if-a-bhikkhu-should-wish.md'}
# {'text': '7 The Simile of the Cloth', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/007-the-simile-of-the-cloth.md'}
# {'text': '8 Effacement', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/008-effacement.md'}
# {'text': '9 Right View', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/009-right-view.md'}
# {'text': '10 The Foundations of Mindfulness', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/010-the-foundations-of-mindfulness.md'}
# {'text': "11 The Shorter Discourse on the Lion's Roar", 'link': '../kinhtrungbo/nanamoli-bodhi-vi/011-the-shorter-discourse-on-the-lion-s-roar.md'}
# {'text': "12 The Greater Discourse on the Lion's Roar", 'link': '../kinhtrungbo/nanamoli-bodhi-vi/012-the-greater-discourse-on-the-lion-s-roar.md'}
# {'text': '13 The Greater Discourse on the Mass of Suffering', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/013-the-greater-discourse-on-the-mass-of-suffering.md'}
# {'text': '14 The Shorter Discourse on the Mass of Suffering', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/014-the-shorter-discourse-on-the-mass-of-suffering.md'}
# {'text': '15 Inference', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/015-inference.md'}
# {'text': '16 The Wilderness in the Heart', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/016-the-wilderness-in-the-heart.md'}
# {'text': '17 Jungle Thickets', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/017-jungle-thickets.md'}
# {'text': '18 The Honeyball', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/018-the-honeyball.md'}
# {'text': '19 Two Kinds of Thought', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/019-two-kinds-of-thought.md'}
# {'text': '20 The Removal of Distracting Thoughts', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/020-the-removal-of-distracting-thoughts.md'}
# {'text': '21 The Simile of the Saw', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/021-the-simile-of-the-saw.md'}
# {'text': '22 The Simile of the Snake', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/022-the-simile-of-the-snake.md'}
# {'text': '23 The Ant-hill', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/023-the-ant-hill.md'}
# {'text': '24 The Relay Chariots', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/024-the-relay-chariots.md'}
# {'text': '25 The Bait', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/025-the-bait.md'}
# {'text': '26 The Noble Search', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/026-the-noble-search.md'}
# {'text': "27 The Shorter Discourse on the Simile of the Elephant's Footprint", 'link': '../kinhtrungbo/nanamoli-bodhi-vi/027-the-shorter-discourse-on-the-simile-of-the-elephant-s-footprint.md'}
# {'text': "28 The Greater Discourse on the Simile of the Elephant's Footprint", 'link': '../kinhtrungbo/nanamoli-bodhi-vi/028-the-greater-discourse-on-the-simile-of-the-elephant-s-footprint.md'}
# {'text': '29 The Greater Discourse on the Simile of the Heartwood', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/029-the-greater-discourse-on-the-simile-of-the-heartwood.md'}
# {'text': '30 The Shorter Discourse on the Simile of the Heartwood', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/030-the-shorter-discourse-on-the-simile-of-the-heartwood.md'}
# {'text': '31 The Shorter Discourse in Gosinga', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/031-the-shorter-discourse-in-gosinga.md'}
# {'text': '32 The Greater Discourse in Gosinga', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/032-the-greater-discourse-in-gosinga.md'}
# {'text': '33 The Greater Discourse on the Cowherd', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/033-the-greater-discourse-on-the-cowherd.md'}
# {'text': '34 The Shorter Discourse on the Cowherd', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/034-the-shorter-discourse-on-the-cowherd.md'}
# {'text': '35 The Shorter Discourse to Saccaka', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/035-the-shorter-discourse-to-saccaka.md'}
# {'text': '36 The Greater Discourse to Saccaka', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/036-the-greater-discourse-to-saccaka.md'}
# {'text': '37 The Shorter Discourse on the Destruction of Craving', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/037-the-shorter-discourse-on-the-destruction-of-craving.md'}
# {'text': '38 The Greater Discourse on the Destruction of Craving', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/038-the-greater-discourse-on-the-destruction-of-craving.md'}
# {'text': '39 The Greater Discourse at Assapura', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/039-the-greater-discourse-at-assapura.md'}
# {'text': '40 The Shorter Discourse at Assapura', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/040-the-shorter-discourse-at-assapura.md'}
# {'text': '41 The Brahmins of Sālā', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/041-the-brahmins-of-sala.md'}
# {'text': '42 The Brahmins of Verañja', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/042-the-brahmins-of-veranja.md'}
# {'text': '43 The Greater Series of Questions and Answers', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/043-the-greater-series-of-questions-and-answers.md'}
# {'text': '44 The Shorter Series of Questions and Answers', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/044-the-shorter-series-of-questions-and-answers.md'}
# {'text': '45 The Shorter Discourse on Ways of Undertaking Things', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/045-the-shorter-discourse-on-ways-of-undertaking-things.md'}
# {'text': '46 The Greater Discourse on Ways of Undertaking Things', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/046-the-greater-discourse-on-ways-of-undertaking-things.md'}
# {'text': '47 The Inquirer', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/047-the-inquirer.md'}
# {'text': '48 The Kosambians', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/048-the-kosambians.md'}
# {'text': '49 The Invitation of a Brahmā', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/049-the-invitation-of-a-brahma.md'}
# {'text': '50 The Rebuke to Māra', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/050-the-rebuke-to-mara.md'}
# {'text': '51 To Kandaraka', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/051-to-kandaraka.md'}
# {'text': '52 The Man from Atṭhakanagara', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/052-the-man-from-atthakanagara.md'}
# {'text': '53 The Disciple in Higher Training', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/053-the-disciple-in-higher-training.md'}
# {'text': '54 To Potaliya', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/054-to-potaliya.md'}
# {'text': '55 To Jīvaka', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/055-to-jivaka.md'}
# {'text': '56 To Upāli', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/056-to-upali.md'}
# {'text': '57 The Dog-duty Ascetic', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/057-the-dog-duty-ascetic.md'}
# {'text': '58 To Prince Abhaya', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/058-to-prince-abhaya.md'}
# {'text': '59 The Many Kinds of Feeling', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/059-the-many-kinds-of-feeling.md'}
# {'text': '60 The Incontrovertible Teaching', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/060-the-incontrovertible-teaching.md'}
# {'text': '61 Advice to Rāhula at Ambalațṭhikā', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/061-advice-to-rahula-at-ambalatthika.md'}
# {'text': '62 The Greater Discourse of Advice to Rāhula', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/062-the-greater-discourse-of-advice-to-rahula.md'}
# {'text': '63 The Shorter Discourse to Mālunkyāputta', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/063-the-shorter-discourse-to-malunkyaputta.md'}
# {'text': '64 The Greater Discourse to Mālunkyāputta', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/064-the-greater-discourse-to-malunkyaputta.md'}
# {'text': '65 To Bhaddāli', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/065-to-bhaddali.md'}
# {'text': '66 The Simile of the Quail', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/066-the-simile-of-the-quail.md'}
# {'text': '67 At Cātumā', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/067-at-catuma.md'}
# {'text': '68 At Naḷakapāna', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/068-at-nalakapana.md'}
# {'text': '69 Gulissäni', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/069-gulissani.md'}
# {'text': '70 At Kīṭāgiri', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/070-at-kitagiri.md'}
# {'text': '71 To Vacchagotta on the Threefold True Knowledge', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/071-to-vacchagotta-on-the-threefold-true-knowledge.md'}
# {'text': '72 To Vacchagotta on Fire', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/072-to-vacchagotta-on-fire.md'}
# {'text': '73 The Greater Discourse to Vacchagotta', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/073-the-greater-discourse-to-vacchagotta.md'}
# {'text': '74 To Dīghanakha', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/074-to-dighanakha.md'}
# {'text': '75 To Māgandiya', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/075-to-magandiya.md'}
# {'text': '76 To Sandaka', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/076-to-sandaka.md'}
# {'text': '77 The Greater Discourse to Sakuludāyin', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/077-the-greater-discourse-to-sakuludayin.md'}
# {'text': '78 Samaṇamaṇ̣̣ikāputta', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/078-samanamanikaputta.md'}
# {'text': '79 The Shorter Discourse to Sakuludāyin', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/079-the-shorter-discourse-to-sakuludayin.md'}
# {'text': '80 To Vekhanassa', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/080-to-vekhanassa.md'}
# {'text': '81 Ghaṭikāra the Potter', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/081-ghatikara-the-potter.md'}
# {'text': '82 On Raṭthapāla', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/082-on-ratthapala.md'}
# {'text': '83 King Makhādeva', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/083-king-makhadeva.md'}
# {'text': '84 At Madhurā', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/084-at-madhura.md'}
# {'text': '85 To Prince Bodhi', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/085-to-prince-bodhi.md'}
# {'text': '86 On Angulimāla', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/086-on-angulimala.md'}
# {'text': '87 Born from Those Who Are Dear', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/087-born-from-those-who-are-dear.md'}
# {'text': '88 The Cloak', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/088-the-cloak.md'}
# {'text': '89 Monuments to the Dhamma', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/089-monuments-to-the-dhamma.md'}
# {'text': '90 At Kannakatthala', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/090-at-kannakatthala.md'}
# {'text': '91 Brahmāyu', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/091-brahmayu.md'}
# {'text': '92 To Sela', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/092-to-sela.md'}
# {'text': '93 To Assalāyana', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/093-to-assalayana.md'}
# {'text': '94 To Ghotamukha', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/094-to-ghotamukha.md'}
# {'text': '95 With Cankī', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/095-with-canki.md'}
# {'text': '96 To Esukārī', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/096-to-esukari.md'}
# {'text': '97 To Dhānañjāni', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/097-to-dhananjani.md'}
# {'text': '98 To Vāsetṭha', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/098-to-vasettha.md'}
# {'text': '99 To Subha', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/099-to-subha.md'}
# {'text': '100 To Sangārava', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/100-to-sangarava.md'}
# {'text': '101 At Devadaha', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/101-at-devadaha.md'}
# {'text': '102 The Five and Three', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/102-the-five-and-three.md'}
# {'text': '103 What Do You Think About Me?', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/103-what-do-you-think-about-me.md'}
# {'text': '104 At Sāmagāma', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/104-at-samagama.md'}
# {'text': '105 To Sunakkhatta', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/105-to-sunakkhatta.md'}
# {'text': '106 The Way to the Imperturbable', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/106-the-way-to-the-imperturbable.md'}
# {'text': '107 To Gaṇaka Moggallāna', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/107-to-ganaka-moggallana.md'}
# {'text': '108 With Gopaka Moggallāna', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/108-with-gopaka-moggallana.md'}
# {'text': '109 The Greater Discourse on the Full-moon Night', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/109-the-greater-discourse-on-the-full-moon-night.md'}
# {'text': '110 The Shorter Discourse on the Full-moon Night', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/110-the-shorter-discourse-on-the-full-moon-night.md'}
# {'text': '111 One by One As They Occurred', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/111-one-by-one-as-they-occurred.md'}
# {'text': '112 The Sixfold Purity', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/112-the-sixfold-purity.md'}
# {'text': '113 The True Man', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/113-the-true-man.md'}
# {'text': '114 To Be Cultivated and Not To Be Cultivated', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/114-to-be-cultivated-and-not-to-be-cultivated.md'}
# {'text': '115 The Many Kinds of Elements', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/115-the-many-kinds-of-elements.md'}
# {'text': '116 Isigili: The Gullet of the Seers', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/116-isigili-the-gullet-of-the-seers.md'}
# {'text': '117 The Great Forty', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/117-the-great-forty.md'}
# {'text': '118 Mindfulness of Breathing', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/118-mindfulness-of-breathing.md'}
# {'text': '119 Mindfulness of the Body', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/119-mindfulness-of-the-body.md'}
# {'text': '120 Reappearance by Aspiration', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/120-reappearance-by-aspiration.md'}
# {'text': '121 The Shorter Discourse on Voidness', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/121-the-shorter-discourse-on-voidness.md'}
# {'text': '122 The Greater Discourse on Voidness', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/122-the-greater-discourse-on-voidness.md'}
# {'text': '123 Wonderful and Marvellous', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/123-wonderful-and-marvellous.md'}
# {'text': '124 Bakkula', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/124-bakkula.md'}
# {'text': '125 The Grade of the Tamed', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/125-the-grade-of-the-tamed.md'}
# {'text': '126 Bhūmija', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/126-bhumija.md'}
# {'text': '127 Anuruddha', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/127-anuruddha.md'}
# {'text': '128 Imperfections', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/128-imperfections.md'}
# {'text': '129 Fools and Wise Men', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/129-fools-and-wise-men.md'}
# {'text': '130 The Divine Messengers', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/130-the-divine-messengers.md'}
# {'text': '131 One Fortunate Attachment', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/131-one-fortunate-attachment.md'}
# {'text': '132 Ānanda and One Fortunate Attachment', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/132-ananda-and-one-fortunate-attachment.md'}
# {'text': '133 Mahā Kaccāna and One Fortunate Attachment', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/133-maha-kaccana-and-one-fortunate-attachment.md'}
# {'text': '134 Lomasakangiya and One Fortunate Attachment', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/134-lomasakangiya-and-one-fortunate-attachment.md'}
# {'text': '135 The Shorter Exposition of Action', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/135-the-shorter-exposition-of-action.md'}
# {'text': '136 The Greater Exposition of Action', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/136-the-greater-exposition-of-action.md'}
# {'text': '137 The Exposition of the Sixfold Base', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/137-the-exposition-of-the-sixfold-base.md'}
# {'text': '138 The Exposition of a Summary', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/138-the-exposition-of-a-summary.md'}
# {'text': '139 The Exposition of Non-Conflict', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/139-the-exposition-of-non-conflict.md'}
# {'text': '140 The Exposition of the Elements', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/140-the-exposition-of-the-elements.md'}
# {'text': '141 The Exposition of the Truths', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/141-the-exposition-of-the-truths.md'}
# {'text': '142 The Exposition of Offerings', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/142-the-exposition-of-offerings.md'}
# {'text': '143 Advice to Anāthapiṇ̣ika', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/143-advice-to-anathapinika.md'}
# {'text': '144 Advice to Channa', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/144-advice-to-channa.md'}
# {'text': '145 Advice to Punna', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/145-advice-to-punna.md'}
# {'text': '146 Advice from Nandaka', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/146-advice-from-nandaka.md'}
# {'text': '147 The Shorter Discourse of Advice to Rāhula', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/147-the-shorter-discourse-of-advice-to-rahula.md'}
# {'text': '148 The Six Sets of Six', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/148-the-six-sets-of-six.md'}
# {'text': '149 The Great Sixfold Base', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/149-the-great-sixfold-base.md'}
# {'text': '150 To the Nagaravindans', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/150-to-the-nagaravindans.md'}
# {'text': '151 The Purification of Almsfood', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/151-the-purification-of-almsfood.md'}
# {'text': '152 The Development of the Faculties', 'link': '../kinhtrungbo/nanamoli-bodhi-vi/152-the-development-of-the-faculties.md'}
# Warning: No title found in mucluc.md
# Successfully generated filelist.js in ../kinhtrungbo/nanamoli-bodhi-vi
# Successfully generated mucluc.md in ../kinhtrungbo/nanamoli-bodhi-vi
