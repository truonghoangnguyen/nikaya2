# %%
import os
import re

def remove_frontmatter(directory):
    """
    Removes frontmatter from files in the given directory.

    Args:
        directory (str): The directory containing the files to process.
    """
    for filename in os.listdir(directory):
        if filename.endswith(".md"):
            filepath = os.path.join(directory, filename)
            with open(filepath, "r+") as f:
                content = f.read()

                # Define the regex pattern for the frontmatter
                pattern = re.compile(
                    r"^---\s*title:\s*\"[^\"]*\"\s*prev:\s*[^\n]*\s*next:\s*[^\n]*\s*---\s*\n*",
                    re.MULTILINE
                )

                # Check if the content matches the pattern
                match = pattern.match(content)
                if match:
                    # print(f"Removing frontmatter from {match[0]}")
                    # Remove the frontmatter
                    new_content = content[match.end():]

                    # Write the new content back to the file
                    f.seek(0)
                    f.write(new_content)
                    f.truncate()  # Remove any remaining characters after the new content

# Example usage:
directory_path = "../docs/kinhtrungbo/nanamoli-bodhi"  # Replace with the actual path
remove_frontmatter(directory_path)

# %%
# đổi tên file từ 1.md -> 001-tat-ca-caclauh...md
# import md
import re
import unidecode

def slugify(text):
    text = unidecode.unidecode(text).lower()
    return re.sub(r'[\W_]+', '-', text)

def format_number(s):
    parts = s.split(". ", 1)
    if len(parts) != 2:
        return s
    number_str = parts[0]
    try:
        number = int(number_str)
        formatted_number = "{:03d}".format(number)
        return formatted_number + ". " + parts[1]
    except ValueError:
        return s
def remove_trailing_hyphen(s):
    if s.endswith("-"):
        return s[:-1]
    return s
def generate_slug(directory):
    """
    Generates slugs for markdown files in the given directory.

    Args:
        directory (str): The directory containing the markdown files.

    Returns:
        dict: A dictionary mapping original filenames to new filenames.
    """
    filename_mapping = {}
    for filename in os.listdir(directory):

        match = re.match(r"^(\d+)\.md$", filename)
        if match:

            filepath = os.path.join(directory, filename)
            with open(filepath, "r") as f:
                content = f.read()
                title_match = re.search(r"^#\s+(.+)$", content, re.MULTILINE)
                if title_match:
                    title = title_match.group(1).strip()
                    title = format_number(title)
                    # padded_number = str(number).zfill(3)
                    slug = remove_trailing_hyphen(slugify(title.lower()))
                    new_filename = f"{slug}.md"
                    filename_mapping[filename] = new_filename
    return filename_mapping

# Example usage:
directory_path = "../kinhtrungbo/nanamoli-bodhi"  # Replace with the actual path
filename_mapping = generate_slug(directory_path)

print(filename_mapping)
# Out:
# {'1.md': 'the-root-of-all-things.md', '2.md': '002-all-the-taints.md'}

# %%
def rename_files(directory, name_map):
    """
    Renames files in a directory based on a dictionary mapping old names to new names.

    Args:
        directory (str): The absolute path to the directory containing the files to rename.
        name_map (dict): A dictionary where keys are the old filenames and values are the new filenames.
    """

    for old_name, new_name in name_map.items():
        old_path = os.path.join(directory, old_name)
        new_path = os.path.join(directory, new_name)

        try:
            if os.path.exists(old_path):
                os.rename(old_path, new_path)
                print(f"Renamed '{old_name}' to '{new_name}'")
            else:
                print(f"File not found: '{old_name}'")
        except Exception as e:
            print(f"Error renaming '{old_name}': {e}")

rename_files(directory_path , filename_mapping)
# Out:
# Renamed '28.md' to '028-greater-discourse-on-the-simile-of-the-elephant-s-footprint.md'
# Renamed '79.md' to '079-lesser-discourse-to-sakuludayin.md'
# Renamed '124.md' to '124-discourse-by-bakkula.md'
# Renamed '141.md' to '141-discourse-on-the-analysis-of-the-truths.md'
# Renamed '110.md' to '110-lesser-discourse-at-the-time-of-a-full-moon.md'
# Renamed '100.md' to '100-discourse-with-sangarava.md'
# Renamed '151.md' to '151-discourse-on-complete-purity-for-alms-gathering.md'
# Renamed '134.md' to '134-lomasakangiya-s-discourse-on-the-auspicious.md'
# Renamed '5.md' to '005-discourse-on-no-blemishes.md'
# Renamed '69.md' to '069-discourse-on-gulissani.md'
# Renamed '38.md' to '038-greater-discourse-on-the-destruction-of-craving.md'
# Renamed '18.md' to '018-discourse-of-the-honey-ball.md'
# Renamed '49.md' to '049-discourse-on-a-challenge-to-a-brahma.md'
# Renamed '114.md' to '114-discourse-on-what-is-to-be-followed-and-what-is-not-to-be-followed.md'
# Renamed '145.md' to '145-discourse-on-an-exhortation-to-punna.md'
# Renamed '120.md' to '120-discourse-on-uprising-by-means-of.md'
# Renamed '130.md' to '130-discourse-on-the-deva-messengers-1.md'
# Renamed '104.md' to '104-discourse-at-samagama.md'
# Renamed '59.md' to '059-discourse-on-much-to-be-experienced.md'
# Renamed '19.md' to '019-discourse-on-the-twofold-thought.md'
# Renamed '48.md' to '048-discourse-at-kosambi-1.md'
# Renamed '115.md' to '115-discourse-on-the-manifold-elements.md'
# Renamed '144.md' to '144-discourse-on-an-exhortation-to-channa.md'
# Renamed '121.md' to '121-the-lesser-discourse-on-emptiness.md'
# Renamed '131.md' to '131-discourse-on-the-auspicious-1.md'
# Renamed '105.md' to '105-discourse-to-sunakkhatta.md'
# Renamed '58.md' to '058-discourse-to-abhaya.md'
# Renamed '29.md' to '029-greater-discourse-on-the-simile-of-the-pith.md'
# Renamed '78.md' to '078-discourse-to-samanamandika-s-son.md'
# Renamed '125.md' to '125-the-discourse-on-the-tamed-stage.md'
# Renamed '140.md' to '140-discourse-on-the-analysis-of-the-elements.md'
# Renamed '111.md' to '111-discourse-on-the-uninterrupted.md'
# Renamed '101.md' to '101-discourse-at-devadaha.md'
# Renamed '150.md' to '150-discourse-to-the-people-of-nagaravinda.md'
# Renamed '135.md' to '135-discourse-on-the-lesser-analysis-of-deeds.md'
# Renamed '4.md' to '004-discourse-on-fear-and-dread.md'
# Renamed '68.md' to '068-discourse-at-nalakapana.md'
# Renamed '39.md' to '039-greater-discourse-at-assapura.md'
# Renamed '47.md' to '047-discourse-on-inquiring.md'
# Renamed '16.md' to '016-discourse-on-mental-barrenness-1.md'
# Renamed '80.md' to '080-discourse-to-vekhanassa.md'
# Renamed '22.md' to '022-discourse-on-the-parable-of-the-water-snake.md'
# Renamed '73.md' to '073-greater-discourse-to-vacchagotta.md'
# Renamed '63.md' to '063-lesser-discourse-to-malunkya-putta.md'
# Renamed '32.md' to '032-greater-discourse-in-gosinga.md'
# Renamed '90.md' to '090-discourse-at-kannakatthala.md'
# Renamed '57.md' to '057-discourse-on-the-canine-ascetic.md'
# Renamed '84.md' to '084-discourse-at-madhura.md'
# Renamed '77.md' to '077-greater-discourse-to-sakuludayin.md'
# Renamed '26.md' to '026-discourse-on-the-ariyan-quest.md'
# Renamed '12.md' to '012-greater-discourse-on-the-lion-s-roar.md'
# Renamed '43.md' to '043-greater-discourse-of-the-miscellany.md'
# Renamed '53.md' to '053-discourse-for-learners.md'
# Renamed '36.md' to '036-greater-discourse-to-saccaka.md'
# Renamed '67.md' to '067-discourse-at-catuma.md'
# Renamed '94.md' to '094-discourse-with-ghotamukha.md'
# Renamed '85.md' to '085-discourse-to-prince-bodhi.md'
# Renamed '76.md' to '076-discourse-to-sandaka.md'
# Renamed '27.md' to '027-lesser-discourse-on-the-simile-of-the-elephant-s-footprint.md'
# Renamed '13.md' to '013-greater-discourse-on-the-stems-of-anguish.md'
# Renamed '42.md' to '042-discourse-to-the-people-of-veranja.md'
# Renamed '52.md' to '052-discourse-to-a-citizen-of-atthaka.md'
# Renamed '37.md' to '037-lesser-discourse-on-the-destruction-of-craving.md'
# Renamed '66.md' to '066-discourse-on-the-simile-of-the-quail.md'
# Renamed '95.md' to '095-discourse-with-canki-1.md'
# Renamed '46.md' to '046-greater-discourse-on-the-ways-of-undertaking-dhamma.md'
# Renamed '81.md' to '081-discourse-on-ghatikara.md'
# Renamed '23.md' to '023-discourse-on-the-anthill.md'
# Renamed '72.md' to '072-discourse-to-vacchagotta-on-fire.md'
# Renamed '62.md' to '062-greater-discourse-on-an-exhortation-to-rahula.md'
# Renamed '33.md' to '033-greater-discourse-on-the-cowherd.md'
# Renamed '91.md' to '091-discourse-with-brahmayu.md'
# Renamed '56.md' to '056-discourse-with-upali.md'
# Renamed '128.md' to '128-the-discourse-on-defilements.md'
# Renamed '24.md' to '024-discourse-on-the-relays-of-chariots.md'
# Renamed '86.md' to '086-discourse-with-angulimala.md'
# Renamed '41.md' to '041-discourse-to-the-people-of-sala.md'
# Renamed '10.md' to '010-discourse-on-the-applications-of-mindfulness.md'
# Renamed '51.md' to '051-discourse-to-kandaraka-1.md'
# Renamed '9.md' to '009-discourse-on-perfect-view.md'
# Renamed '96.md' to '096-discourse-with-esukari.md'
# Renamed '65.md' to '065-discourse-to-bhaddali.md'
# Renamed '34.md' to '034-lesser-discourse-on-the-cowherd.md'
# Renamed '138.md' to '138-discourse-on-an-exposition-and-analysis.md'
# Renamed '118.md' to '118-discourse-on-mindfulness-when-breathing-in-and-out.md'
# Renamed '149.md' to '149-discourse-pertaining-to-the-great-sixfold-sense-field.md'
# Renamed '14.md' to '014-lesser-discourse-on-the-stems-of-anguish.md'
# Renamed '45.md' to '045-lesser-discourse-on-the-ways-of-undertaking-dhamma.md'
# Renamed '71.md' to '071-discourse-to-vacchagotta-on-the-threefold-knowledge.md'
# Renamed '20.md' to '020-discourse-on-the-forms-of-thought.md'
# Renamed '82.md' to '082-discourse-with-ratthapala.md'
# Renamed '92.md' to '092-discourse-with-sela.md'
# Renamed '30.md' to '030-lesser-discourse-on-the-simile-of-the-pith.md'
# Renamed '61.md' to '061-discourse-on-an-exhortation-to-rahula-at-ambalatthika.md'
# Renamed '55.md' to '055-discourse-to-jivaka.md'
# Renamed '108.md' to '108-the-discourse-to-ganaka-moggallana.md'
# Renamed '119.md' to '119-discourse-on-mindfulness-of-body-1.md'
# Renamed '148.md' to '148-discourse-on-the-six-sixes.md'
# Renamed '15.md' to '015-discourse-on-measuring-in-accordance-with.md'
# Renamed '44.md' to '044-lesser-discourse-of-the-miscellany.md'
# Renamed '70.md' to '070-discourse-at-kitagiri.md'
# Renamed '21.md' to '021-discourse-on-the-parable-of-the-saw.md'
# Renamed '83.md' to '083-discourse-on-makhadeva-1.md'
# Renamed '93.md' to '093-discourse-with-assalayana.md'
# Renamed '31.md' to '031-lesser-discourse-in-gosinga.md'
# Renamed '60.md' to '060-discourse-on-the-sure.md'
# Renamed '54.md' to '054-discourse-to-potaliya.md'
# Renamed '109.md' to '109-greater-discourse-at-the-time-of-a-full.md'
# Renamed '129.md' to '129-discourse-on-fools-and-the-wise.md'
# Renamed '25.md' to '025-discourse-on-crops.md'
# Renamed '74.md' to '074-discourse-to-magandiya.md'
# Renamed '87.md' to '087-discourse-on-born-of-affection.md'
# Renamed '40.md' to '040-lesser-discourse-at-assapura.md'
# Renamed '11.md' to '011-lesser-discourse-on-the-lion-s-roar.md'
# Renamed '50.md' to '050-discourse-on-a-rebuke-to-mara.md'
# Renamed '8.md' to '008-discourse-on-expunging.md'
# Renamed '97.md' to '097-discourse-with-dhananjani.md'
# Renamed '64.md' to '064-greater-discourse-to-malunkya-putta.md'
# Renamed '35.md' to '035-lesser-discourse-to-saccaka.md'
# Renamed '139.md' to '139-discourse-on-the-analysis-of-the.md'
# Renamed '147.md' to '147-discourse-on-an-exhortation-to-rahula.md'
# Renamed '116.md' to '116-discourse-at-isigili.md'
# Renamed '122.md' to '122-the-greater-discourse-on-emptiness.md'
# Renamed '132.md' to '132-ananda-s-discourse-on-the-auspicious.md'
# Renamed '106.md' to '106-discourse-on-beneficial-imperturbability.md'
# Renamed '3.md' to '003-discourse-on-heirs-of-dhamma.md'
# Renamed '88.md' to '088-discourse-on-the-foreign-cloth.md'
# Renamed '126.md' to '126-discourse-to-bhumija.md'
# Renamed '112.md' to '112-discourse-on-the-sixfold-cleansing.md'
# Renamed '143.md' to '143-discourse-on-an-exhortation-to-anathapindika.md'
# Renamed '102.md' to '102-discourse-on-the-threefold-five-1.md'
# Renamed '136.md' to '136-discourse-on-the-greater-analysis-of.md'
# Renamed '98.md' to '098-discourse-to-vasettha.md'
# Renamed '7.md' to '007-discourse-on-the-simile-of-the-cloth.md'
# Renamed '89.md' to '089-discourse-on-testimonies-to-dhamma.md'
# Renamed '127.md' to '127-discourse-with-anuruddha.md'
# Renamed '113.md' to '113-discourse-on-the-good-man.md'
# Renamed '142.md' to '142-discourse-on-the-analysis-of-offerings.md'
# Renamed '152.md' to '152-discourse.md'
# Renamed '103.md' to '103-discourse-on-what-then.md'
# Renamed '137.md' to '137-discourse-on-the-analysis-of-the-sixfold-sense-field.md'
# Renamed '99.md' to '099-discourse-with-subha.md'
# Renamed '6.md' to '006-discourse-on-what-one-may-wish.md'
# Renamed '146.md' to '146-discourse-on-an-exhortation-from-nandaka.md'
# Renamed '117.md' to '117-discourse-pertaining-to-the-great-forty.md'
# Renamed '123.md' to '123-discourse-on-wonderful-and-marvellous-qualities.md'
# Renamed '133.md' to '133-maha-kaccana-s-discourse-on-the-auspicious.md'
# Renamed '107.md' to '107-the-discourse-to-ganaka-moggallana.md'
# Renamed '2.md' to '002-discourse-on-all-the-cankers.md'
