# %%
import os

BASE_URL = "https://kinhnikaya.org"
DOCS_ROOT = os.path.join(os.path.dirname(os.getcwd()), "docs")  # adjust if needed

folders = [
    "docs/kinhtruongbo/sujato-vi",
]

results = []

for folder in folders:
    abs_folder = os.path.join(os.path.dirname(os.getcwd()), folder)
    if not os.path.isdir(abs_folder):
        print(f"[skip] not found: {abs_folder}")
        continue
    for fname in sorted(os.listdir(abs_folder)):
        if not fname.endswith(".md"):
            continue
        # strip docs/ prefix and .md suffix, build URL path
        rel = os.path.join(folder, fname)          # e.g. docs/kinhtruongbo/.../dn-001.md
        url_path = rel.removeprefix("docs/").removesuffix(".md")  # kinhtruongbo/.../dn-001
        url = f"{BASE_URL}/{url_path}#chapter"
        results.append(f'{{ "@id": "{url}" }}')

print("\n".join(results))
# Out:
# { "@id": "https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-001-the-divine-net-brahmajalasutta#chapter" }
# { "@id": "https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-002-the-fruits-of-the-ascetic-life-samannaphalasutta#chapter" }
# { "@id": "https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-003-with-ambattha-ambatthasutta#chapter" }
# { "@id": "https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-004-with-sonadanda-sonadandasutta#chapter" }
# { "@id": "https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-005-with-kutadanta-kutadantasutta#chapter" }
# { "@id": "https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-006-with-mahali-mahalisutta#chapter" }
# { "@id": "https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-007-with-jaliya-jaliyasutta#chapter" }
# { "@id": "https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-008-the-lion-s-roar-to-the-naked-ascetic-kassapa-mahasihanadasutta#chapter" }
# { "@id": "https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-009-with-potthapada-potthapadasutta#chapter" }
# { "@id": "https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-010-with-subha-subhasutta#chapter" }
# { "@id": "https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-011-with-kevaddha-kevattasutta#chapter" }
# { "@id": "https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-012-with-lohicca-lohiccasutta#chapter" }
# { "@id": "https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-013-experts-in-the-three-vedas-tevijjasutta#chapter" }
# { "@id": "https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-014-the-great-discourse-on-traces-left-behind#chapter" }
# { "@id": "https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-015-the-great-discourse-on-causation#chapter" }
# { "@id": "https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-016-the-great-discourse-on-the-buddha-s-extinguishment#chapter" }
# { "@id": "https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-017-king-mahasudassana#chapter" }
# { "@id": "https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-018-with-janavasabha#chapter" }
# { "@id": "https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-019-the-great-steward#chapter" }
# { "@id": "https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-020-the-great-congregation#chapter" }
# { "@id": "https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-021-sakka-s-questions#chapter" }
# { "@id": "https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-022-the-longer-discourse-on-mindfulness-meditation#chapter" }
# { "@id": "https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-023-with-payasi#chapter" }
# { "@id": "https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-024-about-patikaputta-pathikasutta#chapter" }
# { "@id": "https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-025-the-lion-s-roar-at-the-monastery-of-lady-udumbarika-udumbarikasutta#chapter" }
# { "@id": "https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-026-the-wheel-turning-monarch-cakkavattisutta#chapter" }
# { "@id": "https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-027-what-came-first-aggannasutta#chapter" }
# { "@id": "https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-028-inspiring-confidence-sampasadaniyasutta#chapter" }
# { "@id": "https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-029-an-impressive-discourse-pasadikasutta#chapter" }
# { "@id": "https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-030-the-marks-of-a-great-man-lakkhanasutta#chapter" }
# { "@id": "https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-031-advice-to-sigalaka-singalasutta#chapter" }
# { "@id": "https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-032-the-atanatiya-protection-atanatiyasutta#chapter" }
# { "@id": "https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-033-reciting-in-concert-sangitisutta#chapter" }
# { "@id": "https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-034-up-to-ten-dasuttarasutta#chapter" }
# { "@id": "https://kinhnikaya.org/kinhtruongbo/sujato-vi/index#chapter" }
