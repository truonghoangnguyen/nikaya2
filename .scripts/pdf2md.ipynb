# %%
import pymupdf4llm
md_text = pymupdf4llm.to_markdown("../.docsource/truongbokinh.pdf")
# Out:
# Processing ../.docsource/truongbokinh.pdf...
# [                                        ] (0/46[                                        ] (  1/46[                                        ] (  2/46[                                        ] (  3/46[                                        ] (  4/46[                                        ] (  5/46[                                        ] (  6/46[                                        ] (  7/46[                                        ] (  8/46[                                        ] (  9/46[                                        ] ( 10/46[                                        ] ( 11/466[=                                       ] ( 12/4[=                                       ] ( 13/4[=                                       ] ( 14/4[=                                       ] ( 15/4[=                                       ] ( 16/4[=                                       ] ( 17/4[=                                       ] ( 18/4[=                                       ] ( 19/4[=                                       ] ( 20/4[=                                       ] ( 21/4[=                                       ] ( 22/4[=                                       ] ( 23/46[==                                      ] ( 24/46[==                                      ] ( 25/46[==                                      ] ( 26/46[==                                      ] ( 27/46[==                                      ] ( 28/46[==                                      ] ( 29/46[==                                      ] ( 30/46[==                                      ] ( 31/46[==                                      ] ( 32/46[==                                      ] ( 33/46[==                                      ] ( 34/466[===                                     ] ( 35/466[===                                     ] ( 36/466[===                                     ] ( 37/4[===                                     ] ( 38/4[===                                     ] ( 39/4[===                                     ] ( 40/466[===                                     ] ( 41/466[===                                     ] ( 42/466[===                                     ] ( 43/466[===                                     ] ( 44/466[===                                     ] ( 45/466[===                                     ] ( 46/46[====                                    ] ( 47/46[====                                    ] ( 48/46[====                                    ] ( 49/46[====                                    ] ( 50/46[====                                    ] ( 51/46[====                                    ] ( 52/46[====                                    ] ( 53/46[====                                    ] ( 54/46[====                                    ] ( 55/46[====                                    ] ( 56/46[====                                    ] ( 57/46[====                                    ] ( 58/466[=====                                   ] ( 59/466[=====                                   ] ( 60/466[=====                                   ] ( 61/466[=====                                   ] ( 62/466[=====                                   ] ( 63/466[=====                                   ] ( 64/466[=====                                   ] ( 65/466[=====                                   ] ( 66/466[=====                                   ] ( 67/4[=====                                   ] ( 68/466[=====                                   ] ( 69/46[======                                  ] ( 70/46[======                                  ] ( 71/46[======                                  ] ( 72/46[======                                  ] ( 73/46[======                                  ] ( 74/46[======                                  ] ( 75/46[======                                  ] ( 76/46[======                                  ] ( 77/46[======                                  ] ( 78/46[======                                  ] ( 79 ...

# %%
import pathlib
pathlib.Path("output/kinhtruongbo.md").write_bytes(md_text.encode())
# Out:
# 1845901

# %% [markdown]
# bây giờ clear text, dùng tay để clean

# %%
# -*- coding: utf-8 -*-
# Import các thư viện cần thiết
import re
import os
from slugify import slugify # Thư viện để tạo slug thân thiện với URL/tên file

# --- Cấu hình ---
input_file = 'output/kinhtruongbo.md' # Tên file markdown nguồn
output_dir = 'output/kinhtruongbo/'       # Thư mục để lưu các file đã chia
encoding = 'utf-8'               # Encoding của file
number_padding = 3               # Số ký tự cho phần số (vd: 3 -> 001, 024)

# --- Logic xử lý ---

# Tạo thư mục output nếu chưa tồn tại
os.makedirs(output_dir, exist_ok=True)
print(f"Thư mục output: '{output_dir}'")

# Biến để lưu trữ file đang ghi và nội dung
current_file_handle = None
current_filename = None
file_count = 0

# Biểu thức chính quy để tìm dòng tiêu đề bài kinh
# ####\s+(\d+)\.\s+(.*)
# - ^####: Bắt đầu bằng ####
# - \s+: Theo sau bởi một hoặc nhiều khoảng trắng
# - (\d+): Nhóm 1: Một hoặc nhiều chữ số (số thứ tự bài kinh)
# - \.: Dấu chấm literal
# - \s+: Theo sau bởi một hoặc nhiều khoảng trắng
# - (.*): Nhóm 2: Bất kỳ ký tự nào cho đến cuối dòng (tên bài kinh)
pattern = re.compile(r'^####\s+(\d+)\.\s+(.*)', re.IGNORECASE)

try:
    with open(input_file, 'r', encoding=encoding) as infile:
        print(f"Đang đọc file: '{input_file}'...")
        for line in infile:
            match = pattern.match(line)
            if match:
                # Nếu tìm thấy dòng tiêu đề mới
                file_count += 1

                # Đóng file cũ nếu đang mở
                if current_file_handle:
                    current_file_handle.close()
                    print(f" -> Đã ghi xong: '{current_filename}'")

                # Lấy thông tin từ kết quả khớp regex
                kinh_num_str = match.group(1)
                kinh_title_raw = match.group(2).strip()

                # Tạo tên file slug
                padded_num = kinh_num_str.zfill(number_padding)
                slug_title = slugify(kinh_title_raw)
                filename = f"{padded_num}-{slug_title}.md"
                filepath = os.path.join(output_dir, filename)

                # Mở file mới để ghi
                print(f"\n{file_count}. Tìm thấy bài kinh: '{kinh_title_raw}' - Đang tạo file: '{filename}'...", end='')
                current_filename = filename
                current_file_handle = open(filepath, 'w', encoding=encoding)

            # Ghi dòng hiện tại vào file đang mở (nếu có)
            if current_file_handle:
                current_file_handle.write(line)

    # Đóng file cuối cùng sau khi kết thúc vòng lặp
    if current_file_handle:
        current_file_handle.close()
        print(f" -> Đã ghi xong: '{current_filename}'")

    print(f"\nHoàn tất! Đã chia thành công {file_count} file trong thư mục '{output_dir}'.")

except FileNotFoundError:
    print(f"Lỗi: Không tìm thấy file '{input_file}'. Vui lòng kiểm tra lại tên file và đường dẫn.")
except Exception as e:
    print(f"Đã xảy ra lỗi không mong muốn: {e}")
    # Đảm bảo đóng file nếu có lỗi xảy ra giữa chừng
    if current_file_handle and not current_file_handle.closed:
        current_file_handle.close()
        print(f"Đã đóng file '{current_filename}' do lỗi.")
# Out:
# Thư mục output: 'output/kinhtruongbo/'
# Đang đọc file: 'output/kinhtruongbo.md'...
#
# 1. Tìm thấy bài kinh: 'KINH PHẠM VÕNG' - Đang tạo file: '001-kinh-pham-vong.md'... -> Đã ghi xong: '001-kinh-pham-vong.md'
#
# 2. Tìm thấy bài kinh: 'KINH SA MÔN QỦA' - Đang tạo file: '002-kinh-sa-mon-qua.md'... -> Đã ghi xong: '002-kinh-sa-mon-qua.md'
#
# 3. Tìm thấy bài kinh: 'KINH AMBATTHA (A-MA-TRÚ)' - Đang tạo file: '003-kinh-ambattha-a-ma-tru.md'... -> Đã ghi xong: '003-kinh-ambattha-a-ma-tru.md'
#
# 4. Tìm thấy bài kinh: 'KINH SONADANDA (CHỦNG ÐỨC)' - Đang tạo file: '004-kinh-sonadanda-chung-duc.md'... -> Đã ghi xong: '004-kinh-sonadanda-chung-duc.md'
#
# 5. Tìm thấy bài kinh: 'KINH KÙTADANTA (CỨU-LA-ÐÀN-ÐẦU)' - Đang tạo file: '005-kinh-kutadanta-cuu-la-dan-dau.md'... -> Đã ghi xong: '005-kinh-kutadanta-cuu-la-dan-dau.md'
#
# 6. Tìm thấy bài kinh: 'KINH MAHÀLI' - Đang tạo file: '006-kinh-mahali.md'... -> Đã ghi xong: '006-kinh-mahali.md'
#
# 7. Tìm thấy bài kinh: 'KINH JÀLIYA' - Đang tạo file: '007-kinh-jaliya.md'... -> Đã ghi xong: '007-kinh-jaliya.md'
#
# 8. Tìm thấy bài kinh: 'KINH CA-DIẾP SƯ TỬ HỐNG' - Đang tạo file: '008-kinh-ca-diep-su-tu-hong.md'... -> Đã ghi xong: '008-kinh-ca-diep-su-tu-hong.md'
#
# 9. Tìm thấy bài kinh: 'KINH POTTHAPÀDA (BỐ-SÁ-BÀ-LÂU)' - Đang tạo file: '009-kinh-potthapada-bo-sa-ba-lau.md'... -> Đã ghi xong: '009-kinh-potthapada-bo-sa-ba-lau.md'
#
# 10. Tìm thấy bài kinh: 'KINH SUBHA (TU-BÀ)' - Đang tạo file: '010-kinh-subha-tu-ba.md'... -> Đã ghi xong: '010-kinh-subha-tu-ba.md'
#
# 11. Tìm thấy bài kinh: 'KINH KEVADDHA (KIÊN CỐ)' - Đang tạo file: '011-kinh-kevaddha-kien-co.md'... -> Đã ghi xong: '011-kinh-kevaddha-kien-co.md'
#
# 12. Tìm thấy bài kinh: 'KINH LOHICCA (LÔ-HI-GIA)' - Đang tạo file: '012-kinh-lohicca-lo-hi-gia.md'... -> Đã ghi xong: '012-kinh-lohicca-lo-hi-gia.md'
#
# 13. Tìm thấy bài kinh: 'KINH TEVIJJA (TAM MINH)' - Đang tạo file: '013-kinh-tevijja-tam-minh.md'... -> Đã ghi xong: '013-kinh-tevijja-tam-minh.md'
#
# 14. Tìm thấy bài kinh: 'KINH ÐẠI BỔN' - Đang tạo file: '014-kinh-dai-bon.md'... -> Đã ghi xong: '014-kinh-dai-bon.md'
#
# 15. Tìm thấy bài kinh: 'KINH ÐẠI DUYÊN' - Đang tạo file: '015-kinh-dai-duyen.md'... -> Đã ghi xong: '015-kinh-dai-duyen.md'
#
# 16. Tìm thấy bài kinh: 'KINH ÐẠI BÁT NIẾT BÀN' - Đang tạo file: '016-kinh-dai-bat-niet-ban.md'... -> Đã ghi xong: '016-kinh-dai-bat-niet-ban.md'
#
# 17. Tìm thấy bài kinh: 'KINH ÐẠI THIỆN KIẾN VƯƠNG' - Đang tạo file: '017-kinh-dai-thien-kien-vuong.md'... -> Đã ghi xong: '017-kinh-dai-thien-kien-vuong.md'
#
# 18. Tìm thấy bài kinh: 'KINH XA-NI-SA' - Đang tạo file: '018-kinh-xa-ni-sa.md'... -> Đã ghi xong: '018-kinh-xa-ni-sa.md'
#
# 19. Tìm thấy bài kinh: 'KINH ÐẠI ÐIỂN TÔN' - Đang tạo file: '019-kinh-dai-dien-ton.md'... -> Đã ghi xong: '019-kinh-dai-dien-ton.md'
#
# 20. Tìm thấy bài kinh: 'KINH ÐẠI HỘI' - Đang tạo file: '020-kinh-dai-hoi.md'... -> Đã ghi xong: '020-kinh-dai-hoi.md'
#
# 21. Tìm thấy bài kinh: 'KINH ÐẾ-THÍCH SỞ VẤN' - Đang tạo file: '021-kinh-de-thich-so-van.md'... -> Đã ghi xong: '021-kinh-de-thich-so-van.md'
#
# 22. Tìm thấy bài kinh: 'KINH ÐẠI NIỆM XỨ' - Đang tạo file: '022-kinh-dai-niem-xu.md'... -> Đã ghi xong: '022-kinh-dai-niem-xu.md'
#
# 23. Tìm thấy bài kinh: 'KINH TỆ-TÚC' - Đang tạo file: '023-kinh-te-tuc.md'... -> Đã ghi xong: '023-kinh-te-tuc.md'
#
# 24. Tìm thấy bài kinh: 'KINH BA-LÊ' - Đang tạo file: '024-kinh-ba-le.md'... -> Đã ghi xong: '024-kinh-ba-le.md'
#
# 25. Tìm thấy bài kinh: 'KINH ƯU-ÐÀM-BÀ-LA SƯ TỬ HỐNG' - Đang tạo file: '025-kinh-uu-dam-ba-la-su-tu-hong.md'... -> Đã ghi xong: '025-kinh-uu-dam-ba-la-su-tu-hong.md'
#
# 26. Tìm thấy bài kinh: 'KINH CHUYỂN LUÂN THÁNH VƯƠNG SƯ TỬ HỐNG' - Đang tạo file: '026-kinh-chuyen-luan-thanh-vuong-su-tu-hong.md'... -> Đã ghi xong: '026-kinh-chuyen-luan-thanh-vuong-su-tu-hong.md'
#
# 27. Tìm thấy bài kinh: 'KINH KHỞI THẾ NHÂN BỔN' - Đang tạo file: '027-kinh-khoi-the-nhan-bon.md'... -> Đã ghi xong: '027-kinh-khoi-the-nhan-bon.md'
#
# 28. Tìm thấy bài kinh: 'KINH TỰ HOAN HỶ' - Đang tạo file: '028-kinh-tu-hoan-hy.md'... -> Đã ghi xong: '028-kinh-tu-hoan-hy.md'
#
# 29. Tìm thấy bài kinh: 'KINH THANH TỊNH' - Đang tạo file: '029-kinh-thanh-tinh.md'... -> Đã ghi xong: '029-kinh-thanh-tinh.md'
#
# 30. Tìm thấy bài kinh: 'KINH TƯỚNG' - Đang tạo file: '030-kinh-tuong.md'... -> Đã ghi xong: '030-kinh-tuong.md'
#
# 31. Tìm thấy bài kinh: 'KINH GIÁO THỌ THI-CA-LA-VIỆT' - Đang tạo file: '031-kinh-giao-tho-thi-ca-la-viet.md'... -> Đã ghi xong: '031-kinh-giao-tho-thi-ca-la-viet.md'
#
# 32. Tìm thấy bài kinh: 'KINH A-SÁ-NANG-CHI' - Đang tạo file: '032-kinh-a-sa-nang-chi.md'... -> Đã ghi xong: '032-kinh-a-sa-nang-chi.md'
#
# 33. Tìm thấy bài kinh: 'KINH PHÚNG TỤNG' - Đang tạo file: '033-kinh-phung-tung.md'... -> Đã ghi xong: '033-kinh-phung-tung.md'
#
# 34. Tìm thấy bài kinh: 'KINH THẬP THƯỢNG' - Đang tạo file: '034-kinh-thap-thuong.md'... -> Đã ghi xong: '034-kinh-thap-thuong.md'
#
# Hoàn tất! Đã chia thành công 34 file trong thư mục 'output/kinhtruongbo/'.

# %% [markdown]
# Vào tạo filelist 1make_filelist.ipynb
