# %%
# change sujato paragraph ####3 -> 3.
import sys
import re
import os

def process_markdown_headers(input_filepath, output_filepath):
    """
    Reads a markdown file, finds lines starting with '#### <number/range> ',
    and replaces them with r'<number/range>. <rest of line>'.
    Handles cases where the content is on the same line or the next non-blank line.

    Args:
        input_filepath (str): The path to the input markdown file.
        output_filepath (str): The path where the modified content will be saved.
    """
    # Regex explanation:
    # ^####          - Matches the start of the line followed by '#### '
    # (\d+(--\d+)?) - Group 1: Captures one or more digits (\d+), optionally followed by
    #                '--' and one or more digits (--\d+). This captures the number or range.
    # \s*            - Matches zero or more whitespace characters after the number/range.
    # (.*)           - Group 3: Captures the rest of the line after the whitespace.
    # $              - Matches the end of the line.
    # This regex captures both "#### 98" (where rest_of_line is empty)
    # and "#### 101 Text" (where rest_of_line is "Text").
    header_pattern = re.compile(r'^#### (\d+(--\d+)?)\s*(.*)$')

    pending_number = None # Use a state variable to remember the number from a #### line

    try:
        # Ensure the directory for the output file exists
        output_dir = os.path.dirname(output_filepath)
        if output_dir and not os.path.exists(output_dir):
            os.makedirs(output_dir)

        with open(input_filepath, 'r', encoding='utf-8') as infile, \
             open(output_filepath, 'w', encoding='utf-8') as outfile:

            for line in infile:
                # If we are currently waiting for the content after a #### line
                if pending_number is not None:
                    stripped_line = line.strip()
                    if stripped_line:
                        # This is the first non-blank line after the ####
                        # Combine the pending number and the content
                        # Use \\. to ensure a literal period is outputted in markdown
                        new_line = f"{pending_number}\\. {stripped_line}\n"
                        outfile.write(new_line)
                        pending_number = None # Reset the state
                    # If stripped_line is empty (blank line), just discard it by doing nothing
                    continue # Move to the next line in the input file

                # If not waiting for content, check if the current line is a #### header
                match = header_pattern.match(line)
                if match:
                    number_or_range = match.group(1)
                    rest_of_line = match.group(3).strip() # Strip whitespace from captured text

                    if rest_of_line:
                        # The #### header had content on the same line
                        new_line = f"{number_or_range}\\. {rest_of_line}\n"
                        outfile.write(new_line)
                        # No pending state needed as content was processed immediately
                    else:
                        # The #### header had no content on the same line
                        # Store the number and wait for the next non-blank line
                        pending_number = number_or_range
                        # Do NOT write the #### line itself to the output yet
                else:
                    # This line is not a #### header and we are not waiting for content
                    # Write the line as is
                    outfile.write(line)

            # If the file ends and pending_number is not None, it means a ####
            # was the last relevant content. No action needed based on requirement.

        print(f"Successfully processed '{input_filepath}' and saved to '{output_filepath}'")

    # except FileNotFoundError:
    #     print(f"Error: Input file not found at '{input_filepath}'", file=sys.stderr)

    # except PermissionError:
    #     print(f"Error: Permission denied to access files. Check permissions for '{input_filepath}' or '{output_filepath}'", file=sys.stderr)

    except Exception as e:
        print(f"An unexpected error occurred: {e}", file=sys.stderr)




# Process the file'
input_file = "../.docsource/kinh-tang-chi/sujato/1.md"  # Example output file
output_file = "../.docsource/kinh-tang-chi/sujato/1-1.md"
process_markdown_headers(input_file, output_file)

# %%
# add <!--pg-->
import sys
import re
import os

def process_markdown_headers(input_filepath, output_filepath):
    """
    Reads a markdown file, finds lines starting with '#### <number/range>',
    replaces them with r'<number/range>\. <rest of line>', and adds
    a blank line and '<!--pg-->' after the entire content block.
    Handles multi-line content, initial blank lines after the H4,
    same-line content, and block termination by a blank line or any header.

    Args:
        input_filepath (str): The path to the input markdown file.
        output_filepath (str): The path where the modified content will be saved.
    """
    # Regex for the target H4 header: #### <number/range> optional_text
    # Captures the number/range in group 1 and optional rest of the line in group 3.
    header_pattern = re.compile(r'^#### (\d+(--\d+)?)\s*(.*)$')
    # Regex to identify any markdown header (H1, H2, H3, H4, etc.)
    any_header_pattern = re.compile(r'^\s*#+')

    try:
        # Ensure the directory for the output file exists
        output_dir = os.path.dirname(output_filepath)
        if output_dir and not os.path.exists(output_dir):
            os.makedirs(output_dir)

        with open(input_filepath, 'r', encoding='utf-8') as infile, \
             open(output_filepath, 'w', encoding='utf-8') as outfile:

            lines = infile.readlines() # Read all lines into memory for easier lookahead
            i = 0 # Index for the main loop through lines

            while i < len(lines):
                line = lines[i]
                is_h4 = header_pattern.match(line)

                if is_h4:
                    # Found the start of a potential #### block
                    number_or_range = is_h4.group(1)
                    rest_of_h4_line = is_h4.group(3).strip()

                    content_lines_raw = [] # Buffer for lines after the H4 line
                    first_content_found = False # Flag: have we seen a non-blank line after initial blanks?

                    # Look ahead for the rest of the content block
                    j = i + 1 # Start looking from the line *after* the H4 line
                    while j < len(lines):
                        next_line = lines[j]
                        is_next_any_header = any_header_pattern.match(next_line)
                        is_next_blank = next_line.strip() == ''

                        # Termination condition for the content block:
                        # 1. The next line is any header (H1, H2, H3, etc.)
                        # 2. The next line is blank AND we have already collected some content lines.
                        #    This handles blank lines *between* blocks as terminators.
                        if is_next_any_header or (is_next_blank and first_content_found):
                            break # Found the terminator line, stop collecting content for this block

                        # If we reach here, the next line is not a block terminator.
                        # If it's a blank line *before* any content has been found, consume it and continue the lookahead.
                        if is_next_blank and not first_content_found:
                            j += 1 # Consume this initial blank line
                            continue # Go to the next line in the inner loop

                        # If we reach here, next_line is not a header and not an initial blank line.
                        # It must be a content line (could be blank *within* the block if first_content_found is True).
                        content_lines_raw.append(next_line)
                        # Mark first_content_found the moment we add the first non-blank line
                        if not first_content_found: # Check state *before* adding the line
                             if not is_next_blank: # Only set if the line being added is not blank itself
                                first_content_found = True

                        j += 1 # Move to the next line in the input

                    # Prepare the final list of content lines to write
                    if rest_of_h4_line:
                         # Add the same-line content as the effective first line.
                         # Ensure it ends with a newline for consistency if it didn't originally.
                         if not rest_of_h4_line.endswith('\n'):
                             rest_of_h4_line += '\n'
                         processed_content_lines = [rest_of_h4_line] + content_lines_raw
                    else:
                         # Use the raw buffered lines starting from the first non-blank after H4
                         processed_content_lines = content_lines_raw

                    # Process and write the collected block *if* there were any content lines
                    # We only write if content_lines_raw was non-empty OR rest_of_h4_line was non-empty
                    if processed_content_lines:
                        # Format and write the first line
                        # Strip leading/trailing space from the very first content line
                        first_line_content = processed_content_lines[0].strip()
                        # Use \\. in the f-string to output the literal '\.'
                        outfile.write(f"{number_or_range}\\. {first_line_content}\n")

                        # Write subsequent buffered lines (already include original newlines)
                        for subsequent_line in processed_content_lines[1:]:
                            outfile.write(subsequent_line)

                        # Add the blank line and the marker after the content block
                        outfile.write("\n")
                        outfile.write("<!--pg-->")

                    # Move the main loop index past the H4 line and all the lines that were buffered as content.
                    # The line at index j is the terminator (header or blank after content),
                    # or the end of the file. The next iteration should start processing *that* line.
                    i = j

                else:
                    # Not a #### header, just write the line as is
                    outfile.write(line)
                    i += 1 # Move to the next line in the input


        print(f"Successfully processed '{input_filepath}' and saved to '{output_filepath}'")

    except FileNotFoundError:
        print(f"Error: Input file not found at '{input_filepath}'", file=sys.stderr)
        sys.exit(1)
    except PermissionError:
        print(f"Error: Permission denied to access files. Check permissions for '{input_filepath}' or '{output_filepath}'", file=sys.stderr)
        sys.exit(1)
    except Exception as e:
        print(f"An unexpected error occurred: {e}", file=sys.stderr)
        sys.exit(1)

input_file = "../.docsource/kinh-tang-chi/sujato/1.md"  # Example output file
output_file = "../.docsource/kinh-tang-chi/sujato/1-1.md"
process_markdown_headers(input_file, output_file)

# %%
# add paragraph for thichminhchau

import argparse
import re
import sys
import os

def modify_markdown(input_file_path: str, output_file_path: str):
    """
    Reads a Markdown file, inserts '<!--pg-->' before lines starting
    with a number or number range followed by '\. ', and writes the
    result to a new file.

    Args:
        input_file_path: Path to the input Markdown file.
        output_file_path: Path to the output Markdown file.
    """
    # Regex to find lines starting with:
    # - One or more digits (\d+)
    # - Optionally, a hyphen and more digits (?:-\d+)? for ranges like 7-10
    # - Followed by a literal backslash and period ('\.') - need to escape backslash in regex
    # - Followed by a space (' ')
    # ^ anchors the match to the start of the line.
    pattern = re.compile(r"^\d+(?:-\d+)?\\\. ")
    pattern = re.compile(r"^\d+(?:-\d+)?")
    pattern = re.compile(r"^\d+(?:-\d+)?(?:\\\.|\.) ")

    print(f"Processing '{input_file_path}'...")

    try:
        # Ensure the output directory exists if specified as part of the path
        output_dir = os.path.dirname(output_file_path)
        if output_dir and not os.path.exists(output_dir):
            os.makedirs(output_dir)
            print(f"Created output directory: '{output_dir}'")

        with open(input_file_path, 'r', encoding='utf-8') as infile, \
             open(output_file_path, 'w', encoding='utf-8') as outfile:

            for line in infile:
                # Check if the current line matches the pattern
                if pattern.match(line):
                    # If it matches, write the marker first, followed by a newline
                    outfile.write("<!--pg-->\n")
                # Write the original line (it includes its own newline character)
                outfile.write(line)

        print(f"Successfully modified content written to '{output_file_path}'.")

    except FileNotFoundError:
        print(f"Error: Input file not found at '{input_file_path}'", file=sys.stderr)
        sys.exit(1)
    except IOError as e:
        print(f"Error reading or writing file: {e}", file=sys.stderr)
        sys.exit(1)
    except Exception as e:
        print(f"An unexpected error occurred: {e}", file=sys.stderr)
        sys.exit(1)

# %%
input_file = "../.docsource/kinh-tang-chi/thichminhchau/01-002-pham-doan-trien-cai.md"  # Example output file
output_file = "../.docsource/kinh-tang-chi/thichminhchau/01-002-pham-doan-trien-cai-1.md"
modify_markdown(input_file, output_file)

# %%
import os
file_list = [os.path.join('../.docsource/kinh-tang-chi/thichminhchau/', f) for f in os.listdir('../.docsource/kinh-tang-chi/thichminhchau/') if f.endswith('.md')]

def create_output_path(input_path: str, sub_dir: str = "out") -> str:
    original_dir = os.path.dirname(input_path)
    filename = os.path.basename(input_path)
    new_dir = os.path.join(original_dir, sub_dir)
    new_path = os.path.join(new_dir, filename)
    return new_path

for f in file_list:
    modify_markdown(f, create_output_path(f, 'out'))
# Out:
# Processing '../.docsource/kinh-tang-chi/thichminhchau/05-012-pham-andhakavinda.md'...
# Created output directory: '../.docsource/kinh-tang-chi/thichminhchau/out'
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/05-012-pham-andhakavinda.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/07-008-pham-ve-luat.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/07-008-pham-ve-luat.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/02-002-pham-tranh-luan.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/02-002-pham-tranh-luan.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/06-011-pham-ba-phap.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/06-011-pham-ba-phap.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/10-021-pham-than-do-nghiep-sanh.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/10-021-pham-than-do-nghiep-sanh.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/01-019-pham-khong-phong-dat.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/01-019-pham-khong-phong-dat.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/03-004-pham-su-gia-cua-troi.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/03-004-pham-su-gia-cua-troi.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/03-001-pham-nguoi-ngu.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/03-001-pham-nguoi-ngu.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/10-012-pham-di-xuong.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/10-012-pham-di-xuong.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/mucluc.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/mucluc.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/07-007-dai-pham.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/07-007-dai-pham.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/06-008-pham-a-la-han.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/06-008-pham-a-la-han.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/04-009-pham-khong-co-rung-dong.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/04-009-pham-khong-co-rung-dong.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/09-004-dai-pham.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/09-004-dai-pham.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/04-013-pham-so-hai.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/04-013-pham-so-hai.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/09-003-pham-cho-cu-tru-cua-huu-tinh.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/09-003-pham-cho-cu-tru-cua-huu-tinh.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/07-002-pham-tuy-mien.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/07-002-pham-tuy-mien.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/03-009-pham-sa-mon.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/03-009-pham-sa-mon.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/04-014-pham-loai-nguoi.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/04-014-pham-loai-nguoi.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/08-005-pham-ngay-trai-gioi.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/08-005-pham-ngay-trai-gioi.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/01-012-pham-vo-pham.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/01-012-pham-vo-pham.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/01-001-pham-sac.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/01-001-pham-sac.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/05-011-pham-an-on-tru.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/05-011-pham-an-on-tru.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/05-015-pham-tikandaki.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/05-015-pham-tikandaki.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/02-014-pham-don-chao.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/02-014-pham-don-chao.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/05-001-pham-suc-manh-huu-hoc.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/05-001-pham-suc-manh-huu-hoc.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/04-004-pham-banh-xe.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/04-004-pham-banh-xe.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/07-005-pham-dai-te-dan.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/07-005-pham-dai-te-dan.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/10-017-pham-janussoni.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/10-017-pham-janussoni.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/03-010-pham-hat-muoi.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/03-010-pham-hat-muoi.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/06-009-pham-mat-lanh.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/06-009-pham-mat-lanh.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/09-008-pham-chanh-can.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/09-008-pham-chanh-can.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/06-010-pham-loi-ich.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/06-010-pham-loi-ich.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/01-020-pham-thien-dinh-that-su-la-vay.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/01-020-pham-thien-dinh-that-su-la-vay.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/09-005-pham-pancala.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/09-005-pham-pancala.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/05-024-pham-tru-tai-cho.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/05-024-pham-tru-tai-cho.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/10-015-pham-thanh-dao.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/10-015-pham-thanh-dao.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/08-002-pham-lon.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/08-002-pham-lon.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/08-004-pham-bo-thi.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/08-004-pham-bo-thi.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/10-009-pham-truong-lao.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/10-009-pham-truong-lao.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/01-013-pham-mot-nguoi.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/01-013-pham-mot-nguoi.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/01-023-pham-thien-dinh-2-bat-tu.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/01-023-pham-thien-dinh-2-bat-tu.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/02-004-pham-tam-thang-bang.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/02-004-pham-tam-thang-bang.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/03-003-pham-nguoi.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/03-003-pham-nguoi.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/04-001-pham-bhandagana.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/04-001-pham-bhandagana.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/06-002-pham-can-phai-nho.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/06-002-pham-can-phai-nho.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/01-006-pham-bung-ngon-tay.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/01-006-pham-bung-ngon-tay.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/07-003-pham-vajji-bat-ky.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/07-003-pham-vajji-bat-ky.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/04-021-pham-bac-chan-nhan.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/04-021-pham-bac-chan-nhan.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/01-007-pham-tinh-tan.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/01-007-pham-tinh-tan.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/05-004-pham-sumana.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/05-004-pham-sumana.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/05-016-pham-dieu-phap.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/05-016-pham-dieu-phap.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/07-006-pham-khong-tuyen-bo.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/07-006-pham-khong-tuyen-bo.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/04-018-pham-tu-tam-so.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/04-018-pham-tu-tam-so.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/10-022-pham-khong-co-dau-de.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/10-022-pham-khong-co-dau-de.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/10-013-pham-thanh-tinh.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/10-013-pham-thanh-tinh.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/05-003-pham-nam-phan.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/05-003-pham-nam-phan.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/04-010-pham-asura-a-tu-la.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/04-010-pham-asura-a-tu-la.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/03-015-pham-cat-tuong.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/03-015-pham-cat-tuong.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/05-007-pham-tuong.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/05-007-pham-tuong.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/02-017-1-pham-thu-muoi-bay.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/02-017-1-pham-thu-muoi-bay.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/04-022-pham-o-ue.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/04-022-pham-o-ue.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/06-012-pham-cac-kinh-khong-nhiep-trong-pham.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/06-012-pham-cac-kinh-khong-nhiep-trong-pham.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/05-026-pham-cu-tuc-gioi.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/05-026-pham-cu-tuc-gioi.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/10-020-pham-cac-hang-nguoi.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/10-020-pham-cac-hang-nguoi.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/08-001-pham-tu.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/08-001-pham-tu.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/10-016-pham-nguoi.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/10-016-pham-nguoi.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/02-016-1-pham-phan-no.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/02-016-1-pham-phan-no.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/01-021-pham-thien-dinh-bung-ngon-tay.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/01-021-pham-thien-dinh-bung-ngon-tay.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/10-004-pham-upali-va-ananda.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/10-004-pham-upali-va-ananda.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/01-016-pham-mot-phap.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/01-016-pham-mot-phap.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/04-002-pham-hanh.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/04-002-pham-hanh.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/10-001-pham-loi-ich.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/10-001-pham-loi-ich.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/01-002-pham-doan-trien-cai.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/01-002-pham-doan-trien-cai.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/09-006-pham-an-on.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/09-006-pham-an-on.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/01-015-pham-khong-the-co-duoc.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/01-015-pham-khong-the-co-duoc.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/10-011-pham-sa-mon-tuong.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/10-011-pham-sa-mon-tuong.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/06-001-pham-dang-duoc-cung-kinh.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/06-001-pham-dang-duoc-cung-kinh.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/04-005-pham-rohitassa.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/04-005-pham-rohitassa.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/01-004-pham-khong-dieu-phuc.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/01-004-pham-khong-dieu-phuc.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/07-004-pham-chu-thien.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/07-004-pham-chu-thien.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/10-006-pham-tam-cua-minh.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/10-006-pham-tam-cua-minh.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/05-019-pham-rung.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/05-019-pham-rung.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/06-007-pham-chu-thien.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/06-007-pham-chu-thien.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/09-002-pham-tieng-rong-con-su-tu.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/09-002-pham-tieng-rong-con-su-tu.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/03-007-pham-lon.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/03-007-pham-lon.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/02-012-pham-hy-cau.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/02-012-pham-hy-cau.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/02-001-pham-hinh-phat.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/02-001-pham-hinh-phat.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/05-022-pham-mang-nhiec.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/05-022-pham-mang-nhiec.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/08-009-pham-niem.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/08-009-pham-niem.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/04-024-pham-nghiep.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/04-024-pham-nghiep.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/03-012-pham-doa-xu.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/03-012-pham-doa-xu.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/05-020-pham-ba-la-mon.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/05-020-pham-ba-la-mon.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/05-023-pham-du-hanh-dai.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/05-023-pham-du-hanh-dai.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/02-008-pham-tuong.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/02-008-pham-tuong.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/05-025-pham-ac-hanh.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/05-025-pham-ac-hanh.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/05-018-pham-nam-cu-si.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/05-018-pham-nam-cu-si.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/03-008-pham-ananda.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/03-008-pham-ananda.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/01-010-pham-phi-phap-1.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/01-010-pham-phi-phap-1.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/03-013-pham-kusinara.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/03-013-pham-kusinara.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/04-011-pham-may-mua.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/04-011-pham-may-mua.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/01-005-pham-dat-huong-va-trong-sang.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/01-005-pham-dat-huong-va-trong-sang.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/10-007-pham-song-doi.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/10-007-pham-song-doi.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/09-007-pham-niem-xu.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/09-007-pham-niem-xu.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/04-015-pham-anh-sang.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/04-015-pham-anh-sang.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/08-008-pham-song-doi.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/08-008-pham-song-doi.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/03-005-pham-nho.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/03-005-pham-nho.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/01-003-pham-kho-su-dung.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/01-003-pham-kho-su-dung.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/01-011-pham-phi-phap-3.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/01-011-pham-phi-phap-3.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/08-010-pham-tham-ai.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/08-010-pham-tham-ai.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/02-017-2-pham-thu-muoi-bay.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/02-017-2-pham-thu-muoi-bay.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/02-015-pham-nhap-dinh.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/02-015-pham-nhap-dinh.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/08-006-pham-gotami.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/08-006-pham-gotami.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/11-003-pham-ba-tong-ket.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/11-003-pham-ba-tong-ket.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/10-018-pham-thien-luong.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/10-018-pham-thien-luong.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/04-012-pham-kesi.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/04-012-pham-kesi.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/10-008-pham-uoc-nguyen.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/10-008-pham-uoc-nguyen.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/04-020-dai-pham.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/04-020-dai-pham.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/03-006-pham-cac-ba-la-mon.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/03-006-pham-cac-ba-la-mon.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/02-007-pham-lac.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/02-007-pham-lac.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/04-008-pham-khong-hy-luan.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/04-008-pham-khong-hy-luan.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/04-027-pham-nghiep-dao.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/04-027-pham-nghiep-dao.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/05-006-pham-trien-cai.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/05-006-pham-trien-cai.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/01-014-pham-nguoi-toi-thang.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/01-014-pham-nguoi-toi-thang.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/05-017-pham-hiem-han.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/05-017-pham-hiem-han.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/04-003-pham-uruvela.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/04-003-pham-uruvela.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/01-018-pham-makkhali.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/01-018-pham-makkhali.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/05-013-pham-benh.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/05-013-pham-benh.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/04-026-pham-thang-tri.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/04-026-pham-thang-tri.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/02-016-2-pham-phan-no.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/02-016-2-pham-phan-no.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/05-008-pham-chien-si.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/05-008-pham-chien-si.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/01-009-pham-phong-dat.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/01-009-pham-phong-dat.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/04-006-pham-nguon-sanh-phuoc.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/04-006-pham-nguon-sanh-phuoc.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/02-003-pham-nguoi-ngu.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/02-003-pham-nguoi-ngu.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/02-010-pham-ke-ngu.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/02-010-pham-ke-ngu.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/03-014-pham-ke-chien-si.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/03-014-pham-ke-chien-si.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/06-006-dai-pham.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/06-006-dai-pham.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/01-022-pham-thien-dinh-2-than-hanh-niem.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/01-022-pham-thien-dinh-2-than-hanh-niem.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/09-010-pham-tham.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/09-010-pham-tham.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/03-016-pham-loa-the.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/03-016-pham-loa-the.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/05-010-pham-kakudha.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/05-010-pham-kakudha.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/05-005-pham-vua-munda.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/05-005-pham-vua-munda.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/02-013-pham-bo-thi.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/02-013-pham-bo-thi.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/10-019-pham-thanh-dao.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/10-019-pham-thanh-dao.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/04-028-pham-tham.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/04-028-pham-tham.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/08-003-pham-gia-chu.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/08-003-pham-gia-chu.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/02-005-pham-hoi-chung.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/02-005-pham-hoi-chung.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/08-007-pham-dat-rung-dong.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/08-007-pham-dat-rung-dong.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/11-002-pham-tuy-niem.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/11-002-pham-tuy-niem.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/09-009-pham-bon-nhu-y-tuc.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/09-009-pham-bon-nhu-y-tuc.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/02-011-pham-cac-hy-vong.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/02-011-pham-cac-hy-vong.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/07-009-pham-cac-kinh-khong-nhiep.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/07-009-pham-cac-kinh-khong-nhiep.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/06-005-pham-dhammika.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/06-005-pham-dhammika.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/11-001-pham-y-chi.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/11-001-pham-y-chi.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/03-002-pham-nguoi-dong-xe.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/03-002-pham-nguoi-dong-xe.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/04-017-pham-dao-hanh.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/04-017-pham-dao-hanh.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/05-009-pham-truong-lao.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/05-009-pham-truong-lao.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/10-014-pham-thien-luong.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/10-014-pham-thien-luong.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/06-003-pham-tren-tat-ca.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/06-003-pham-tren-tat-ca.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/04-023-pham-dieu-hanh.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/04-023-pham-dieu-hanh.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/10-005-pham-mang-nhiec.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/10-005-pham-mang-nhiec.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/01-017-pham-chung-tu.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/01-017-pham-chung-tu.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/10-003-pham-lon.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/10-003-pham-lon.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/06-004-pham-chu-thien.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/06-004-pham-chu-thien.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/10-002-pham-ho-tri.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/10-002-pham-ho-tri.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/01-008-pham-lam-ban-voi-thien.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/01-008-pham-lam-ban-voi-thien.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/05-014-pham-vua.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/05-014-pham-vua.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/07-001-pham-tai-san.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/07-001-pham-tai-san.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/04-007-pham-nghiep-cong-duc.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/04-007-pham-nghiep-cong-duc.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/09-001-pham-chanh-giac.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/09-001-pham-chanh-giac.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/04-016-pham-cac-can.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/04-016-pham-cac-can.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/05-002-pham-suc-manh.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/05-002-pham-suc-manh.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/05-021-pham-kimbila.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/05-021-pham-kimbila.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/04-025-pham-so-hai-pham-toi.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/04-025-pham-so-hai-pham-toi.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/04-019-pham-chien-si.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/04-019-pham-chien-si.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/10-010-pham-nam-cu-si.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/10-010-pham-nam-cu-si.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/02-006-pham-nguoi.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/02-006-pham-nguoi.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/02-009-pham-cac-phap.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/02-009-pham-cac-phap.md'.
# Processing '../.docsource/kinh-tang-chi/thichminhchau/03-011-pham-chanh-giac.md'...
# Successfully modified content written to '../.docsource/kinh-tang-chi/thichminhchau/out/03-011-pham-chanh-giac.md'.

# %%
import os
import re

def replace_double_asterisks_with_heading(folder_path):
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if not file.endswith('.md'):
                continue
            file_path = os.path.join(root, file)
            try:
                # Read the file content
                with open(file_path, 'r', encoding='utf-8') as f:
                    content = f.read()

                # Replace **text** with ### text
                modified_content = re.sub(r'\*\*(.*?)\*\*', r'### \1', content)

                # Write back to file if changes were made
                if content != modified_content:
                    with open(file_path, 'w', encoding='utf-8') as f:
                        f.write(modified_content)
                    print(f"Updated: {file_path}")
            except Exception as e:
                print(f"Error processing {file_path}: {e}")

# Example usage
folder_path = "../docs/kinhtangchi/thichminhchau/"  # Replace with actual folder path
replace_double_asterisks_with_heading(folder_path)
# Out:
# Updated: ../docs/kinhtangchi/thichminhchau/07-008-pham-ve-luat.md
# Updated: ../docs/kinhtangchi/thichminhchau/02-002-pham-tranh-luan.md
# Updated: ../docs/kinhtangchi/thichminhchau/10-021-pham-than-do-nghiep-sanh.md
# Updated: ../docs/kinhtangchi/thichminhchau/01-019-pham-khong-phong-dat.md
# Updated: ../docs/kinhtangchi/thichminhchau/03-004-pham-su-gia-cua-troi.md
# Updated: ../docs/kinhtangchi/thichminhchau/03-001-pham-nguoi-ngu.md
# Updated: ../docs/kinhtangchi/thichminhchau/10-012-pham-di-xuong.md
# Updated: ../docs/kinhtangchi/thichminhchau/07-007-dai-pham.md
# Updated: ../docs/kinhtangchi/thichminhchau/04-009-pham-khong-co-rung-dong.md
# Updated: ../docs/kinhtangchi/thichminhchau/09-004-dai-pham.md
# Updated: ../docs/kinhtangchi/thichminhchau/04-013-pham-so-hai.md
# Updated: ../docs/kinhtangchi/thichminhchau/09-003-pham-cho-cu-tru-cua-huu-tinh.md
# Updated: ../docs/kinhtangchi/thichminhchau/07-002-pham-tuy-mien.md
# Updated: ../docs/kinhtangchi/thichminhchau/03-009-pham-sa-mon.md
# Updated: ../docs/kinhtangchi/thichminhchau/04-014-pham-loai-nguoi.md
# Updated: ../docs/kinhtangchi/thichminhchau/08-005-pham-ngay-trai-gioi.md
# Updated: ../docs/kinhtangchi/thichminhchau/01-012-pham-vo-pham.md
# Updated: ../docs/kinhtangchi/thichminhchau/01-001-pham-sac.md
# Updated: ../docs/kinhtangchi/thichminhchau/02-014-pham-don-chao.md
# Updated: ../docs/kinhtangchi/thichminhchau/04-004-pham-banh-xe.md
# Updated: ../docs/kinhtangchi/thichminhchau/07-005-pham-dai-te-dan.md
# Updated: ../docs/kinhtangchi/thichminhchau/10-017-pham-janussoni.md
# Updated: ../docs/kinhtangchi/thichminhchau/03-010-pham-hat-muoi.md
# Updated: ../docs/kinhtangchi/thichminhchau/09-008-pham-chanh-can.md
# Updated: ../docs/kinhtangchi/thichminhchau/01-020-pham-thien-dinh-that-su-la-vay.md
# Updated: ../docs/kinhtangchi/thichminhchau/03-016-1-pham-loa-the.md
# Updated: ../docs/kinhtangchi/thichminhchau/09-005-pham-pancala.md
# Updated: ../docs/kinhtangchi/thichminhchau/10-015-pham-thanh-dao.md
# Updated: ../docs/kinhtangchi/thichminhchau/08-002-pham-lon.md
# Updated: ../docs/kinhtangchi/thichminhchau/08-004-pham-bo-thi.md
# Updated: ../docs/kinhtangchi/thichminhchau/10-009-pham-truong-lao.md
# Updated: ../docs/kinhtangchi/thichminhchau/01-013-pham-mot-nguoi.md
# Updated: ../docs/kinhtangchi/thichminhchau/01-023-pham-thien-dinh-2-bat-tu.md
# Updated: ../docs/kinhtangchi/thichminhchau/02-004-pham-tam-thang-bang.md
# Updated: ../docs/kinhtangchi/thichminhchau/03-003-pham-nguoi.md
# Updated: ../docs/kinhtangchi/thichminhchau/04-001-pham-bhandagana.md
# Updated: ../docs/kinhtangchi/thichminhchau/01-006-pham-bung-ngon-tay.md
# Updated: ../docs/kinhtangchi/thichminhchau/07-003-pham-vajji-bat-ky.md
# Updated: ../docs/kinhtangchi/thichminhchau/04-021-pham-bac-chan-nhan.md
# Updated: ../docs/kinhtangchi/thichminhchau/01-007-pham-tinh-tan.md
# Updated: ../docs/kinhtangchi/thichminhchau/07-006-pham-khong-tuyen-bo.md
# Updated: ../docs/kinhtangchi/thichminhchau/04-018-pham-tu-tam-so.md
# Updated: ../docs/kinhtangchi/thichminhchau/10-022-pham-khong-co-dau-de.md
# Updated: ../docs/kinhtangchi/thichminhchau/10-013-pham-thanh-tinh.md
# Updated: ../docs/kinhtangchi/thichminhchau/04-010-pham-asura-a-tu-la.md
# Updated: ../docs/kinhtangchi/thichminhchau/03-015-pham-cat-tuong.md
# Updated: ../docs/kinhtangchi/thichminhchau/04-022-pham-o-ue.md
# Updated: ../docs/kinhtangchi/thichminhchau/10-020-pham-cac-hang-nguoi.md
# Updated: ../docs/kinhtangchi/thichminhchau/08-001-pham-tu.md
# Updated: ../docs/kinhtangchi/thichminhchau/10-016-pham-nguoi.md
# Updated: ../docs/kinhtangchi/thichminhchau/01-021-pham-thien-dinh-bung-ngon-tay.md
# Updated: ../docs/kinhtangchi/thichminhchau/10-004-pham-upali-va-ananda.md
# Updated: ../docs/kinhtangchi/thichminhchau/01-016-pham-mot-phap.md
# Updated: ../docs/kinhtangchi/thichminhchau/04-002-pham-hanh.md
# Updated: ../docs/kinhtangchi/thichminhchau/10-001-pham-loi-ich.md
# Updated: ../docs/kinhtangchi/thichminhchau/01-002-pham-doan-trien-cai.md
# Updated: ../docs/kinhtangchi/thichminhchau/09-006-pham-an-on.md
# Updated: ../docs/kinhtangchi/thichminhchau/01-015-pham-khong-the-co-duoc.md
# Updated: ../docs/kinhtangchi/thichminhchau/10-011-pham-sa-mon-tuong.md
# Updated: ../docs/kinhtangchi/thichminhchau/04-005-pham-rohitassa.md
# Updated: ../docs/kinhtangchi/thichminhchau/01-004-pham-khong-dieu-phuc.md
# Updated: ../docs/kinhtangchi/thichminhchau/07-004-pham-chu-thien.md
# Updated: ../docs/kinhtangchi/thichminhchau/10-006-pham-tam-cua-minh.md
# Updated: ../docs/kinhtangchi/thichminhchau/09-002-pham-tieng-rong-con-su-tu.md
# Updated: ../docs/kinhtangchi/thichminhchau/03-007-pham-lon.md
# Updated: ../docs/kinhtangchi/thichminhchau/02-012-pham-hy-cau.md
# Updated: ../docs/kinhtangchi/thichminhchau/02-001-pham-hinh-phat.md
# Updated: ../docs/kinhtangchi/thichminhchau/08-009-pham-niem.md
# Updated: ../docs/kinhtangchi/thichminhchau/04-024-pham-nghiep.md
# Updated: ../docs/kinhtangchi/thichminhchau/03-012-pham-doa-xu.md
# Updated: ../docs/kinhtangchi/thichminhchau/03-008-pham-ananda.md
# Updated: ../docs/kinhtangchi/thichminhchau/01-010-pham-phi-phap-1.md
# Updated: ../docs/kinhtangchi/thichminhchau/03-013-pham-kusinara.md
# Updated: ../docs/kinhtangchi/thichminhchau/04-011-pham-may-mua.md
# Updated: ../docs/kinhtangchi/thichminhchau/01-005-pham-dat-huong-va-trong-sang.md
# Updated: ../docs/kinhtangchi/thichminhchau/10-007-pham-song-doi.md
# Updated: ../docs/kinhtangchi/thichminhchau/09-007-pham-niem-xu.md
# Updated: ../docs/kinhtangchi/thichminhchau/04-015-pham-anh-sang.md
# Updated: ../docs/kinhtangchi/thichminhchau/08-008-pham-song-doi.md
# Updated: ../docs/kinhtangchi/thichminhchau/03-016-2-pham-loa-the.md
# Updated: ../docs/kinhtangchi/thichminhchau/03-005-pham-nho.md
# Updated: ../docs/kinhtangchi/thichminhchau/01-003-pham-kho-su-dung.md
# Updated: ../docs/kinhtangchi/thichminhchau/01-011-pham-phi-phap-3.md
# Updated: ../docs/kinhtangchi/thichminhchau/08-010-pham-tham-ai.md
# Updated: ../docs/kinhtangchi/thichminhchau/02-017-2-pham-thu-muoi-bay.md
# Updated: ../docs/kinhtangchi/thichminhchau/02-015-pham-nhap-dinh.md
# Updated: ../docs/kinhtangchi/thichminhchau/08-006-pham-gotami.md
# Updated: ../docs/kinhtangchi/thichminhchau/11-003-pham-ba-tong-ket.md
# Updated: ../docs/kinhtangchi/thichminhchau/10-018-pham-thien-luong.md
# Updated: ../docs/kinhtangchi/thichminhchau/04-012-pham-kesi.md
# Updated: ../docs/kinhtangchi/thichminhchau/10-008-pham-uoc-nguyen.md
# Updated: ../docs/kinhtangchi/thichminhchau/04-020-dai-pham.md
# Updated: ../docs/kinhtangchi/thichminhchau/03-006-pham-cac-ba-la-mon.md
# Updated: ../docs/kinhtangchi/thichminhchau/04-008-pham-khong-hy-luan.md
# Updated: ../docs/kinhtangchi/thichminhchau/04-027-pham-nghiep-dao.md
# Updated: ../docs/kinhtangchi/thichminhchau/01-014-pham-nguoi-toi-thang.md
# Updated: ../docs/kinhtangchi/thichminhchau/04-003-pham-uruvela.md
# Updated: ../docs/kinhtangchi/thichminhchau/01-018-pham-makkhali.md
# Updated: ../docs/kinhtangchi/thichminhchau/04-026-pham-thang-tri.md
# Updated: ../docs/kinhtangchi/thichminhchau/04-006-pham-nguon-sanh-phuoc.md
# Updated: ../docs/kinhtangchi/thichminhchau/02-010-pham-ke-ngu.md
# Updated: ../docs/kinhtangchi/thichminhchau/03-014-pham-ke-chien-si.md
# Updated: ../docs/kinhtangchi/thichminhchau/09-010-pham-tham.md
# Updated: ../docs/kinhtangchi/thichminhchau/02-013-pham-bo-thi.md
# Updated: ../docs/kinhtangchi/thichminhchau/10-019-pham-thanh-dao.md
# Updated: ../docs/kinhtangchi/thichminhchau/04-028-pham-tham.md
# Updated: ../docs/kinhtangchi/thichminhchau/08-003-pham-gia-chu.md
# Updated: ../docs/kinhtangchi/thichminhchau/02-005-pham-hoi-chung.md
# Updated: ../docs/kinhtangchi/thichminhchau/08-007-pham-dat-rung-dong.md
# Updated: ../docs/kinhtangchi/thichminhchau/11-002-pham-tuy-niem.md
# Updated: ../docs/kinhtangchi/thichminhchau/09-009-pham-bon-nhu-y-tuc.md
# Updated: ../docs/kinhtangchi/thichminhchau/02-011-pham-cac-hy-vong.md
# Updated: ../docs/kinhtangchi/thichminhchau/07-009-pham-cac-kinh-khong-nhiep.md
# Updated: ../docs/kinhtangchi/thichminhchau/11-001-pham-y-chi.md
# Updated: ../docs/kinhtangchi/thichminhchau/03-002-pham-nguoi-dong-xe.md
# Updated: ../docs/kinhtangchi/thichminhchau/04-017-pham-dao-hanh.md
# Updated: ../docs/kinhtangchi/thichminhchau/10-014-pham-thien-luong.md
# Updated: ../docs/kinhtangchi/thichminhchau/04-023-pham-dieu-hanh.md
# Updated: ../docs/kinhtangchi/thichminhchau/10-005-pham-mang-nhiec.md
# Updated: ../docs/kinhtangchi/thichminhchau/01-017-pham-chung-tu.md
# Updated: ../docs/kinhtangchi/thichminhchau/10-003-pham-lon.md
# Updated: ../docs/kinhtangchi/thichminhchau/10-002-pham-ho-tri.md
# Updated: ../docs/kinhtangchi/thichminhchau/01-008-pham-lam-ban-voi-thien.md
# Updated: ../docs/kinhtangchi/thichminhchau/07-001-pham-tai-san.md
# Updated: ../docs/kinhtangchi/thichminhchau/04-007-pham-nghiep-cong-duc.md
# Updated: ../docs/kinhtangchi/thichminhchau/09-001-pham-chanh-giac.md
# Updated: ../docs/kinhtangchi/thichminhchau/04-016-pham-cac-can.md
# Updated: ../docs/kinhtangchi/thichminhchau/04-025-pham-so-hai-pham-toi.md
# Updated: ../docs/kinhtangchi/thichminhchau/04-019-pham-chien-si.md
# Updated: ../docs/kinhtangchi/thichminhchau/10-010-pham-nam-cu-si.md
# Updated: ../docs/kinhtangchi/thichminhchau/03-016-3-pham-loa-the.md
# Updated: ../docs/kinhtangchi/thichminhchau/03-011-pham-chanh-giac.md
# Updated: ../docs/kinhtangchi/thichminhchau/02/05-023-pham-du-hanh-dai.md
