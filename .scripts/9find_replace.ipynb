# %%
import os
import re # Import the regular expression module

def find_and_replace_in_file_regex(file_path, find_pattern_regex, replace_pattern_regex):
    """
    Reads a file, replaces all occurrences matching find_pattern_regex
    with replace_pattern_regex, and writes the changes back to the same file.

    Args:
        file_path (str): The path to the file to be modified.
        find_pattern_regex (str): The regular expression pattern to find.
        replace_pattern_regex (str): The replacement string or regex pattern
                                     (can include backreferences like \1, \2).

    Returns:
        bool: True if replacements were made, False otherwise (or if an error occurred).
    """
    try:
        # Read the file content
        with open(file_path, 'r', encoding='utf-8') as file:
            content = file.read()

        # Perform the replacement using regex
        # re.sub(pattern, repl, string, count=0, flags=0)
        # We use flags=re.MULTILINE so that ^ and $ match start/end of lines,
        # which is often useful for patterns like the example.
        new_content, num_replacements = re.subn(find_pattern_regex,
                                                replace_pattern_regex,
                                                content,
                                                flags=re.MULTILINE)

        if num_replacements > 0:
            # Write the modified content back to the file
            with open(file_path, 'w', encoding='utf-8') as file:
                file.write(new_content)
            print(f"Successfully made {num_replacements} replacement(s) in '{file_path}'")
            return True
        else:
            print(f"Pattern '{find_pattern_regex}' not found in '{file_path}'. No changes made.")
            return False

    except FileNotFoundError:
        print(f"Error: File not found at '{file_path}'")
        return False
    except re.error as e:
        print(f"Regex error: {e}")
        return False
    except Exception as e:
        print(f"An error occurred: {e}")
        return False

# %%
import os
file_list = [os.path.join('../docs/kinhtangchi/sujato-vi', f) for f in os.listdir('../docs/kinhtangchi/sujato-vi') if f.endswith('.md')]

# %%
import re

find_regex = r"^(###\s+)N(.*)$"
replace_regex = r"\g<1>AN\g<2>" # Using named group \g<index> is often clearer
for f in file_list:
    find_and_replace_in_file_regex(f , find_regex, replace_regex)
# Out:
# Successfully made 10 replacement(s) in '../docs/kinhtangchi/sujato-vi/05-016-the-chapter-on-the-true-teaching.md'
# Successfully made 21 replacement(s) in '../docs/kinhtangchi/sujato-vi/05-026-the-chapter-on-ordination.md'
# Successfully made 13 replacement(s) in '../docs/kinhtangchi/sujato-vi/03-014-the-chapter-on-a-warrior.md'
# Successfully made 1 replacement(s) in '../docs/kinhtangchi/sujato-vi/01-016-four-chapters-on-one-thing-1.md'
# Successfully made 10 replacement(s) in '../docs/kinhtangchi/sujato-vi/03-007-the-great-chapter.md'
# Successfully made 1 replacement(s) in '../docs/kinhtangchi/sujato-vi/02-005-the-chapter-on-assemblies.md'
# Successfully made 11 replacement(s) in '../docs/kinhtangchi/sujato-vi/06-010-the-chapter-on-benefit.md'
# Successfully made 10 replacement(s) in '../docs/kinhtangchi/sujato-vi/04-013-the-chapter-on-perils.md'
# Successfully made 11 replacement(s) in '../docs/kinhtangchi/sujato-vi/04-023-the-chapter-on-bad-conduct.md'
# Successfully made 10 replacement(s) in '../docs/kinhtangchi/sujato-vi/04-021-the-chapter-on-a-good-person.md'
# Successfully made 12 replacement(s) in '../docs/kinhtangchi/sujato-vi/06-005-the-chapter-with-dhammika.md'
# Successfully made 10 replacement(s) in '../docs/kinhtangchi/sujato-vi/04-018-the-chapter-on-intention.md'
# Successfully made 10 replacement(s) in '../docs/kinhtangchi/sujato-vi/04-016-the-chapter-on-faculties.md'
# Successfully made 10 replacement(s) in '../docs/kinhtangchi/sujato-vi/04-002-the-chapter-on-walking.md'
# Successfully made 1 replacement(s) in '../docs/kinhtangchi/sujato-vi/01-005-the-chapter-on-a-spike.md'
# Successfully made 1 replacement(s) in '../docs/kinhtangchi/sujato-vi/01-020-the-chapter-on-freedom-from-death.md'
# Successfully made 10 replacement(s) in '../docs/kinhtangchi/sujato-vi/05-019-the-chapter-on-wilderness-dwellers.md'
# Successfully made 10 replacement(s) in '../docs/kinhtangchi/sujato-vi/06-008-the-chapter-on-perfection.md'
# Successfully made 10 replacement(s) in '../docs/kinhtangchi/sujato-vi/06-011-the-chapter-on-triads.md'
# Successfully made 1 replacement(s) in '../docs/kinhtangchi/sujato-vi/01-016-four-chapters-on-one-thing-4.md'
# Successfully made 5 replacement(s) in '../docs/kinhtangchi/sujato-vi/04-028-abbreviated-texts-beginning-with-greed.md'
# Successfully made 11 replacement(s) in '../docs/kinhtangchi/sujato-vi/03-009-the-chapter-on-ascetics.md'
# Successfully made 10 replacement(s) in '../docs/kinhtangchi/sujato-vi/05-014-the-chapter-on-kings.md'
# Successfully made 1 replacement(s) in '../docs/kinhtangchi/sujato-vi/02-007-the-chapter-on-happiness.md'
# Successfully made 10 replacement(s) in '../docs/kinhtangchi/sujato-vi/05-005-the-chapter-with-king-munda.md'
# Pattern '^(###\s+)N(.*)$' not found in '../docs/kinhtangchi/sujato-vi/01-007-the-chapter-on-arousing-energy.md'. No changes made.
# Successfully made 1 replacement(s) in '../docs/kinhtangchi/sujato-vi/01-006-the-chapter-on-a-finger-snap.md'
# Successfully made 10 replacement(s) in '../docs/kinhtangchi/sujato-vi/05-025-the-chapter-on-bad-conduct.md'
# Successfully made 10 replacement(s) in '../docs/kinhtangchi/sujato-vi/06-002-the-chapter-on-warm-hearted.md'
# Pattern '^(###\s+)N(.*)$' not found in '../docs/kinhtangchi/sujato-vi/02-012-the-chapter-on-aspiration.md'. No changes made.
# Successfully made 1 replacement(s) in '../docs/kinhtangchi/sujato-vi
# Successfully made 10 replacement(s) in '../docs/kinhtangchi/sujato-vi/05-020-the-chapter-on-brahmins.md'
# Pattern '^(###\s+)N(.*)$' not found in '../docs/kinhtangchi/sujato-vi/02-001-the-chapter-on-punishments.md'. No changes made.
# Successfully made 10 replacement(s) in '../docs/kinhtangchi/sujato-vi/03-003-the-chapter-on-persons.md'
# Successfully made 10 replacement(s) in '../docs/kinhtangchi/sujato-vi/04-015-the-chapter-on-brightness.md'
# Successfully made 1 replacement(s) in '../docs/kinhtangchi/sujato-vi/03-017-the-chapter-on-ways-of-performing-deeds.md'
# Successfully made 10 replacement(s) in '../docs/kinhtangchi/sujato-vi/05-018-the-chapter-on-a-lay-follower.md'
# Successfully made 1 replacement(s) in '../docs/kinhtangchi/sujato-vi/02-013-the-chapter-on-giving.md'
# Successfully made 10 replacement(s) in '../docs/kinhtangchi/sujato-vi/03-012-the-chapter-on-bound-for-loss.md'
# Successfully made 7 replacement(s) in '../docs/kinhtangchi/sujato-vi/01-014-seven-chapters-on-the-foremost-persons.md'
# Successfully made 1 replacement(s) in '../docs/kinhtangchi/sujato-vi/02-009-the-chapter-on-two-things.md'
# Pattern '^(###\s+)N(.*)$' not found in '../docs/kinhtangchi/sujato-vi/01-003-the-chapter-on-the-useless-mind.md'. No changes made.
# Successfully made 10 replacement(s) in '../docs/kinhtangchi/sujato-vi/05-021-the-chapter-with-kimbila.md'
# Successfully made 10 replacement(s) in '../docs/kinhtangchi/sujato-vi/05-011-the-chapter-on-living-comfortably.md'
# Successfully made 10 replacement(s) in '../docs/kinhtangchi/sujato-vi/05-024-the-chapter-on-a-resident-mendicant.md'
# Successfully made 1 replacement(s) in '../docs/kinhtangchi/sujato-vi/02-011-the-chapter-on-hopes-that-are-hard-to-give-up.md'
# Successfully made 1 replacement(s) in '../docs/kinhtangchi/sujato-vi/01-010-the-chapter-on-negligence-2nd.md'
# Successfully made 10 replacement(s) in '../docs/kinhtangchi/sujato-vi/05-004-the-chapter-with-sumana.md'
# Successfully made 1 replacement(s) in '../docs/kinhtangchi/sujato-vi/01-019-the-chapter-on-mindfulness-of-the-body.md'
# Successfully made 10 replacement(s) in '../docs/kinhtangchi/sujato-vi/06-007-the-chapter-on-deities.md'
# Pattern '^(###\s+)N(.*)$' not found in '../docs/kinhtangchi/sujato-vi/01-012-the-chapter-on-non-offense.md'. No changes made.
# Successfully made 10 replacement(s) in '../docs/kinhtangchi/sujato-vi/04-009-the-chapter-on-confirmed.md'
# Successfully made 1 replacement(s) in '../docs/kinhtangchi/sujato-vi/02-004-the-chapter-on-the-peaceful-mind.md'
# Successfully made 1 replacement(s) in '../docs/kinhtangchi/sujato-vi/01-016-four-chapters-on-one-thing-3.md'
# Successfully made 10 replacement(s) in '../docs/kinhtangchi/sujato-vi/04-014-the-chapter-on-persons.md'
# Successfully made 10 replacement(s) in '../docs/kinhtangchi/sujato-vi/05-023-the-chapter-on-long-wandering.md'
# Successfully made 2 replacement(s) in '../docs/kinhtangchi/sujato-vi/03-018-the-chapter-on-abbreviated-texts-beginning-with-greed.md'
# Pattern '^(###\s+)N(.*)$' not found in '../docs/kinhtangchi/sujato-vi/01-008-the-chapter-on-good-friends.md'. No changes made.
# Pattern '^(###\s+)N(.*)$' not found in '../docs/kinhtangchi/sujato-vi/01-016-four-chapters-on-one-thing-2.md'. No changes made.
# Pattern '^(###\s+)N(.*)$' not found in '../docs/kinhtangchi/sujato-vi/05-007-the-chapter-on-perceptions.md'. No changes made.
# Successfully made 10 replacement(s) in '../docs/kinhtangchi/sujato-vi/03-015-the-chapter-on-good-fortune.md'
# Successfully made 1 replacement(s) in '../docs/kinhtangchi/sujato-vi/02-010-the-chapter-on-fools.md'
# Successfully made 10 replacement(s) in '../docs/kinhtangchi/sujato-vi/04-019-the-chapter-on-brahmins.md'
# Successfully made 11 replacement(s) in '../docs/kinhtangchi/sujato-vi/04-024-the-chapter-on-deeds.md'
# Successfully made 10 replacement(s) in '../docs/kinhtangchi/sujato-vi/05-017-the-chapter-on-resentment.md'
# Successfully made 1 replacement(s) in '../docs/kinhtangchi/sujato-vi/02-003-the-chapter-on-fools.md'
# Successfully made 10 replacement(s) in '../docs/kinhtangchi/sujato-vi/04-003-the-chapter-at-uruvela.md'
# Successfully made 10 replacement(s) in '../docs/kinhtangchi/sujato-vi/03-002-the-chapter-on-the-chariot-maker.md'
# Successfully made 10 replacement(s) in '../docs/kinhtangchi/sujato-vi/04-010-the-chapter-on-demons.md'
# Successfully made 10 replacement(s) in '../docs/kinhtangchi/sujato-vi/04-022-the-chapter-on-assemblies.md'
# Successfully made 3 replacement(s) in '../docs/kinhtangchi/sujato-vi/01-015-three-chapters-on-the-impossible.md'
# Successfully made 1 replacement(s) in '../docs/kinhtangchi/sujato-vi/02-017-the-chapter-of-abbreviated-texts-beginning-with-the-unskillful.md'
# Successfully made 10 replacement(s) in '../docs/kinhtangchi/sujato-vi/03-013-the-chapter-at-kusinara.md'

# %%
import re
# đổi từ N thành AN
find_regex = r"^(###\s+)N(.*)$"
replace_regex = r"\g<1>AN\g<2>" # Using named group \g<index> is often clearer

content = """

### N 3.92 Urgent  *Accāyikasutta*

"Mendicants, a farmer has three urgent duties. What three? A farmer
swiftly makes sure the field is well ploughed and tilled. Next they
swiftly plant seeds in season. When the time is right, they swiftly
irrigate or drain the field. These are the three urgent duties of a
farmer. That farmer has no special power or ability to say: 'Let the
crops germinate today! Let them flower tomorrow! Let them ripen the day
after!' But there comes a time when that farmer's crops germinate,
flower, and ripen as the seasons change.
"""
new_content, num_replacements = re.subn(find_regex,
                                        replace_regex,
                                        content,
                                        flags=re.MULTILINE)

print(new_content)
