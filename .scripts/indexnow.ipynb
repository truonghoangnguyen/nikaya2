# %%
import os
import sys
import re

def remove_first_pg_tag(folder):
    pattern = re.compile(r'<!--pg-->')

    for root, dirs, files in os.walk(folder):
        for file in files:
            file_path = os.path.join(root, file)

            # Chỉ làm với các file text, bạn có thể thêm điều kiện lọc file type ở đây nếu cần
            try:
                with open(file_path, 'r', encoding='utf-8') as f:
                    content = f.read()

                # Nếu có match thì xóa match đầu tiên
                if '<!--pg-->' in content:
                    new_content = pattern.sub('', content, count=1)

                    with open(file_path, 'w', encoding='utf-8') as f:
                        f.write(new_content)

                    print(f'Removed in: {file_path}')
            except Exception as e:
                print(f'Error processing {file_path}: {e}')
remove_first_pg_tag ('../.docsource/kinh-tang-chi/sujato/2')

# %%
from pathlib import Path

INPUT_DIR = "../docs/kinhtruongbo/pali/"
OUTPUT_DIR = Path("output/mn/")

OUTPUT_DIR.mkdir(exist_ok=True)

# lấy danh sách file .md và sort theo tên
files = sorted(Path(INPUT_DIR).glob("*.md"))

# merge mỗi 2 file
for i in range(0, len(files), 2):
    chunk = files[i:i+2]

    merged = []

    for file in chunk:
        content = file.read_text(encoding="utf-8")
        merged.append(content)

    output_content = "\n\n".join(merged)

    output_name = f"dn-{(i//2)+1:02d}.md"
    output_path = OUTPUT_DIR / output_name

    output_path.write_text(output_content, encoding="utf-8")

    print(f"Created: {output_path}")

# %%
# scan mucluc
from pathlib import Path
import re

BASE_URL = "https://kinhnikaya.org"

# Danh sách các file mục lục
files = [
    "../docs/kinhtruongbo/c-pali-tmc-vi/mucluc.md",
    "../docs/kinhtruongbo/c-sujato-tmc-vi/index.md",
    "../docs/kinhtruongbo/pali/meta/mucluc.md",
    "../docs/kinhtruongbo/pali-vi/meta/mucluc.md",
    "../docs/kinhtruongbo/sujato-en/meta/mucluc.md",
    "../docs/kinhtruongbo/sujato-vi/meta/mucluc.md"

]

# Regex bắt URL trong markdown:
# - [Tiêu đề](/duong-dan)
link_pattern = re.compile(r"\[[^\]]+\]\((/[^)]+)\)")

for file in files:
    content = Path(file).read_text(encoding="utf-8")

    for match in link_pattern.finditer(content):
        path = match.group(1)
        print(f"'{BASE_URL}{path}',")
# Out:
# 'https://kinhnikaya.org/kinhtruongbo/c-pali-tmc-vi/dnc-001-kinh-pham-vong',
# 'https://kinhnikaya.org/kinhtruongbo/c-pali-tmc-vi/dnc-002-kinh-sa-mon-qua',
# 'https://kinhnikaya.org/kinhtruongbo/c-pali-tmc-vi/dnc-003-kinh-ambattha-a-ma-tru',
# 'https://kinhnikaya.org/kinhtruongbo/c-pali-tmc-vi/dnc-004-kinh-sonadanda-chung-duc',
# 'https://kinhnikaya.org/kinhtruongbo/c-pali-tmc-vi/dnc-005-kinh-kutadanta-cuu-la-dan-dau',
# 'https://kinhnikaya.org/kinhtruongbo/c-pali-tmc-vi/dnc-006-kinh-mahali',
# 'https://kinhnikaya.org/kinhtruongbo/c-pali-tmc-vi/dnc-007-kinh-jaliya',
# 'https://kinhnikaya.org/kinhtruongbo/c-pali-tmc-vi/dnc-008-kinh-ca-diep-su-tu-hong',
# 'https://kinhnikaya.org/kinhtruongbo/c-pali-tmc-vi/dnc-009-kinh-potthapada-bo-sa-ba-lau',
# 'https://kinhnikaya.org/kinhtruongbo/c-pali-tmc-vi/dnc-010-kinh-subha-tu-ba',
# 'https://kinhnikaya.org/kinhtruongbo/c-pali-tmc-vi/dnc-011-kinh-kevaddha-kien-co',
# ...

# %%
# ngày 22-6-xong kinh trường bộ
import requests

url = "https://api.indexnow.org/IndexNow"

payload = {
    "host": "https://kinhnikaya.org",
    "key": "f58fc73f53ad426f8d04871bf52b72ad",
    "keyLocation": "https://kinhnikaya.org/f58fc73f53ad426f8d04871bf52b72ad.txt",

"urlList": [
 'https://kinhnikaya.org/kinhtruongbo/c-pali-tmc-vi/dnc-001-kinh-pham-vong',
'https://kinhnikaya.org/kinhtruongbo/c-pali-tmc-vi/dnc-002-kinh-sa-mon-qua',
'https://kinhnikaya.org/kinhtruongbo/c-pali-tmc-vi/dnc-003-kinh-ambattha-a-ma-tru',
'https://kinhnikaya.org/kinhtruongbo/c-pali-tmc-vi/dnc-004-kinh-sonadanda-chung-duc',
'https://kinhnikaya.org/kinhtruongbo/c-pali-tmc-vi/dnc-005-kinh-kutadanta-cuu-la-dan-dau',
'https://kinhnikaya.org/kinhtruongbo/c-pali-tmc-vi/dnc-006-kinh-mahali',
'https://kinhnikaya.org/kinhtruongbo/c-pali-tmc-vi/dnc-007-kinh-jaliya',
'https://kinhnikaya.org/kinhtruongbo/c-pali-tmc-vi/dnc-008-kinh-ca-diep-su-tu-hong',
'https://kinhnikaya.org/kinhtruongbo/c-pali-tmc-vi/dnc-009-kinh-potthapada-bo-sa-ba-lau',
'https://kinhnikaya.org/kinhtruongbo/c-pali-tmc-vi/dnc-010-kinh-subha-tu-ba',
'https://kinhnikaya.org/kinhtruongbo/c-pali-tmc-vi/dnc-011-kinh-kevaddha-kien-co',
'https://kinhnikaya.org/kinhtruongbo/c-pali-tmc-vi/dnc-012-kinh-lohicca-lo-hi-gia',
'https://kinhnikaya.org/kinhtruongbo/c-pali-tmc-vi/dnc-013-kinh-tevijja-tam-minh',
'https://kinhnikaya.org/kinhtruongbo/c-pali-tmc-vi/dnc-014-kinh-dai-bon',
'https://kinhnikaya.org/kinhtruongbo/c-pali-tmc-vi/dnc-015-kinh-dai-duyen',
'https://kinhnikaya.org/kinhtruongbo/c-pali-tmc-vi/dnc-016-kinh-dai-bat-niet-ban',
'https://kinhnikaya.org/kinhtruongbo/c-pali-tmc-vi/dnc-017-kinh-dai-thien-kien-vuong',
'https://kinhnikaya.org/kinhtruongbo/c-pali-tmc-vi/dnc-018-kinh-xa-ni-sa',
'https://kinhnikaya.org/kinhtruongbo/c-pali-tmc-vi/dnc-019-kinh-dai-dien-ton',
'https://kinhnikaya.org/kinhtruongbo/c-pali-tmc-vi/dnc-020-kinh-dai-hoi',
'https://kinhnikaya.org/kinhtruongbo/c-pali-tmc-vi/dnc-021-kinh-de-thich-so-van',
'https://kinhnikaya.org/kinhtruongbo/c-pali-tmc-vi/dnc-022-kinh-dai-niem-xu',
'https://kinhnikaya.org/kinhtruongbo/c-pali-tmc-vi/dnc-023-kinh-te-tuc',
'https://kinhnikaya.org/kinhtruongbo/c-pali-tmc-vi/dnc-024-kinh-ba-le',
'https://kinhnikaya.org/kinhtruongbo/c-pali-tmc-vi/dnc-025-kinh-uu-dam-ba-la-su-tu-hong',
'https://kinhnikaya.org/kinhtruongbo/c-pali-tmc-vi/dnc-026-kinh-chuyen-luan-thanh-vuong-su-tu-hong',
'https://kinhnikaya.org/kinhtruongbo/c-pali-tmc-vi/dnc-027-kinh-khoi-the-nhan-bon',
'https://kinhnikaya.org/kinhtruongbo/c-pali-tmc-vi/dnc-028-kinh-tu-hoan-hy',
'https://kinhnikaya.org/kinhtruongbo/c-pali-tmc-vi/dnc-029-kinh-thanh-tinh',
'https://kinhnikaya.org/kinhtruongbo/c-pali-tmc-vi/dnc-030-kinh-tuong',
'https://kinhnikaya.org/kinhtruongbo/c-pali-tmc-vi/dnc-031-kinh-giao-tho-thi-ca-la-viet',
'https://kinhnikaya.org/kinhtruongbo/c-pali-tmc-vi/dnc-032-kinh-a-sa-nang-chi',
'https://kinhnikaya.org/kinhtruongbo/c-pali-tmc-vi/dnc-033-kinh-phung-tung',
'https://kinhnikaya.org/kinhtruongbo/c-pali-tmc-vi/dnc-034-kinh-thap-thuong',
'https://kinhnikaya.org/kinhtruongbo/pali/dn-001-brahmajalasutta.md',
'https://kinhnikaya.org/kinhtruongbo/pali/dn-002-samannaphalasutta.md',
'https://kinhnikaya.org/kinhtruongbo/pali/dn-003-ambatthasutta.md',
'https://kinhnikaya.org/kinhtruongbo/pali/dn-004-sonadandasutta.md',
'https://kinhnikaya.org/kinhtruongbo/pali/dn-005-kutadantasutta.md',
'https://kinhnikaya.org/kinhtruongbo/pali/dn-006-mahalisutta.md',
'https://kinhnikaya.org/kinhtruongbo/pali/dn-007-jaliyasutta.md',
'https://kinhnikaya.org/kinhtruongbo/pali/dn-008-mahasihanadasutta.md',
'https://kinhnikaya.org/kinhtruongbo/pali/dn-009-potthapadasutta.md',
'https://kinhnikaya.org/kinhtruongbo/pali/dn-010-subhasutta.md',
'https://kinhnikaya.org/kinhtruongbo/pali/dn-011-kevattasutta.md',
'https://kinhnikaya.org/kinhtruongbo/pali/dn-012-lohiccasutta.md',
'https://kinhnikaya.org/kinhtruongbo/pali/dn-013-tevijjasutta.md',
'https://kinhnikaya.org/kinhtruongbo/pali/dn-014-mahapadanasutta.md',
'https://kinhnikaya.org/kinhtruongbo/pali/dn-015-mahanidanasutta.md',
'https://kinhnikaya.org/kinhtruongbo/pali/dn-016-mahaparinibbanasutta.md',
'https://kinhnikaya.org/kinhtruongbo/pali/dn-017-mahasudassanasutta.md',
'https://kinhnikaya.org/kinhtruongbo/pali/dn-018-janavasabhasutta.md',
'https://kinhnikaya.org/kinhtruongbo/pali/dn-019-mahagovindasutta.md',
'https://kinhnikaya.org/kinhtruongbo/pali/dn-020-mahasamayasutta.md',
'https://kinhnikaya.org/kinhtruongbo/pali/dn-021-sakkapanhasutta.md',
'https://kinhnikaya.org/kinhtruongbo/pali/dn-022-mahasatipatthanasutta.md',
'https://kinhnikaya.org/kinhtruongbo/pali/dn-023-payasisutta.md',
'https://kinhnikaya.org/kinhtruongbo/pali/dn-024-pathikasutta.md',
'https://kinhnikaya.org/kinhtruongbo/pali/dn-025-udumbarikasutta.md',
'https://kinhnikaya.org/kinhtruongbo/pali/dn-026-cakkavattisutta.md',
'https://kinhnikaya.org/kinhtruongbo/pali/dn-027-aggannasutta.md',
'https://kinhnikaya.org/kinhtruongbo/pali/dn-028-sampasadaniyasutta.md',
'https://kinhnikaya.org/kinhtruongbo/pali/dn-029-pasadikasutta.md',
'https://kinhnikaya.org/kinhtruongbo/pali/dn-030-lakkhanasutta.md',
'https://kinhnikaya.org/kinhtruongbo/pali/dn-031-singalasutta.md',
'https://kinhnikaya.org/kinhtruongbo/pali/dn-032-atanatiyasutta.md',
'https://kinhnikaya.org/kinhtruongbo/pali/dn-033-sangitisutta.md',
'https://kinhnikaya.org/kinhtruongbo/pali/dn-034-dasuttarasutta.md',
'https://kinhnikaya.org/kinhtruongbo/pali-vi/dn-001-kinh-luoi-troi.md',
'https://kinhnikaya.org/kinhtruongbo/pali-vi/dn-002-kinh-ve-thanh-qua-cua-nguoi-tu-hanh.md',
'https://kinhnikaya.org/kinhtruongbo/pali-vi/dn-003-kinh-ambattha.md',
'https://kinhnikaya.org/kinhtruongbo/pali-vi/dn-004-kinh-sonadanda.md',
'https://kinhnikaya.org/kinhtruongbo/pali-vi/dn-005-kinh-kutadanta.md',
'https://kinhnikaya.org/kinhtruongbo/pali-vi/dn-006-kinh-mahali.md',
'https://kinhnikaya.org/kinhtruongbo/pali-vi/dn-007-kinh-jaliya.md',
'https://kinhnikaya.org/kinhtruongbo/pali-vi/dn-008-kinh-tieng-gam-su-tu.md',
'https://kinhnikaya.org/kinhtruongbo/pali-vi/dn-009-kinh-potthapada.md',
'https://kinhnikaya.org/kinhtruongbo/pali-vi/dn-010-kinh-subha.md',
'https://kinhnikaya.org/kinhtruongbo/pali-vi/dn-011-kinh-kevatta.md',
'https://kinhnikaya.org/kinhtruongbo/pali-vi/dn-012-kinh-lohicca.md',
'https://kinhnikaya.org/kinhtruongbo/pali-vi/dn-013-kinh-tevijja-kinh-ba-minh.md',
'https://kinhnikaya.org/kinhtruongbo/pali-vi/dn-014-kinh-dai-ve-nguon-goc.md',
'https://kinhnikaya.org/kinhtruongbo/pali-vi/dn-015-kinh-dai-ve-quan-he-phu-thuoc.md',
'https://kinhnikaya.org/kinhtruongbo/pali-vi/dn-016-kinh-dai-ve-bat-niet-ban.md',
'https://kinhnikaya.org/kinhtruongbo/pali-vi/dn-017-kinh-ai-thien-kien-vuong.md',
'https://kinhnikaya.org/kinhtruongbo/pali-vi/dn-018-kinh-janavasabha.md',
'https://kinhnikaya.org/kinhtruongbo/pali-vi/dn-019-kinh-dai-ve-govinda.md',
'https://kinhnikaya.org/kinhtruongbo/pali-vi/dn-020-kinh-ai-hoi.md',
'https://kinhnikaya.org/kinhtruongbo/pali-vi/dn-021-kinh-sakkapanha-e-thich-so-van.md',
'https://kinhnikaya.org/kinhtruongbo/pali-vi/dn-022-kinh-dai-ve-bon-noi-chu-tam.md',
'https://kinhnikaya.org/kinhtruongbo/pali-vi/dn-023-kinh-payasi.md',
'https://kinhnikaya.org/kinhtruongbo/pali-vi/dn-024-kinh-pathika.md',
'https://kinhnikaya.org/kinhtruongbo/pali-vi/dn-025-kinh-udumbarika.md',
'https://kinhnikaya.org/kinhtruongbo/pali-vi/dn-026-kinh-vua-chuyen-luan.md',
'https://kinhnikaya.org/kinhtruongbo/pali-vi/dn-027-kinh-ve-nguon-goc-toi-so.md',
'https://kinhnikaya.org/kinhtruongbo/pali-vi/dn-028-kinh-niem-tin-trong-sang.md',
'https://kinhnikaya.org/kinhtruongbo/pali-vi/dn-029-kinh-ro-rang-va-mach-lac.md',
'https://kinhnikaya.org/kinhtruongbo/pali-vi/dn-030-kinh-ac-iem.md',
'https://kinhnikaya.org/kinhtruongbo/pali-vi/dn-031-kinh-singala.md',
'https://kinhnikaya.org/kinhtruongbo/pali-vi/dn-032-kinh-atanatiya.md',
'https://kinhnikaya.org/kinhtruongbo/pali-vi/dn-033-kinh-tung-oc-cung-nhau.md',
'https://kinhnikaya.org/kinhtruongbo/pali-vi/dn-034-kinh-den-muoi.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-en/intro/01-the-suttacentral-editions-series.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-en/intro/02-preface-to-long-discourses.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-en/intro/03-a-reader-s-guide-to-the-pali-suttas.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-en/intro/04-the-long-discourses-dhamma-as-literature-and-compilation.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-en/intro/05-acknowledgements.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-en/intro/06-summary-of-contents.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-en/intro/07-colophon.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-en/dn-001-the-divine-net-brahmajalasutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-en/dn-002-the-fruits-of-the-ascetic-life-samannaphalasutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-en/dn-003-with-ambattha-ambatthasutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-en/dn-004-with-sonadanda-sonadandasutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-en/dn-005-with-kutadanta-kutadantasutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-en/dn-006-with-mahali-mahalisutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-en/dn-007-with-jaliya-jaliyasutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-en/dn-008-the-lion-s-roar-to-the-naked-ascetic-kassapa-mahasihanadasutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-en/dn-009-with-potthapada-potthapadasutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-en/dn-010-with-subha-subhasutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-en/dn-011-with-kevaddha-kevattasutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-en/dn-012-with-lohicca-lohiccasutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-en/dn-013-experts-in-the-three-vedas-tevijjasutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-en/dn-014-the-great-discourse-on-traces-left-behind.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-en/dn-015-the-great-discourse-on-causation.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-en/dn-016-the-great-discourse-on-the-buddha-s-extinguishment.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-en/dn-017-king-mahasudassana.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-en/dn-018-with-janavasabha.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-en/dn-019-the-great-steward.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-en/dn-020-the-great-congregation.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-en/dn-021-sakka-s-questions.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-en/dn-022-the-longer-discourse-on-mindfulness-meditation.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-en/dn-023-with-payasi.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-en/dn-024-about-patikaputta-pathikasutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-en/dn-025-the-lion-s-roar-at-the-monastery-of-lady-udumbarika-udumbarikasutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-en/dn-026-the-wheel-turning-monarch-cakkavattisutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-en/dn-027-what-came-first-aggannasutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-en/dn-028-inspiring-confidence-sampasadaniyasutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-en/dn-029-an-impressive-discourse-pasadikasutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-en/dn-030-the-marks-of-a-great-man-lakkhanasutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-en/dn-031-advice-to-sigalaka-singalasutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-en/dn-032-the-atanatiya-protection-atanatiyasutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-en/dn-033-reciting-in-concert-sangitisutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-en/dn-034-up-to-ten-dasuttarasutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-vi/intro/01-the-suttacentral-editions-series.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-vi/intro/02-preface-to-long-discourses.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-vi/intro/03-a-reader-s-guide-to-the-pali-suttas.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-vi/intro/04-the-long-discourses-dhamma-as-literature-and-compilation.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-vi/intro/05-acknowledgements.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-vi/intro/06-summary-of-contents.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-vi/intro/07-colophon.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-001-the-divine-net-brahmajalasutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-002-the-fruits-of-the-ascetic-life-samannaphalasutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-003-with-ambattha-ambatthasutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-004-with-sonadanda-sonadandasutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-005-with-kutadanta-kutadantasutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-006-with-mahali-mahalisutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-007-with-jaliya-jaliyasutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-008-the-lion-s-roar-to-the-naked-ascetic-kassapa-mahasihanadasutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-009-with-potthapada-potthapadasutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-010-with-subha-subhasutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-011-with-kevaddha-kevattasutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-012-with-lohicca-lohiccasutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-013-experts-in-the-three-vedas-tevijjasutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-014-the-great-discourse-on-traces-left-behind.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-015-the-great-discourse-on-causation.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-016-the-great-discourse-on-the-buddha-s-extinguishment.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-017-king-mahasudassana.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-018-with-janavasabha.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-019-the-great-steward.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-020-the-great-congregation.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-021-sakka-s-questions.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-022-the-longer-discourse-on-mindfulness-meditation.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-023-with-payasi.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-024-about-patikaputta-pathikasutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-025-the-lion-s-roar-at-the-monastery-of-lady-udumbarika-udumbarikasutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-026-the-wheel-turning-monarch-cakkavattisutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-027-what-came-first-aggannasutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-028-inspiring-confidence-sampasadaniyasutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-029-an-impressive-discourse-pasadikasutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-030-the-marks-of-a-great-man-lakkhanasutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-031-advice-to-sigalaka-singalasutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-032-the-atanatiya-protection-atanatiyasutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-033-reciting-in-concert-sangitisutta.md',
'https://kinhnikaya.org/kinhtruongbo/sujato-vi/dn-034-up-to-ten-dasuttarasutta.md'
]
}

headers = {
    "Content-Type": "application/json; charset=utf-8"
}

response = requests.post(
    url,
    json=payload,
    headers=headers
)

print("Status:", response.status_code)
print("Response:", response.text)
## xong kinh trường bộ - thích minh châu và 3 level, làm tiếp theo: tất cả các kinh thích minh châu ?
# Out:
# Status: 200
# Response:

# %%
response
# Out:
# <Response [202]>
