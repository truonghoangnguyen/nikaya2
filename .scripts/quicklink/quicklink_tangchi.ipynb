# %%
import os, re, json

# Thư mục chứa các file .md",",

# Thư mục chứa các file .md",",
SOURCE_DIR = "../../docs/kinhtangchi/sujato-vi"

# Danh sách tên file .md",", cần xử lý (chỉ tên file, không cần đường dẫn đầy đủ)
key = "key"
FILES = [
{"filename": "an-01-001-the-chapter-on-what-occupies-the-mind.md", "key": 1},
{"filename": "an-01-002-the-chapter-on-giving-up-the-hindrances.md", key:1 },
{"filename": "an-01-003-the-chapter-on-the-useless-mind.md", key: 1},
{"filename": "an-01-004-the-chapter-on-the-wild-mind.md", key: 1},
{"filename": "an-01-005-the-chapter-on-a-spike.md", key: 1},
{"filename": "an-01-006-the-chapter-on-a-finger-snap.md", key: 1},
{"filename": "an-01-007-the-chapter-on-arousing-energy.md", key:1 },
{"filename": "an-01-008-the-chapter-on-good-friends.md", key: 1},
{"filename": "an-01-009-the-chapter-on-negligence.md", key: 1},
{"filename": "an-01-010-the-chapter-on-negligence-2nd.md", key: 1},
{"filename": "an-01-011-the-chapter-on-not-the-teaching.md", key: 1},
{"filename": "an-01-012-the-chapter-on-non-offense.md", key: 1},
{"filename": "an-01-013-the-chapter-on-one-person.md", key: 1},
{"filename": "an-01-014-seven-chapters-on-the-foremost-persons.md", key: 1},
{"filename": "an-01-015-three-chapters-on-the-impossible.md", key: 1},
{"filename": "an-01-016-four-chapters-on-one-thing-1.md", key: 1},
{"filename": "an-01-017-four-chapters-on-one-thing-2.md", key: 1},
{"filename": "an-01-018-four-chapters-on-one-thing-3.md", key: 1},
{"filename": "an-01-019-four-chapters-on-one-thing-4.md", key: 1},
{"filename": "an-01-020-the-chapter-on-inspiring-qualities.md", key: 1},
{"filename": "an-01-021-another-chapter-on-a-finger-snap.md", key: 1},
{"filename": "an-01-022-the-chapter-on-mindfulness-of-the-body.md", key: 1},
{"filename": "an-01-023-the-chapter-on-freedom-from-death.md", key: 1},
{"filename": "an-02-001-the-chapter-on-punishments.md", key: 2},
{"filename": "an-02-002-the-chapter-on-disciplinary-issues.md", key: 2},
{"filename": "an-02-003-the-chapter-on-fools.md", key: 2},
{"filename": "an-02-004-the-chapter-on-the-peaceful-mind.md", key: 2},
{"filename": "an-02-005-the-chapter-on-assemblies.md", key: 2},
{"filename": "an-02-006-the-chapter-on-persons.md", key: 2},
{"filename": "an-02-007-the-chapter-on-happiness.md", key: 2},
{"filename": "an-02-008-the-chapter-with-a-foundation.md", key: 2},
{"filename": "an-02-009-the-chapter-on-two-things.md", key: 2},
{"filename": "an-02-010-the-chapter-on-fools.md", key: 2},
{"filename": "an-02-011-the-chapter-on-hopes-that-are-hard-to-give-up.md", key: 2},
{"filename": "an-02-012-the-chapter-on-aspiration.md", key: 2},
{"filename": "an-02-013-the-chapter-on-giving.md", key: 2},
{"filename": "an-02-014-the-chapter-on-welcome.md", key: 2},
{"filename": "an-02-015-the-chapter-on-attainment.md", key: 2},
{"filename": "an-02-016-the-chapter-of-abbreviated-texts-beginning-with-anger.md", key: 2},
{"filename": "an-02-017-the-chapter-of-abbreviated-texts-on-monastic-law.md", key: 2},
{"filename": "an-03-001-the-chapter-on-fools.md", key: 3},
{"filename": "an-03-002-the-chapter-on-the-chariot-maker.md", key: 3},
{"filename": "an-03-003-the-chapter-on-persons.md", key: 3},
{"filename": "an-03-004-the-chapter-on-messengers-of-the-gods.md", key: 3},
{"filename": "an-09-004-the-great-chapter.md", key: 9},
{"filename": "an-09-005-the-chapter-on-similarity.md", key: 9},
{"filename": "an-09-006-the-chapter-on-a-safe-place.md", key: 9},
{"filename": "an-09-007-the-chapter-on-mindfulness-meditation.md", key: 9},
{"filename": "an-09-008-the-chapter-on-right-efforts.md", key: 9},
{"filename": "an-09-009-the-chapter-on-bases-of-psychic-power.md", key: 9},
{"filename": "an-09-010-the-chapter-on-bases-of-psychic-power2.md", key: 9},
{"filename": "an-10-001-the-chapter-on-benefits.md", key: 10},
{"filename": "an-10-002-the-chapter-on-a-protector.md", key: 10},
{"filename": "an-10-003-the-great-chapter.md", key: 10},
{"filename": "an-10-004-the-chapter-with-upali.md", key: 10},
{"filename": "an-10-005-the-chapter-on-abuse.md", key: 10},
{"filename": "an-10-006-the-chapter-on-your-own-mind.md", key: 10},
{"filename": "an-10-007-the-chapter-on-pairs.md", key: 10},
{"filename": "an-10-008-the-chapter-on-if-you-want.md", key: 10},
{"filename": "an-10-009-the-chapter-on-senior-mendicants.md", key: 10},
{"filename": "an-10-010-the-chapter-with-upali.md", key: 10},
{"filename": "an-10-011-the-chapter-on-perceptions-for-ascetics.md", key: 10},
{"filename": "an-10-012-the-chapter-on-the-ceremony-of-descent.md", key: 10},
{"filename": "an-10-013-the-chapter-on-purified.md", key: 10},
{"filename": "an-10-014-the-chapter-on-good.md", key: 10},
{"filename": "an-10-015-the-chapter-on-the-noble-path.md", key: 10},
{"filename": "an-10-016-the-chapter-on-persons.md", key: 10},
{"filename": "an-10-017-the-chapter-with-janussoni.md", key: 10},
{"filename": "an-10-018-the-chapter-on-good.md", key: 10},
{"filename": "an-10-019-the-chapter-on-the-noble-path.md", key: 10},
{"filename": "an-10-020-another-chapter-on-persons.md", key: 10},
{"filename": "an-10-021-the-chapter-on-the-body-born-of-deeds.md", key: 10},
{"filename": "an-10-022-the-chapter-on-similarity.md", key: 10},
{"filename": "an-11-001-the-chapter-on-dependence.md", key: 11},
{"filename": "an-11-002-the-chapter-on-recollection.md", key: 11},
{"filename": "an-11-003-the-chapter-on-similarity.md", key: 11},

]
# Heading cấp mấy được coi là "đoạn con" (### = 3, ## = 2, ...)
CHILD_HEADING_LEVEL = 1


# (Tùy chọn) đặt tiêu đề tay cho 1 top-index thay vì lấy H1 của file đầu tiên gặp.
# Hữu ích cho case gộp nhiều file (AN) vì H1 của từng phẩm không đại diện cho cả nipata.
NIPATA_TITLES = {
    # "1": "AN 1. Chương Một Pháp",
}

# Heading cấp mấy được coi là "đoạn con" (### = 3, ## = 2, ...)
CHILD_HEADING_LEVEL = 3

# %% [markdown]
# ## 2. Các hàm xử lý

# %%
import os
import re

CHILD_HEADING_LEVEL = 6  # Tùy chỉnh cấp độ heading con mong muốn
TOP_INDEX_RE = re.compile(r"^[a-z]+-0*(\d+)")
H1_RE = re.compile(r"^#\s+(.*)$", re.MULTILINE)
CHILD_RE = re.compile(r"^#{2,%d}\s+(.*)$" % CHILD_HEADING_LEVEL)

# Regex tìm anchor dạng {#...} ở cuối heading
ANCHOR_RE = re.compile(r"\{#([^}]+)\}\s*$")


def top_index_from_slug(slug):
    m = TOP_INDEX_RE.match(slug.lower())
    return m.group(1) if m else None


def extract_h1(text):
    m = H1_RE.search(text)
    return m.group(1).strip() if m else None


def process_file(dirpath, spec, items, warnings):
    filename = spec["filename"]
    file_range = spec.get("range")  # (start, end) hoặc None
    key_override = spec.get("key")  # ghi đè top-index, dùng khi tên file không theo
                                     # đúng quy ước "prefix-SỐ-..." (vd KN: "kn-001-tap-1-...")

    slug = filename[:-3] if filename.endswith(".md") else filename
    filepath = os.path.join(dirpath, filename)
    if not os.path.isfile(filepath):
        warnings.append(f"{filename}: không tìm thấy file, bỏ qua")
        return

    with open(filepath, "r", encoding="utf-8") as f:
        text = f.read()

    top_index = key_override # top_index_from_slug(slug)
    title = extract_h1(text)

    item = {}
    item["title"] = title if title else "??? (không tìm thấy H1)"
    if not title:
        warnings.append(f"{filename}: không tìm thấy dòng H1 (# ...)")
    item["slug"] = slug
    item["children"] = []  # Đổi thành mảng chứa danh sách anchor

    for line in text.splitlines():
        m = CHILD_RE.match(line)
        if not m:
            continue
        heading_text = m.group(1).strip()

        # Bắt anchor dạng {#...}
        anchor_match = ANCHOR_RE.search(heading_text)
        if anchor_match:
            anchor = anchor_match.group(1).strip()
            item["children"].append(anchor)

    if top_index is None:
        warnings.append(
            f"{filename}: không suy ra được số thứ tự từ tên file, cần điền tay"
        )
        key = f"???({slug})"
    else:
        key = str(int(top_index))
        if key in items:
            warnings.append(
                f'{filename}: trùng key "{key}" với 1 file khác — kiểm tra lại'
            )

    items[key] = item

# %% [markdown]
# ## 3. Chạy xử lý

# %%
items = {}
warnings = []

for fn in FILES:
    process_file(SOURCE_DIR, fn, items, warnings)

if warnings:
    print("⚠️  Cảnh báo:")
    for w in warnings:
        print(" -", w)
else:
    print("Không có cảnh báo.")
# Out:
# ⚠️  Cảnh báo:
#  - an-01-002-the-chapter-on-giving-up-the-hindrances.md: trùng key "1" với 1 file khác — kiểm tra lại
#  - an-01-003-the-chapter-on-the-useless-mind.md: trùng key "1" với 1 file khác — kiểm tra lại
#  - an-01-004-the-chapter-on-the-wild-mind.md: trùng key "1" với 1 file khác — kiểm tra lại
#  - an-01-005-the-chapter-on-a-spike.md: trùng key "1" với 1 file khác — kiểm tra lại
#  - an-01-006-the-chapter-on-a-finger-snap.md: trùng key "1" với 1 file khác — kiểm tra lại
#  - an-01-007-the-chapter-on-arousing-energy.md: trùng key "1" với 1 file khác — kiểm tra lại
#  - an-01-008-the-chapter-on-good-friends.md: trùng key "1" với 1 file khác — kiểm tra lại
#  - an-01-009-the-chapter-on-negligence.md: trùng key "1" với 1 file khác — kiểm tra lại
#  - an-01-010-the-chapter-on-negligence-2nd.md: trùng key "1" với 1 file khác — kiểm tra lại
#  - an-01-011-the-chapter-on-not-the-teaching.md: trùng key "1" với 1 file khác — kiểm tra lại
# ...

# %%
output = {
    "folder": "kinhtangchi",
    "editions": {
        "tmc": {
            "label": "Sujato",
            "path": "sujato-vi",
            "index_length": "1",
            "items": items,
        }
    },
}

print(json.dumps(output, ensure_ascii=False, indent=2))

# %% [markdown]
# ## 5. (Tùy chọn) Ghi ra file JSON
#
# Chạy cell dưới nếu muốn lưu kết quả ra file thay vì chỉ copy từ output ở trên.

# %%
OUT_PATH = "quicklink-data.generated.json"

with open(OUT_PATH, "w", encoding="utf-8") as f:
    json.dump(output, f, ensure_ascii=False, indent=2)

print(f"Đã ghi: {OUT_PATH}")
