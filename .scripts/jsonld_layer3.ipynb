# %%
# ── CONFIG ────────────────────────────────────────────────────────────────────
# Mỗi entry gồm các trường khác nhau giữa các bản dịch:
#   slug        : path segment dùng trong URL  (vd: 'thichminhchau')
#   name        : tiêu đề đầy đủ của trang bản dịch
#   bookEdition : giá trị bookEdition
#   image       : tên file ảnh bìa (sẽ ghép vào https://kinhnikaya.org/covers/)
#   inLanguage  : mã ngôn ngữ ('vi', 'en', 'pi', …)
#   translator  : dict gồm name + sameAs (hoặc list dict nếu nhiều người)
#   breadcrumb3 : label hiển thị ở breadcrumb vị trí 3

BASE = "https://kinhnikaya.org"

thichminhchau = {
    "name":        "Tỷ kheo Thích Minh Châu",
    "bookEdition": "Bản dịch Tỷ kheo Thích Minh Châu",
    "inLanguage":  "vi",
    "translator": {
        "name":   "Thích Minh Châu",
        "sameAs": "https://vi.wikipedia.org/wiki/Thích_Minh_Châu"
    },
    "breadcrumb3": "Tỷ kheo Thích Minh Châu"
}

tranphuonglan = {
    "name":        "GS Trần Phương Lan",
    "bookEdition": "Bản dịch Giáo sư Trần Phương Lan",
    "inLanguage":  "vi",
    "translator": {
        "name":   "Trần Phương Lan",
        "sameAs": "https://quangduc.com/author/about/931/gs-tran-phuong-lan"
    },
    "breadcrumb3": "GS Trần Phương Lan"
}

sujato_vi={
    "name":        "Bhikkhu Sujato (Tiếng Việt)",
    "bookEdition": "Bhikkhu Sujato (Tiếng Việt)",
    "translator": {
        "name":   "Bhikkhu Sujato",
        "sameAs": "https://en.wikipedia.org/wiki/Bhante_Sujato"
    },
    "breadcrumb3": "Bhikkhu Sujato (Tiếng Việt)"
}

sujato_en={
    "name":        "Long Discourses - A faithful translation of the Dīgha Nikāya — Bhikkhu Sujato",
    "bookEdition": "Bhikkhu Sujato",
    "inLanguage":  "en",
    "translator": {
        "name":   "Bhikkhu Sujato",
        "sameAs": "https://en.wikipedia.org/wiki/Bhante_Sujato"
    },
    "breadcrumb3": "Bhikkhu Sujato"
}


CONFIG = {
    # ── Kinh Trường Bộ ────────────────────────────────────────────────────────
    "kinhtruongbo": {
        "label": "Kinh Trường Bộ",          # tên bộ kinh (breadcrumb vị trí 2)
        "versions": {
            "thichminhchau": {
                "name":        "Tỷ kheo Thích Minh Châu",
                "bookEdition": "Bản dịch Tỷ kheo Thích Minh Châu",
                "image":       "kinhtruongbo.webp",
                "inLanguage":  "vi",
                "translator": {
                    "name":   "Thích Minh Châu",
                    "sameAs": "https://vi.wikipedia.org/wiki/Thích_Minh_Châu"
                },
                "breadcrumb3": "Tỷ kheo Thích Minh Châu"
            },
            "sujato-vi": {
                "name":        "Bhikkhu Sujato (Tiếng Việt)",
                "bookEdition": "Bhikkhu Sujato (Tiếng Việt)",
                "image":       "kinhtruongbo-sujato.webp",
                "inLanguage":  "vi",
                "translator": {
                    "name":   "Bhikkhu Sujato",
                    "sameAs": "https://en.wikipedia.org/wiki/Bhante_Sujato"
                },
                "breadcrumb3": "Bhikkhu Sujato (Tiếng Việt)"
            },
            "sujato-en": {
                "name":        "Long Discourses - A faithful translation of the Dīgha Nikāya — Bhikkhu Sujato",
                "bookEdition": "Bhikkhu Sujato",
                "image":       "kinhtruongbo-sujato.webp",
                "inLanguage":  "en",
                "translator": {
                    "name":   "Bhikkhu Sujato",
                    "sameAs": "https://en.wikipedia.org/wiki/Bhante_Sujato"
                },
                "breadcrumb3": "Bhikkhu Sujato"
            }
        }
    },

    # ── Kinh Trung Bộ ─────────────────────────────────────────────────────────
    "kinhtrungbo": {
        "label": "Kinh Trung Bộ",
        "versions": {
            "c-nm-tmc-vi": {
                "name":        "Bản đọc song song: Ñāṇamoli & Bodhi — Thích Minh Châu",
                "bookEdition": "Bhikkhu Ñāṇamoli & Bhikkhu Bodhi - Tỷ kheo Thích Minh Châu",
                "image":       "kinhtrungbo.webp",
                "inLanguage":  "vi",
                "translator": [
                    {"name": "Bhikkhu Ñāṇamoli", "sameAs": "https://en.wikipedia.org/wiki/Bhikkhu_Ñāṇamoli"},
                    {"name": "Bhikkhu Bodhi",    "sameAs": "https://en.wikipedia.org/wiki/Bhikkhu_Bodhi"},
                    {"name": "Thích Minh Châu", "sameAs": "https://vi.wikipedia.org/wiki/Thích_Minh_Châu"}
                ],
                "breadcrumb3": "Bản đọc song song Ñāṇamoli & Bodhi và Thích Minh Châu"
            },
            "thichminhchau": {
                "name":        thichminhchau["name"],
                "bookEdition": thichminhchau["bookEdition"],
                "image":       "kinhtrungbo.webp",
                "inLanguage":  "vi",
                "translator":  thichminhchau["translator"],
                "breadcrumb3": thichminhchau["breadcrumb3"]
            },
            "nanamoli-bodhi-vi": {
                "name":        "Bhikkhu Ñāṇamoli & Bhikkhu Bodhi (Tiếng Việt)",
                "bookEdition": "Bhikkhu Ñāṇamoli & Bhikkhu Bodhi",
                "image":       "kinhtrungbo-nanamoli.webp",
                "inLanguage":  "vi",
                "translator": [
                    {"name": "Bhikkhu Ñāṇamoli", "sameAs": "https://en.wikipedia.org/wiki/Bhikkhu_Ñāṇamoli"},
                    {"name": "Bhikkhu Bodhi",    "sameAs": "https://en.wikipedia.org/wiki/Bhikkhu_Bodhi"}
                ],
                "breadcrumb3": "Bhikkhu Ñāṇamoli & Bhikkhu Bodhi"
            },
            "nanamoli-bodhi-en": {
                "name":        "The Middle Length Discourses of the Buddha: A Translation of the Majjhima Nikaya - Bhikkhu Ñāṇamoli & Bhikkhu Bodhi",
                "bookEdition": "Bhikkhu Ñāṇamoli & Bhikkhu Bodhi",
                "image":       "kinhtrungbo-nanamoli.webp",
                "inLanguage":  "en",
                "translator": [
                    {"name": "Bhikkhu Ñāṇamoli", "sameAs": "https://en.wikipedia.org/wiki/Bhikkhu_Ñāṇamoli"},
                    {"name": "Bhikkhu Bodhi",    "sameAs": "https://en.wikipedia.org/wiki/Bhikkhu_Bodhi"}
                ],
                "breadcrumb3": "Bhikkhu Ñāṇamoli & Bhikkhu Bodhi"
            },
            "pali-vi-not-yet": {
                "name":        "Kinh Trung Bộ — Dịch từ tiếng Pali",
                "bookEdition": "Majjhima Nikaya",
                "image":       "kinhtrungbo.webp",
                "inLanguage":  "vi",
                "translator": {"name": "Trương Hoàng Nguyên", "sameAs": "https://github.com/truonghoangnguyen/nikaya2"},
                "breadcrumb3": "Dịch từ tiếng Pali"
            },
        }
    },

    # ── Kinh Tương Ưng ────────────────────────────────────────────────────────
    "kinhtuongung": {
        "label": "Kinh Tương Ưng Bộ",
        "versions": {
            "thichminhchau": {
                "name":        thichminhchau["name"],
                "bookEdition": thichminhchau["bookEdition"],
                "image":       "kinhtuongung.webp",
                "inLanguage":  "vi",
                "translator":  thichminhchau["translator"],
                "breadcrumb3": thichminhchau["breadcrumb3"],
            },
            "sujato-vi": {
                "name":        sujato_vi["name"],
                "bookEdition": sujato_vi["bookEdition"],
                "image":       "kinhtuongung.webp",
                "inLanguage":  "vi",
                "translator":  sujato_vi["translator"],
                "breadcrumb3": sujato_vi["breadcrumb3"],
            },
            "sujato-en": {
                "name":        "Linked Discourses A plain translation of the Saṁyutta Nikāya -  Bhikkhu Sujato",
                "bookEdition": sujato_en["bookEdition"],
                "image":       "kinhtuongung-sujato.webp",
                "inLanguage":  "en",
                "translator":   sujato_en["translator"],
                "breadcrumb3": sujato_en["breadcrumb3"]
            },
            "c-sujato-tmc-vi":{
                "name":        "Bản đọc song song: Bhikkhu Sujato - Thích Minh Châu",
                "bookEdition": "Bhikkhu Sujato - Tỷ kheo Thích Minh Châu",
                "image":       "kinhtuongung.webp",
                "inLanguage":  "vi",
                "translator": [
                    sujato_vi["translator"],
                    thichminhchau["translator"]
                ],
                "breadcrumb3": "Bản đọc song song Bhikkhu Sujato và Thích Minh Châu"
            }
        }
    },
    "kinhtieubo": {
        "label": "Kinh Tiểu Bộ",
        "versions": {
            "thichminhchau": {
                "name":        thichminhchau["name"],
                "bookEdition": thichminhchau["bookEdition"],
                "image":       "kinhtieubo.webp",
                "inLanguage":  "vi",
                "translator":  thichminhchau["translator"],
                "breadcrumb3": thichminhchau["breadcrumb3"],
            },
            "tranphuonglan": {
                "name":        sujato_vi["name"],
                "bookEdition": sujato_vi["bookEdition"],
                "image":       "kinhtieubo.webp",
                "inLanguage":  "vi",
                "translator":  sujato_vi["translator"],
                "breadcrumb3": sujato_vi["breadcrumb3"],
            },

        }
    },
    "kinhtangchi": {
        "label": "Kinh Tăng Chi Bộ",
        "versions": {
            "thichminhchau": {
                "name":        thichminhchau["name"],
                "bookEdition": thichminhchau["bookEdition"],
                "image":       "kinhtangchi.webp",
                "inLanguage":  "vi",
                "translator":  thichminhchau["translator"],
                "breadcrumb3": thichminhchau["breadcrumb3"],
            },
            "sujato-vi": {
                "name":        sujato_vi["name"],
                "bookEdition": sujato_vi["bookEdition"],
                "image":       "kinhtangchi-sujato.webp",
                "inLanguage":  "vi",
                "translator":  sujato_vi["translator"],
                "breadcrumb3": sujato_vi["breadcrumb3"],
            },
            "sujato-en": {
                "name":        "Numbered Discourses A sensible translation of the Aṅguttara Nikāya - Bhikkhu Sujato",
                "bookEdition": sujato_en["bookEdition"],
                "image":       "kinhtangchi-sujato.webp",
                "inLanguage":  "en",
                "translator":   sujato_en["translator"],
                "breadcrumb3": sujato_en["breadcrumb3"]
            },
            "c-sujato-tmc-vi":{
                "name":        "Bản đọc song song: Bhikkhu Sujato - Thích Minh Châu",
                "bookEdition": "Bhikkhu Sujato - Tỷ kheo Thích Minh Châu",
                "image":       "kinhtangchi.webp",
                "inLanguage":  "vi",
                "translator": [
                    sujato_vi["translator"],
                    thichminhchau["translator"]
                ],
                "breadcrumb3": "Bản đọc song song Bhikkhu Sujato và Thích Minh Châu"
            }
        }
    }
}

# %%
import json
import os
import re
from pathlib import Path

BASE_URL = "https://kinhnikaya.org"

def build_has_part(folder_path):

    # input: folder path
    file_path = Path(folder_path)

    # ưu tiên: mucluc.md -> meta/mucluc.md
    mucluc_1 = file_path / "mucluc.md"
    mucluc_2 = file_path / "meta" / "mucluc.md"

    if mucluc_1.exists():
        md_file = mucluc_1
    elif mucluc_2.exists():
        md_file = mucluc_2
    else:
        raise FileNotFoundError(
            f"Không tìm thấy '{mucluc_1}' hoặc '{mucluc_2}'"
        )


    text = Path(md_file).read_text(encoding="utf-8")

    # lấy tất cả markdown links
    links = re.findall(r'\[.*?\]\((.*?)\)', text)

    result = []

    for link in links:
        path = link.strip()

        # bỏ .md ở cuối, trừ intro/outro
        if "/intro/" in path or "/outro/" in path:
            suffix = "#article"
            final_path = path
        else:
            suffix = "#chapter"
            final_path = re.sub(r'\.md$', '', path)

        result.append(
            { "@id": f'{BASE_URL}{final_path}{suffix}'}
        )
    return result


def build_layer3_jsonld(kinh: str, author: str, has_part: list | None = None) -> dict:
    """
    Sinh JSON-LD tầng 3 cho trang bản dịch.

    Parameters
    ----------
    kinh    : key bộ kinh trong CONFIG, vd 'kinhtruongbo'
    author  : key bản dịch,            vd 'thichminhchau' hoặc 'sujato-vi'
    has_part: list các dict {"@id": "...#chapter"} — để trống thì bỏ qua field hasPart
    """
    bộ    = CONFIG[kinh]
    ver   = bộ["versions"][author]
    slug  = author                        # vd: 'thichminhchau'
    label = bộ["label"]                   # vd: 'Kinh Trường Bộ'

    page_url    = f"{BASE}/{kinh}/{slug}/"
    book_id     = f"{page_url}#book"
    parent_url  = f"{BASE}/{kinh}/"
    abstract_id = f"{parent_url}#book"

    # ── translator: hỗ trợ 1 người (dict) hoặc nhiều người (list) ──
    raw_tr = ver["translator"]
    if isinstance(raw_tr, list):
        translator_field = [
            {"@type": "Person", **t} for t in raw_tr
        ]
    else:
        translator_field = {"@type": "Person", **raw_tr}

    # ── Book node ──────────────────────────────────────────────────
    book = {
        "@type": "Book",
        "@id":   book_id,
        "mainEntityOfPage": {
            "@type": "WebPage",
            "@id":   page_url
        },
        "name":        ver["name"],
        "bookEdition": ver["bookEdition"],
        "url":         page_url,
        "inLanguage":  ver["inLanguage"],
        "isAccessibleForFree": True,
        "publisher":   {"@id": f"{BASE}/#org"},
        "image":       f"{BASE}/covers/{ver['image']}",
        "author": {
            "@type":  "Person",
            "name":   "Gotama Buddha",
            "sameAs": "https://en.wikipedia.org/wiki/Gautama_Buddha"
        },
        "translator":        translator_field,
        "translationOfWork": {"@id": abstract_id}
    }


    if has_part:
        book["hasPart"] = has_part
    else:
        index_file = f"../docs/{kinh}/{author}"
        book["hasPart"] =  build_has_part(index_file)


    # ── BreadcrumbList ─────────────────────────────────────────────
    breadcrumb = {
        "@type": "BreadcrumbList",
        "itemListElement": [
            {"@type": "ListItem", "position": 1, "name": "Trang chủ",  "item": f"{BASE}/"},
            {"@type": "ListItem", "position": 2, "name": label,         "item": parent_url},
            {"@type": "ListItem", "position": 3, "name": ver["breadcrumb3"], "item": page_url}
        ]
    }

    return {
        "@context": "https://schema.org",
        "@graph": [book, breadcrumb]
    }


# ── CHẠY ──────────────────────────────────────────────────────────────────────
kinh   = "kinhtieubo"
author = "thichminhchau"   # đổi thành 'sujato-vi', 'sujato-en', …
#has_part = [{}] # tu build has_part

result = build_layer3_jsonld(kinh, author)

# JSON-LD pretty format
jsonld_result = json.dumps(result, ensure_ascii=False, indent=2)

# dữ liệu từ CONFIG
bộ   = CONFIG[kinh]
ver  = bộ["versions"][author]

label        = bộ["label"]
breadcrumb3  = ver["breadcrumb3"]
image        = ver["image"]
name         = ver["name"]
markdown_output = f"""---
title: {label} - {name}
head:
  - - script
    - type: application/ld+json
    - |
       {jsonld_result.replace(chr(10), chr(10) + '        ')}

---

<h1 style="text-align: center;">{label}</h1>
<h2 style="text-align: center;">{name}</h2>
<br>
<a href="/{kinh}/{author}/--mục đầu tiên">
<figure style="text-align: center;">
    <img src="/covers/{image}" style="max-width:400px;width:100%;display:block;margin:0 auto;" alt="{label} {name}">
</figure>
</a>

<br/>
<hr/>
<br/>
<h2 style="text-align: center;">Mục Lục</h2>
<br/>

<!--@include: ./meta/mucluc.md-->
"""

print(markdown_output)

# print(json.dumps(result, ensure_ascii=False, indent=2))
# Out:
# ---
# title: Kinh Tiểu Bộ - Tỷ kheo Thích Minh Châu
# head:
#   - - script
#     - type: application/ld+json
#     - |
#        {
#           "@context": "https://schema.org",
#           "@graph": [
#             {
#               "@type": "Book",
#               "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/#book",
#               "mainEntityOfPage": {
#                 "@type": "WebPage",
#                 "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/"
#               },
#               "name": "Tỷ kheo Thích Minh Châu",
#               "bookEdition": "Bản dịch Tỷ kheo Thích Minh Châu",
#               "url": "https://kinhnikaya.org/kinhtieubo/thichminhchau/",
#               "inLanguage": "vi",
#               "isAccessibleForFree": true,
#               "publisher": {
#                 "@id": "https://kinhnikaya.org/#org"
#               },
#               "image": "https://kinhnikaya.org/covers/kinhtieubo.webp",
#               "author": {
#                 "@type": "Person",
#                 "name": "Gotama Buddha",
#                 "sameAs": "https://en.wikipedia.org/wiki/Gautama_Buddha"
#               },
#               "translator": {
#                 "@type": "Person",
#                 "name": "Thích Minh Châu",
#                 "sameAs": "https://vi.wikipedia.org/wiki/Thích_Minh_Châu"
#               },
#               "translationOfWork": {
#                 "@id": "https://kinhnikaya.org/kinhtieubo/#book"
#               },
#               "hasPart": [
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-001-tap-1-kinh-tieu-tung#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-002-tap-2-kinh-phap-cu#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-003-tap-3-kinh-phat-tu-thuyet#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-004-tap-3-chuong-1-pham-bo-de#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-005-tap-3-chuong-2-pham-muccalinda#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-006-tap-3-chuong-3-pham-nanda#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-007-tap-3-chuong-4-pham-meghiya#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-008-tap-3-chuong-5-pham-truong-lao-sona#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-009-tap-3-chuong-6-pham-sanh-ra-da-mu#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-010-tap-3-chuong-7-pham-nho#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-011-tap-3-chuong-8-pham-pataligamiya#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-012-tap-4-kinh-phat-thuyet-nhu-vay#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-013-tap-4-chuong-1-tap-mot-phap#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-014-tap-4-chuong-2-tap-hai-phap#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-015-tap-4-chuong-3-tap-ba-phap#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-016-tap-4-chuong-4-tap-bon-phap#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-017-tap-5-kinh-tap#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-018-tap-5-chuong-1-pham-ran-uragavagga#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-019-tap-5-chuong-2-tieu-pham#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-020-tap-5-chuong-3-dai-pham#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-021-tap-5-chuong-4-pham-tam#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-022-tap-5-chuong-5-tren-duong-den-bo-ben-kia#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-023-tap-6-thien-cung-su#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-024-tap-6-pham-1-lau-dai-nu-gioi#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-025-tap-6-pham-2-cittalata#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-026-tap-6-pham-3-paricchattaka#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-027-tap-6-pham-4-do-sam#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-028-tap-6-pham-5-dai-xa#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-029-tap-6-pham-6-payasi#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-030-tap-6-pham-7-sunikkhitta#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-031-tap-7-nga-quy-su#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-032-tap-7-pham-1-con-ran#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-033-tap-7-pham-2-ubbari#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-034-tap-7-pham-3-tieu-pham#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-035-tap-7-pham-4-dai-pham#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-036-tap-8-truong-lao-tang-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-037-tap-8-chuong-1-pham-mot-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-038-tap-8-chuong-2-pham-hai-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-039-tap-8-chuong-3-pham-ba-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-040-tap-8-chuong-4-pham-bon-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-041-tap-8-chuong-5-pham-nam-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-042-tap-8-chuong-6-pham-sau-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-043-tap-8-chuong-7-pham-bay-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-044-tap-8-chuong-8-pham-tam-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-045-tap-8-chuong-9-pham-chin-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-046-tap-8-chuong-10-pham-muoi-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-046-tap-8-chuong-11-pham-muoi-mot-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-046-tap-8-chuong-12-pham-muoi-hai-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-047-tap-8-chuong-13-pham-muoi-ba-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-047-tap-8-chuong-14-pham-muoi-bon-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-047-tap-8-chuong-15-pham-muoi-lam-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-047-tap-8-chuong-16-pham-hai-muoi-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-048-tap-8-chuong-17-pham-ba-muoi-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-049-tap-8-chuong-18-pham-bon-muoi-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-050-tap-8-chuong-19-pham-nam-muoi-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-051-tap-8-chuong-20-pham-sau-muoi-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-052-tap-8-chuong-21-pham-bay-muoi-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-053-tap-9-truong-lao-ni-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-054-tap-9-pham-1-tap-mot-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-055-tap-9-pham-2-tap-hai-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-056-tap-9-pham-3-tap-ba-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-057-tap-9-pham-4-tap-bon-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-058-tap-9-pham-5-tap-nam-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-059-tap-9-pham-6-tap-sau-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-060-tap-9-pham-7-tap-bay-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-061-tap-9-pham-8-tap-tam-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-062-tap-9-pham-9-tap-chin-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-063-tap-9-pham-10-tap-muoi-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-064-tap-9-pham-11-tap-muoi-hai-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-065-tap-9-pham-12-tap-muoi-sau-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-066-tap-9-pham-13-tap-hai-muoi-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-067-tap-9-pham-14-tap-ba-muoi-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-068-tap-9-pham-15-tap-bon-muoi-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-069-tap-9-pham-16-dai-pham#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-070-tap-10-chuyen-tien-than-duc-phat#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-071-tap-10-p1-chuong-i#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-072-tap-10-p1-pham-apannaka#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-073-tap-10-p1-pham-gioi#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-074-tap-10-p1-pham-kurunga#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-075-tap-10-p1-pham-kulavaka#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-076-tap-10-p1-pham-loi-ai#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-077-tap-10-p1-pham-asimsa#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-078-tap-10-p1-pham-nu-nhan#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-079-tap-10-p1-pham-varana#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-080-tap-10-p1-pham-apayimha#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-081-tap-10-p1-pham-litta#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-082-tap-10-p1-pham-parossata#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-083-tap-10-p1-pham-hamsa#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-084-tap-10-p1-pham-kusanali#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-085-tap-10-p1-pham-asampadana#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-086-tap-10-p1-pham-kakantaka#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-087-tap-10-p2-chuong-2#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-088-tap-10-p2-pham-dalha#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-089-tap-10-p2-pham-santahava#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-090-tap-10-p2-pham-thien-phap#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-091-tap-10-p2-pham-asadisa#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-092-tap-10-p2-pham-ruhaka#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-093-tap-10-p2-pham-natamdaiha#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-094-tap-10-p2-pham-biranatthambahaka-dam-co-thom#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-095-tap-10-p2-pham-kasava#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-096-tap-10-p2-pham-upahana#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-097-tap-10-p2-pham-sigala-cho-rung#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-098-tap-10-p3-chuong-iii-chuong-iv#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-099-tap-10-p3-chuong-3-pham-sankappa#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-100-tap-10-p3-chuong-3-pham-kosya#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-101-tap-10-p3-chuong-3-pham-ba-bai-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-102-tap-10-p3-chuong-3-pham-ba-bai-ke-tt#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-103-tap-10-p3-chuong-3-pham-ba-bai-ke-tt#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-104-tap-10-p3-chuong-4-pham-bon-bai-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-105-tap-10-p3-chuong-4-pham-bon-bai-ke-tt#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-106-tap-10-p3-chuong-4-pham-bon-bai-ke-tt#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-107-tap-10-p3-chuong-4-pham-bon-bai-ke-tt#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-108-tap-10-p3-chuong-4-pham-bon-bai-ke-tt#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-109-tap-10-p4-chuong-v-den-chuong-xxii#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-110-tap-10-p4-chuong-v-pham-nam-bai-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-111-tap-10-p4-chuong-vi-pham-sau-bai-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-112-tap-10-p4-chuong-vii-pham-bay-bai-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-113-tap-10-p4-chuong-viii-pham-tam-bai-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-114-tap-10-p4-chuong-ix-pham-chin-bai-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-115-tap-10-p4-chuong-x-pham-muoi-bai-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-116-tap-10-p4-chuong-xi-pham-muoi-mot-bai-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-117-tap-10-p4-chuong-xii-pham-muoi-hai-bai-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-118-tap-10-p5-chuong-xiii-den-chuong-xx#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-119-tap-10-p5-chuong-xiii-pham-muoi-ba-bai-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-120-tap-10-p5-chuong-xiv-tap-pham#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-121-tap-10-p5-chuong-xv-pham-hai-muoi-bai-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-122-tap-10-p5-chuong-xvi-pham-ba-muoi-bai-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-123-tap-10-p5-chuong-xvii-pham-bon-muoi-bai-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-124-tap-10-p5-chuong-xviii-pham-nam-muoi-bai-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-125-tap-10-p5-chuong-xix-pham-sau-muoi-bai-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-126-tap-10-p5-chuong-xx-pham-bay-muoi-bai-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-127-tap-10-p6-chuong-xxi-chuong-xxii#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-128-tap-10-p6-chuong-xxi-pham-tam-muoi-bai-ke#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-129-tap-10-p6-chuong-xxi-pham-tam-muoi-bai-ke-tt#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-130-tap-10-p6-chuong-xxii-dai-pham-1#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-131-tap-10-p6-chuong-xxii-dai-pham-2#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-132-tap-10-p6-chuong-xxii-dai-pham-3#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-133-tap-10-p6-chuong-xxii-dai-pham-4#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-134-tap-10-p6-chuong-xxii-dai-pham-5#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-135-tap-10-p6-chuong-xxii-dai-pham-6#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-136-tap-10-p6-chuong-xxii-dai-pham-7#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-137-tap-10-p6-chuong-xxii-dai-pham-8#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtieubo/thichminhchau/kn-138-tap-10-p6-chuong-xxii-dai-pham-9#chapter"
#                 }
#               ]
#             },
#             {
#               "@type": "BreadcrumbList",
#               "itemListElement": [
#                 {
#                   "@type": "ListItem",
#                   "position": 1,
#                   "name": "Trang chủ",
#                   "item": "https://kinhnikaya.org/"
#                 },
#                 {
#                   "@type": "ListItem",
#                   "position": 2,
#                   "name": "Kinh Tiểu Bộ",
#                   "item": "https://kinhnikaya.org/kinhtieubo/"
#                 },
#                 {
#                   "@type": "ListItem",
#                   "position": 3,
#                   "name": "Tỷ kheo Thích Minh Châu",
#                   "item": "https://kinhnikaya.org/kinhtieubo/thichminhchau/"
#                 }
#               ]
#             }
#           ]
#         }
#
# ---
#
# <h1 style="text-align: center;">Kinh Tiểu Bộ</h1>
# <h2 style="text-align: center;">Tỷ kheo Thích Minh Châu</h2>
# <br>
# <a href="/kinhtieubo/thichminhchau/--mục đầu tiên">
# <figure style="text-align: center;">
#     <img src="/covers/kinhtieubo.webp" style="max-width:400px;width:100%;display:block;margin:0 auto;" alt="Kinh Tiểu Bộ Tỷ kheo Thích Minh Châu">
# </figure>
# </a>
#
# <br/>
# <hr/>
# <br/>
# <h2 style="text-align: center;">Mục Lục</h2>
# <br/>
#
# <!--@include: ./meta/mucluc.md-->
