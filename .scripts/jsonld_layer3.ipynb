# %%
# ── CONFIG ────────────────────────────────────────────────────────────────────
# Mỗi entry gồm các trường khác nhau giữa các bản dịch:
#   slug        : path segment dùng trong URL  (vd: 'thichminhchau')
#   name        : tiêu đề đầy đủ của trang bản dịch
#   bookEdition : giá trị bookEdition
#   image       : tên file ảnh bìa (sẽ ghép vào https://kinhnikaya.org/covers/)
#   inLanguage  : mã ngôn ngữ ('vi', 'en', 'pi', …)
#   translator  : dict gồm name + sameAs (hoặc list dict nếu nhiều người)
#   breadcrumb3 : label hiển thị ở breadcrumb vị trí 3

BASE = "https://kinhnikaya.org"

CONFIG = {
    # ── Kinh Trường Bộ ────────────────────────────────────────────────────────
    "kinhtruongbo": {
        "label": "Kinh Trường Bộ",          # tên bộ kinh (breadcrumb vị trí 2)
        "versions": {
            "thichminhchau": {
                "name":        "Tỷ kheo Thích Minh Châu",
                "bookEdition": "Bản dịch Tỷ kheo Thích Minh Châu",
                "image":       "kinhtruongbo.webp",
                "inLanguage":  "vi",
                "translator": {
                    "name":   "Thích Minh Châu",
                    "sameAs": "https://vi.wikipedia.org/wiki/Thích_Minh_Châu"
                },
                "breadcrumb3": "Tỷ kheo Thích Minh Châu"
            },
            "sujato-vi": {
                "name":        "Bhikkhu Sujato (Tiếng Việt)",
                "bookEdition": "Bhikkhu Sujato (Tiếng Việt)",
                "image":       "kinhtruongbo-sujato.webp",
                "inLanguage":  "vi",
                "translator": {
                    "name":   "Bhikkhu Sujato",
                    "sameAs": "https://en.wikipedia.org/wiki/Bhante_Sujato"
                },
                "breadcrumb3": "Bhikkhu Sujato (Tiếng Việt)"
            },
            "sujato-en": {
                "name":        "Long Discourses - A faithful translation of the Dīgha Nikāya — Bhikkhu Sujato",
                "bookEdition": "Bhikkhu Sujato",
                "image":       "kinhtruongbo-sujato.webp",
                "inLanguage":  "en",
                "translator": {
                    "name":   "Bhikkhu Sujato",
                    "sameAs": "https://en.wikipedia.org/wiki/Bhante_Sujato"
                },
                "breadcrumb3": "Bhikkhu Sujato"
            }
        }
    },

    # ── Kinh Trung Bộ ─────────────────────────────────────────────────────────
    "kinhtrungbo": {
        "label": "Kinh Trung Bộ",
        "versions": {
            "c-nm-tmc-vi": {
                "name":        "Bản đọc song song: Ñāṇamoli & Bodhi — Thích Minh Châu",
                "bookEdition": "Bhikkhu Ñāṇamoli & Bhikkhu Bodhi - Tỷ kheo Thích Minh Châu",
                "image":       "kinhtrungbo.webp",
                "inLanguage":  "vi",
                "translator": [
                    {"name": "Bhikkhu Ñāṇamoli", "sameAs": "https://en.wikipedia.org/wiki/Bhikkhu_Ñāṇamoli"},
                    {"name": "Bhikkhu Bodhi",    "sameAs": "https://en.wikipedia.org/wiki/Bhikkhu_Bodhi"},
                    {"name": "Thích Minh Châu", "sameAs": "https://vi.wikipedia.org/wiki/Thích_Minh_Châu"}
                ],
                "breadcrumb3": "Bản đọc song song Ñāṇamoli & Bodhi và Thích Minh Châu"
            },
            "thichminhchau": {
                "name":        "Tỷ kheo Thích Minh Châu",
                "bookEdition": "Bản dịch Tỷ kheo Thích Minh Châu",
                "image":       "kinhtrungbo.webp",
                "inLanguage":  "vi",
                "translator": {
                    "name":   "Thích Minh Châu",
                    "sameAs": "https://vi.wikipedia.org/wiki/Thích_Minh_Châu"
                },
                "breadcrumb3": "Tỷ kheo Thích Minh Châu"
            },
            "nanamoli-bodhi-vi": {
                "name":        "Bhikkhu Ñāṇamoli & Bhikkhu Bodhi (Tiếng Việt)",
                "bookEdition": "Bhikkhu Ñāṇamoli & Bhikkhu Bodhi",
                "image":       "kinhtrungbo-nanamoli.webp",
                "inLanguage":  "vi",
                "translator": [
                    {"name": "Bhikkhu Ñāṇamoli", "sameAs": "https://en.wikipedia.org/wiki/Bhikkhu_Ñāṇamoli"},
                    {"name": "Bhikkhu Bodhi",    "sameAs": "https://en.wikipedia.org/wiki/Bhikkhu_Bodhi"}
                ],
                "breadcrumb3": "Bhikkhu Ñāṇamoli & Bhikkhu Bodhi"
            },
            "nanamoli-bodhi-en": {
                "name":        "The Middle Length Discourses of the Buddha: A Translation of the Majjhima Nikaya - Bhikkhu Ñāṇamoli & Bhikkhu Bodhi",
                "bookEdition": "Bhikkhu Ñāṇamoli & Bhikkhu Bodhi",
                "image":       "kinhtrungbo-nanamoli.webp",
                "inLanguage":  "en",
                "translator": [
                    {"name": "Bhikkhu Ñāṇamoli", "sameAs": "https://en.wikipedia.org/wiki/Bhikkhu_Ñāṇamoli"},
                    {"name": "Bhikkhu Bodhi",    "sameAs": "https://en.wikipedia.org/wiki/Bhikkhu_Bodhi"}
                ],
                "breadcrumb3": "Bhikkhu Ñāṇamoli & Bhikkhu Bodhi"
            },
            "pali-vi-not-yet": {
                "name":        "Kinh Trung Bộ — Dịch từ tiếng Pali",
                "bookEdition": "Majjhima Nikaya",
                "image":       "kinhtrungbo.webp",
                "inLanguage":  "vi",
                "translator": {"name": "Trương Hoàng Nguyên", "sameAs": "https://github.com/truonghoangnguyen/nikaya2"},
                "breadcrumb3": "Dịch từ tiếng Pali"
            },
        }
    },

    # ── Kinh Tương Ưng ────────────────────────────────────────────────────────
    "kinhtuongung": {
        "label": "Kinh Tương Ưng",
        "versions": {
            "thichminhchau": {
                "name":        "Kinh Tương Ưng — Tỷ kheo Thích Minh Châu",
                "bookEdition": "Bản dịch Tỷ kheo Thích Minh Châu",
                "image":       "kinhtuongung.webp",
                "inLanguage":  "vi",
                "translator": {
                    "name":   "Thích Minh Châu",
                    "sameAs": "https://vi.wikipedia.org/wiki/Thích_Minh_Châu"
                },
                "breadcrumb3": "Tỷ kheo Thích Minh Châu"
            }
        }
    }
}

# %%
import json
import os
import re
from pathlib import Path

BASE_URL = "https://kinhnikaya.org"

def build_has_part(folder_path):

    # input: folder path
    file_path = Path(folder_path)

    # ưu tiên: mucluc.md -> meta/mucluc.md
    mucluc_1 = file_path / "mucluc.md"
    mucluc_2 = file_path / "meta" / "mucluc.md"

    if mucluc_1.exists():
        md_file = mucluc_1
    elif mucluc_2.exists():
        md_file = mucluc_2
    else:
        raise FileNotFoundError(
            f"Không tìm thấy '{mucluc_1}' hoặc '{mucluc_2}'"
        )


    text = Path(md_file).read_text(encoding="utf-8")

    # lấy tất cả markdown links
    links = re.findall(r'\[.*?\]\((.*?)\)', text)

    result = []

    for link in links:
        path = link.strip()

        # bỏ .md ở cuối, trừ intro/outro
        if "/intro/" in path or "/outro/" in path:
            suffix = "#article"
            final_path = path
        else:
            suffix = "#chapter"
            final_path = re.sub(r'\.md$', '', path)

        result.append(
            { "@id": f'{BASE_URL}{final_path}{suffix}'}
        )
    return result


def build_layer3_jsonld(kinh: str, author: str, has_part: list | None = None) -> dict:
    """
    Sinh JSON-LD tầng 3 cho trang bản dịch.

    Parameters
    ----------
    kinh    : key bộ kinh trong CONFIG, vd 'kinhtruongbo'
    author  : key bản dịch,            vd 'thichminhchau' hoặc 'sujato-vi'
    has_part: list các dict {"@id": "...#chapter"} — để trống thì bỏ qua field hasPart
    """
    bộ    = CONFIG[kinh]
    ver   = bộ["versions"][author]
    slug  = author                        # vd: 'thichminhchau'
    label = bộ["label"]                   # vd: 'Kinh Trường Bộ'

    page_url    = f"{BASE}/{kinh}/{slug}/"
    book_id     = f"{page_url}#book"
    parent_url  = f"{BASE}/{kinh}/"
    abstract_id = f"{parent_url}#book"

    # ── translator: hỗ trợ 1 người (dict) hoặc nhiều người (list) ──
    raw_tr = ver["translator"]
    if isinstance(raw_tr, list):
        translator_field = [
            {"@type": "Person", **t} for t in raw_tr
        ]
    else:
        translator_field = {"@type": "Person", **raw_tr}

    # ── Book node ──────────────────────────────────────────────────
    book = {
        "@type": "Book",
        "@id":   book_id,
        "mainEntityOfPage": {
            "@type": "WebPage",
            "@id":   page_url
        },
        "name":        ver["name"],
        "bookEdition": ver["bookEdition"],
        "url":         page_url,
        "inLanguage":  ver["inLanguage"],
        "isAccessibleForFree": True,
        "publisher":   {"@id": f"{BASE}/#org"},
        "image":       f"{BASE}/covers/{ver['image']}",
        "author": {
            "@type":  "Person",
            "name":   "Gotama Buddha",
            "sameAs": "https://en.wikipedia.org/wiki/Gautama_Buddha"
        },
        "translator":        translator_field,
        "translationOfWork": {"@id": abstract_id}
    }


    if has_part:
        book["hasPart"] = has_part
    else:
        index_file = f"../docs/{kinh}/{author}"
        book["hasPart"] =  build_has_part(index_file)


    # ── BreadcrumbList ─────────────────────────────────────────────
    breadcrumb = {
        "@type": "BreadcrumbList",
        "itemListElement": [
            {"@type": "ListItem", "position": 1, "name": "Trang chủ",  "item": f"{BASE}/"},
            {"@type": "ListItem", "position": 2, "name": label,         "item": parent_url},
            {"@type": "ListItem", "position": 3, "name": ver["breadcrumb3"], "item": page_url}
        ]
    }

    return {
        "@context": "https://schema.org",
        "@graph": [book, breadcrumb]
    }


# ── CHẠY ──────────────────────────────────────────────────────────────────────
kinh   = "kinhtrungbo"
author = "nanamoli-bodhi-en"   # đổi thành 'sujato-vi', 'sujato-en', …
#has_part = [{}] # tu build has_part

result = build_layer3_jsonld(kinh, author)

# JSON-LD pretty format
jsonld_result = json.dumps(result, ensure_ascii=False, indent=2)

# dữ liệu từ CONFIG
bộ   = CONFIG[kinh]
ver  = bộ["versions"][author]

label        = bộ["label"]
breadcrumb3  = ver["breadcrumb3"]
image        = ver["image"]
name         = ver["name"]
markdown_output = f"""---
title: {label} - {name}
head:
  - - script
    - type: application/ld+json
    - |
       {jsonld_result.replace(chr(10), chr(10) + '        ')}

---

<h1 style="text-align: center;">{label}</h1>
<h2 style="text-align: center;">{name}</h2>
<br>
<a href="/{kinh}/{author}/-- mục đầu tiên">
<figure style="text-align: center;">
    <img src="/covers/{image}" style="max-width:400px;width:100%;display:block;margin:0 auto;" alt="{label} {name}">
</figure>
</a>

<br/>
<hr/>
<br/>
<h2 style="text-align: center;">Mục Lục</h2>
<br/>

<!--@include: ./meta/mucluc.md-->
"""

print(markdown_output)

# print(json.dumps(result, ensure_ascii=False, indent=2))
# Out:
# ---
# title: Kinh Trung Bộ - The Middle Length Discourses of the Buddha: A Translation of the Majjhima Nikaya - Bhikkhu Ñāṇamoli & Bhikkhu Bodhi
# head:
#   - - script
#     - type: application/ld+json
#     - |
#        {
#           "@context": "https://schema.org",
#           "@graph": [
#             {
#               "@type": "Book",
#               "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/#book",
#               "mainEntityOfPage": {
#                 "@type": "WebPage",
#                 "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/"
#               },
#               "name": "The Middle Length Discourses of the Buddha: A Translation of the Majjhima Nikaya - Bhikkhu Ñāṇamoli & Bhikkhu Bodhi",
#               "bookEdition": "Bhikkhu Ñāṇamoli & Bhikkhu Bodhi",
#               "url": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/",
#               "inLanguage": "en",
#               "isAccessibleForFree": true,
#               "publisher": {
#                 "@id": "https://kinhnikaya.org/#org"
#               },
#               "image": "https://kinhnikaya.org/covers/kinhtrungbo-nanamoli.webp",
#               "author": {
#                 "@type": "Person",
#                 "name": "Gotama Buddha",
#                 "sameAs": "https://en.wikipedia.org/wiki/Gautama_Buddha"
#               },
#               "translator": [
#                 {
#                   "@type": "Person",
#                   "name": "Bhikkhu Ñāṇamoli",
#                   "sameAs": "https://en.wikipedia.org/wiki/Bhikkhu_Ñāṇamoli"
#                 },
#                 {
#                   "@type": "Person",
#                   "name": "Bhikkhu Bodhi",
#                   "sameAs": "https://en.wikipedia.org/wiki/Bhikkhu_Bodhi"
#                 }
#               ],
#               "translationOfWork": {
#                 "@id": "https://kinhnikaya.org/kinhtrungbo/#book"
#               },
#               "hasPart": [
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/intro/01.preface.md#article"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/intro/02.introduction.md#article"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/intro/03.the-buddha-in-the-majjhima-nikaya.md#article"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/intro/04.the-four-noble-truths.md#article"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/intro/05.the-teaching-of-non-self.md#article"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/intro/06.the-origin-and-cessation-of-suffering.md#article"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/intro/07.nibbana.md#article"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/intro/08.the-way-to-the-cessation-of-suffering.md#article"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/intro/09.the-gradual-training.md#article"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/intro/10.approaches-to-meditation.md#article"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/intro/11.the-four-planes-of-liberation.md#article"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/intro/12.the-arahant.md#article"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/intro/13.kamma-and-rebirth.md#article"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/intro/14.the-buddha-and-his-contemporaries.md#article"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/intro/15.technical-notes.md#article"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/intro/16.dhamma.md#article"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/intro/17.sankhara.md#article"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/intro/18.namarupa.md#article"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/intro/19.brahma.md#article"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/intro/20.a-note-on-pronunciation.md#article"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/intro/21.a-summary-of-the-152-suttas.md#article"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/intro/22.part-two-the-middle-fifty-discourses.md#article"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/intro/23.part-three-the-final-fifty-discourses.md#article"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-001-the-root-of-all-things#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-002-all-the-taints#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-003-heirs-in-dhamma#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-004-fear-and-dread#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-005-without-blemishes#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-006-if-a-bhikkhu-should-wish#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-007-the-simile-of-the-cloth#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-008-effacement#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-009-right-view#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-010-the-foundations-of-mindfulness#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-011-the-shorter-discourse-on-the-lion-s-roar#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-012-the-greater-discourse-on-the-lion-s-roar#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-013-the-greater-discourse-on-the-mass-of-suffering#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-014-the-shorter-discourse-on-the-mass-of-suffering#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-015-inference#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-016-the-wilderness-in-the-heart#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-017-jungle-thickets#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-018-the-honeyball#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-019-two-kinds-of-thought#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-020-the-removal-of-distracting-thoughts#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-021-the-simile-of-the-saw#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-022-the-simile-of-the-snake#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-023-the-ant-hill#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-024-the-relay-chariots#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-025-the-bait#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-026-the-noble-search#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-027-the-shorter-discourse-on-the-simile-of-the-elephant-s-footprint#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-028-the-greater-discourse-on-the-simile-of-the-elephant-s-footprint#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-029-the-greater-discourse-on-the-simile-of-the-heartwood#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-030-the-shorter-discourse-on-the-simile-of-the-heartwood#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-031-the-shorter-discourse-in-gosinga#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-032-the-greater-discourse-in-gosinga#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-033-the-greater-discourse-on-the-cowherd#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-034-the-shorter-discourse-on-the-cowherd#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-035-the-shorter-discourse-to-saccaka#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-036-the-greater-discourse-to-saccaka#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-037-the-shorter-discourse-on-the-destruction-of-craving#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-038-the-greater-discourse-on-the-destruction-of-craving#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-039-the-greater-discourse-at-assapura#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-040-the-shorter-discourse-at-assapura#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-041-the-brahmins-of-sala#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-042-the-brahmins-of-veranja#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-043-the-greater-series-of-questions-and-answers#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-044-the-shorter-series-of-questions-and-answers#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-045-the-shorter-discourse-on-ways-of-undertaking-things#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-046-the-greater-discourse-on-ways-of-undertaking-things#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-047-the-inquirer#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-048-the-kosambians#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-049-the-invitation-of-a-brahma#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-050-the-rebuke-to-mara#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-051-to-kandaraka#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-052-the-man-from-atthakanagara#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-053-the-disciple-in-higher-training#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-054-to-potaliya#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-055-to-jivaka#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-056-to-upali#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-057-the-dog-duty-ascetic#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-058-to-prince-abhaya#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-059-the-many-kinds-of-feeling#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-060-the-incontrovertible-teaching#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-061-advice-to-rahula-at-ambalatthika#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-062-the-greater-discourse-of-advice-to-rahula#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-063-the-shorter-discourse-to-malunkyaputta#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-064-the-greater-discourse-to-malunkyaputta#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-065-to-bhaddali#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-066-the-simile-of-the-quail#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-067-at-catuma#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-068-at-nalakapana#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-069-gulissani#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-070-at-kitagiri#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-071-to-vacchagotta-on-the-threefold-true-knowledge#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-072-to-vacchagotta-on-fire#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-073-the-greater-discourse-to-vacchagotta#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-074-to-dighanakha#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-075-to-magandiya#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-076-to-sandaka#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-077-the-greater-discourse-to-sakuludayin#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-078-samanamanikaputta#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-079-the-shorter-discourse-to-sakuludayin#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-080-to-vekhanassa#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-081-ghatikara-the-potter#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-082-on-ratthapala#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-083-king-makhadeva#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-084-at-madhura#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-085-to-prince-bodhi#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-086-on-angulimala#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-087-born-from-those-who-are-dear#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-088-the-cloak#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-089-monuments-to-the-dhamma#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-090-at-kannakatthala#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-091-brahmayu#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-092-to-sela#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-093-to-assalayana#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-094-to-ghotamukha#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-095-with-canki#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-096-to-esukari#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-097-to-dhananjani#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-098-to-vasettha#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-099-to-subha#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-100-to-sangarava#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-101-at-devadaha#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-102-the-five-and-three#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-103-what-do-you-think-about-me#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-104-at-samagama#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-105-to-sunakkhatta#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-106-the-way-to-the-imperturbable#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-107-to-ganaka-moggallana#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-108-with-gopaka-moggallana#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-109-the-greater-discourse-on-the-full-moon-night#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-110-the-shorter-discourse-on-the-full-moon-night#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-111-one-by-one-as-they-occurred#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-112-the-sixfold-purity#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-113-the-true-man#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-114-to-be-cultivated-and-not-to-be-cultivated#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-115-the-many-kinds-of-elements#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-116-isigili-the-gullet-of-the-seers#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-117-the-great-forty#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-118-mindfulness-of-breathing#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-119-mindfulness-of-the-body#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-120-reappearance-by-aspiration#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-121-the-shorter-discourse-on-voidness#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-122-the-greater-discourse-on-voidness#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-123-wonderful-and-marvellous#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-124-bakkula#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-125-the-grade-of-the-tamed#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-126-bhumija#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-127-anuruddha#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-128-imperfections#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-129-fools-and-wise-men#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-130-the-divine-messengers#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-131-one-fortunate-attachment#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-132-ananda-and-one-fortunate-attachment#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-133-maha-kaccana-and-one-fortunate-attachment#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-134-lomasakangiya-and-one-fortunate-attachment#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-135-the-shorter-exposition-of-action#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-136-the-greater-exposition-of-action#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-137-the-exposition-of-the-sixfold-base#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-138-the-exposition-of-a-summary#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-139-the-exposition-of-non-conflict#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-140-the-exposition-of-the-elements#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-141-the-exposition-of-the-truths#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-142-the-exposition-of-offerings#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-143-advice-to-anathapinika#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-144-advice-to-channa#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-145-advice-to-punna#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-146-advice-from-nandaka#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-147-the-shorter-discourse-of-advice-to-rahula#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-148-the-six-sets-of-six#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-149-the-great-sixfold-base#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-150-to-the-nagaravindans#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-151-the-purification-of-almsfood#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/mn-152-the-development-of-the-faculties#chapter"
#                 }
#               ]
#             },
#             {
#               "@type": "BreadcrumbList",
#               "itemListElement": [
#                 {
#                   "@type": "ListItem",
#                   "position": 1,
#                   "name": "Trang chủ",
#                   "item": "https://kinhnikaya.org/"
#                 },
#                 {
#                   "@type": "ListItem",
#                   "position": 2,
#                   "name": "Kinh Trung Bộ",
#                   "item": "https://kinhnikaya.org/kinhtrungbo/"
#                 },
#                 {
#                   "@type": "ListItem",
#                   "position": 3,
#                   "name": "Bhikkhu Ñāṇamoli & Bhikkhu Bodhi",
#                   "item": "https://kinhnikaya.org/kinhtrungbo/nanamoli-bodhi-en/"
#                 }
#               ]
#             }
#           ]
#         }
#
# ---
#
# <h1 style="text-align: center;">Kinh Trung Bộ</h1>
# <h2 style="text-align: center;">The Middle Length Discourses of the Buddha: A Translation of the Majjhima Nikaya - Bhikkhu Ñāṇamoli & Bhikkhu Bodhi</h2>
# <br>
# <a href="/kinhtrungbo/nanamoli-bodhi-en/-- mục đầu tiên">
# <figure style="text-align: center;">
#     <img src="/covers/kinhtrungbo-nanamoli.webp" style="max-width:400px;width:100%;display:block;margin:0 auto;" alt="Kinh Trung Bộ The Middle Length Discourses of the Buddha: A Translation of the Majjhima Nikaya - Bhikkhu Ñāṇamoli & Bhikkhu Bodhi">
# </figure>
# </a>
#
# <br/>
# <hr/>
# <br/>
# <h2 style="text-align: center;">Mục Lục</h2>
# <br/>
#
# <!--@include: ./meta/mucluc.md-->
