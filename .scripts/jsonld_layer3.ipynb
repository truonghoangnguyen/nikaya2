# %%
# ── CONFIG ────────────────────────────────────────────────────────────────────
# Mỗi entry gồm các trường khác nhau giữa các bản dịch:
#   slug        : path segment dùng trong URL  (vd: 'thichminhchau')
#   name        : tiêu đề đầy đủ của trang bản dịch
#   bookEdition : giá trị bookEdition
#   image       : tên file ảnh bìa (sẽ ghép vào https://kinhnikaya.org/covers/)
#   inLanguage  : mã ngôn ngữ ('vi', 'en', 'pi', …)
#   translator  : dict gồm name + sameAs (hoặc list dict nếu nhiều người)
#   breadcrumb3 : label hiển thị ở breadcrumb vị trí 3

BASE = "https://kinhnikaya.org"

thichminhchau = {
    "name":        "Tỷ kheo Thích Minh Châu",
    "bookEdition": "Bản dịch Tỷ kheo Thích Minh Châu",
    "inLanguage":  "vi",
    "translator": {
        "name":   "Thích Minh Châu",
        "sameAs": "https://vi.wikipedia.org/wiki/Thích_Minh_Châu"
    },
    "breadcrumb3": "Tỷ kheo Thích Minh Châu"
}

tranphuonglan = {
    "name":        "GS Trần Phương Lan",
    "bookEdition": "Bản dịch Giáo sư Trần Phương Lan",
    "inLanguage":  "vi",
    "translator": {
        "name":   "Trần Phương Lan",
        "sameAs": "https://quangduc.com/author/about/931/gs-tran-phuong-lan"
    },
    "breadcrumb3": "GS Trần Phương Lan"
}

sujato_vi={
    "name":        "Bhikkhu Sujato (Tiếng Việt)",
    "bookEdition": "Bhikkhu Sujato (Tiếng Việt)",
    "translator": {
        "name":   "Bhikkhu Sujato",
        "sameAs": "https://en.wikipedia.org/wiki/Bhante_Sujato"
    },
    "breadcrumb3": "Bhikkhu Sujato (Tiếng Việt)"
}

sujato_en={
    "name":        "Long Discourses - A faithful translation of the Dīgha Nikāya — Bhikkhu Sujato",
    "bookEdition": "Bhikkhu Sujato",
    "inLanguage":  "en",
    "translator": {
        "name":   "Bhikkhu Sujato",
        "sameAs": "https://en.wikipedia.org/wiki/Bhante_Sujato"
    },
    "breadcrumb3": "Bhikkhu Sujato"
}


CONFIG = {
    # ── Kinh Trường Bộ ────────────────────────────────────────────────────────
    "kinhtruongbo": {
        "label": "Kinh Trường Bộ",          # tên bộ kinh (breadcrumb vị trí 2)
        "versions": {
            "thichminhchau": {
                "name":        "Tỷ kheo Thích Minh Châu",
                "bookEdition": "Bản dịch Tỷ kheo Thích Minh Châu",
                "image":       "kinhtruongbo.webp",
                "inLanguage":  "vi",
                "translator": {
                    "name":   "Thích Minh Châu",
                    "sameAs": "https://vi.wikipedia.org/wiki/Thích_Minh_Châu"
                },
                "breadcrumb3": "Tỷ kheo Thích Minh Châu"
            },
            "sujato-vi": {
                "name":        "Bhikkhu Sujato (Tiếng Việt)",
                "bookEdition": "Bhikkhu Sujato (Tiếng Việt)",
                "image":       "kinhtruongbo-sujato.webp",
                "inLanguage":  "vi",
                "translator": {
                    "name":   "Bhikkhu Sujato",
                    "sameAs": "https://en.wikipedia.org/wiki/Bhante_Sujato"
                },
                "breadcrumb3": "Bhikkhu Sujato (Tiếng Việt)"
            },
            "sujato-en": {
                "name":        "Long Discourses - A faithful translation of the Dīgha Nikāya — Bhikkhu Sujato",
                "bookEdition": "Bhikkhu Sujato",
                "image":       "kinhtruongbo-sujato.webp",
                "inLanguage":  "en",
                "translator": {
                    "name":   "Bhikkhu Sujato",
                    "sameAs": "https://en.wikipedia.org/wiki/Bhante_Sujato"
                },
                "breadcrumb3": "Bhikkhu Sujato"
            },
             "pali": {
                "name":        "Kinh Trường Bộ — tiếng Pali",
                "bookEdition": "Dīgha Nikāya",
                "image":       "kinhtruongbo.webp",
                "inLanguage":  "pi",
                "breadcrumb3": "Pali"
            },
        }
    },

    # ── Kinh Trung Bộ ─────────────────────────────────────────────────────────
    "kinhtrungbo": {
        "label": "Kinh Trung Bộ",
        "versions": {
            "c-nm-tmc-vi": {
                "name":        "Bản đọc song song: Ñāṇamoli & Bodhi — Thích Minh Châu",
                "bookEdition": "Bhikkhu Ñāṇamoli & Bhikkhu Bodhi - Tỷ kheo Thích Minh Châu",
                "image":       "kinhtrungbo.webp",
                "inLanguage":  "vi",
                "translator": [
                    {"name": "Bhikkhu Ñāṇamoli", "sameAs": "https://en.wikipedia.org/wiki/Bhikkhu_Ñāṇamoli"},
                    {"name": "Bhikkhu Bodhi",    "sameAs": "https://en.wikipedia.org/wiki/Bhikkhu_Bodhi"},
                    {"name": "Thích Minh Châu", "sameAs": "https://vi.wikipedia.org/wiki/Thích_Minh_Châu"}
                ],
                "breadcrumb3": "Bản đọc song song Ñāṇamoli & Bodhi và Thích Minh Châu"
            },
            "thichminhchau": {
                "name":        thichminhchau["name"],
                "bookEdition": thichminhchau["bookEdition"],
                "image":       "kinhtrungbo.webp",
                "inLanguage":  "vi",
                "translator":  thichminhchau["translator"],
                "breadcrumb3": thichminhchau["breadcrumb3"]
            },
            "nanamoli-bodhi-vi": {
                "name":        "Bhikkhu Ñāṇamoli & Bhikkhu Bodhi (Tiếng Việt)",
                "bookEdition": "Bhikkhu Ñāṇamoli & Bhikkhu Bodhi",
                "image":       "kinhtrungbo-nanamoli.webp",
                "inLanguage":  "vi",
                "translator": [
                    {"name": "Bhikkhu Ñāṇamoli", "sameAs": "https://en.wikipedia.org/wiki/Bhikkhu_Ñāṇamoli"},
                    {"name": "Bhikkhu Bodhi",    "sameAs": "https://en.wikipedia.org/wiki/Bhikkhu_Bodhi"}
                ],
                "breadcrumb3": "Bhikkhu Ñāṇamoli & Bhikkhu Bodhi"
            },
            "nanamoli-bodhi-en": {
                "name":        "The Middle Length Discourses of the Buddha: A Translation of the Majjhima Nikaya - Bhikkhu Ñāṇamoli & Bhikkhu Bodhi",
                "bookEdition": "Bhikkhu Ñāṇamoli & Bhikkhu Bodhi",
                "image":       "kinhtrungbo-nanamoli.webp",
                "inLanguage":  "en",
                "translator": [
                    {"name": "Bhikkhu Ñāṇamoli", "sameAs": "https://en.wikipedia.org/wiki/Bhikkhu_Ñāṇamoli"},
                    {"name": "Bhikkhu Bodhi",    "sameAs": "https://en.wikipedia.org/wiki/Bhikkhu_Bodhi"}
                ],
                "breadcrumb3": "Bhikkhu Ñāṇamoli & Bhikkhu Bodhi"
            },
            "pali-vi-not-yet": {
                "name":        "Kinh Trung Bộ — Dịch từ tiếng Pali",
                "bookEdition": "Majjhima Nikaya",
                "image":       "kinhtrungbo.webp",
                "inLanguage":  "vi",
                "translator": {"name": "Trương Hoàng Nguyên", "sameAs": "https://github.com/truonghoangnguyen/nikaya2"},
                "breadcrumb3": "Dịch từ tiếng Pali"
            },
             "pali": {
                "name":        "Kinh Trung Bộ — tiếng Pali",
                "bookEdition": "Majjhima Nikaya",
                "image":       "kinhtrungbo.webp",
                "inLanguage":  "pi",
                "translator": {"name": "Trương Hoàng Nguyên", "sameAs": "https://github.com/truonghoangnguyen/nikaya2"},
                "breadcrumb3": "Dịch từ tiếng Pali"
            },
        }
    },

    # ── Kinh Tương Ưng ────────────────────────────────────────────────────────
    "kinhtuongung": {
        "label": "Kinh Tương Ưng Bộ",
        "versions": {
            "thichminhchau": {
                "name":        thichminhchau["name"],
                "bookEdition": thichminhchau["bookEdition"],
                "image":       "kinhtuongung.webp",
                "inLanguage":  "vi",
                "translator":  thichminhchau["translator"],
                "breadcrumb3": thichminhchau["breadcrumb3"],
            },
            "sujato-vi": {
                "name":        sujato_vi["name"],
                "bookEdition": sujato_vi["bookEdition"],
                "image":       "kinhtuongung.webp",
                "inLanguage":  "vi",
                "translator":  sujato_vi["translator"],
                "breadcrumb3": sujato_vi["breadcrumb3"],
            },
            "sujato-en": {
                "name":        "Linked Discourses A plain translation of the Saṁyutta Nikāya -  Bhikkhu Sujato",
                "bookEdition": sujato_en["bookEdition"],
                "image":       "kinhtuongung-sujato.webp",
                "inLanguage":  "en",
                "translator":   sujato_en["translator"],
                "breadcrumb3": sujato_en["breadcrumb3"]
            },
            "c-sujato-tmc-vi":{
                "name":        "Bản đọc song song: Bhikkhu Sujato - Thích Minh Châu",
                "bookEdition": "Bhikkhu Sujato - Tỷ kheo Thích Minh Châu",
                "image":       "kinhtuongung.webp",
                "inLanguage":  "vi",
                "translator": [
                    sujato_vi["translator"],
                    thichminhchau["translator"]
                ],
                "breadcrumb3": "Bản đọc song song Bhikkhu Sujato và Thích Minh Châu"
            }
        }
    },
    "kinhtieubo": {
        "label": "Kinh Tiểu Bộ",
        "versions": {
            "thichminhchau": {
                "name":        thichminhchau["name"],
                "bookEdition": thichminhchau["bookEdition"],
                "image":       "kinhtieubo.webp",
                "inLanguage":  "vi",
                "translator":  thichminhchau["translator"],
                "breadcrumb3": thichminhchau["breadcrumb3"],
            },
            "tranphuonglan": {
                "name":        sujato_vi["name"],
                "bookEdition": sujato_vi["bookEdition"],
                "image":       "kinhtieubo.webp",
                "inLanguage":  "vi",
                "translator":  sujato_vi["translator"],
                "breadcrumb3": sujato_vi["breadcrumb3"],
            },

        }
    },
    "kinhtangchi": {
        "label": "Kinh Tăng Chi Bộ",
        "versions": {
            "thichminhchau": {
                "name":        thichminhchau["name"],
                "bookEdition": thichminhchau["bookEdition"],
                "image":       "kinhtangchi.webp",
                "inLanguage":  "vi",
                "translator":  thichminhchau["translator"],
                "breadcrumb3": thichminhchau["breadcrumb3"],
            },
            "sujato-vi": {
                "name":        sujato_vi["name"],
                "bookEdition": sujato_vi["bookEdition"],
                "image":       "kinhtangchi-sujato.webp",
                "inLanguage":  "vi",
                "translator":  sujato_vi["translator"],
                "breadcrumb3": sujato_vi["breadcrumb3"],
            },
            "sujato-en": {
                "name":        "Numbered Discourses A sensible translation of the Aṅguttara Nikāya - Bhikkhu Sujato",
                "bookEdition": sujato_en["bookEdition"],
                "image":       "kinhtangchi-sujato.webp",
                "inLanguage":  "en",
                "translator":   sujato_en["translator"],
                "breadcrumb3": sujato_en["breadcrumb3"]
            },
            "c-sujato-tmc-vi":{
                "name":        "Bản đọc song song: Bhikkhu Sujato - Thích Minh Châu",
                "bookEdition": "Bhikkhu Sujato - Tỷ kheo Thích Minh Châu",
                "image":       "kinhtangchi.webp",
                "inLanguage":  "vi",
                "translator": [
                    sujato_vi["translator"],
                    thichminhchau["translator"]
                ],
                "breadcrumb3": "Bản đọc song song Bhikkhu Sujato và Thích Minh Châu"
            }
        }
    }
}

# %%
import json
import os
import re
from pathlib import Path

BASE_URL = "https://kinhnikaya.org"

def build_has_part(folder_path):

    # input: folder path
    file_path = Path(folder_path)

    # ưu tiên: mucluc.md -> meta/mucluc.md
    mucluc_1 = file_path / "mucluc.md"
    mucluc_2 = file_path / "meta" / "mucluc.md"

    if mucluc_1.exists():
        md_file = mucluc_1
    elif mucluc_2.exists():
        md_file = mucluc_2
    else:
        raise FileNotFoundError(
            f"Không tìm thấy '{mucluc_1}' hoặc '{mucluc_2}'"
        )


    text = Path(md_file).read_text(encoding="utf-8")

    # lấy tất cả markdown links
    links = re.findall(r'\[.*?\]\((.*?)\)', text)

    result = []

    for link in links:
        path = link.strip()

        # bỏ .md ở cuối, trừ intro/outro
        if "/intro/" in path or "/outro/" in path:
            suffix = "#article"
            final_path = path
        else:
            suffix = "#chapter"
            final_path = re.sub(r'\.md$', '', path)

        result.append(
            { "@id": f'{BASE_URL}{final_path}{suffix}'}
        )
    return result


def build_layer3_jsonld(kinh: str, author: str, has_part: list | None = None) -> dict:
    """
    Sinh JSON-LD tầng 3 cho trang bản dịch.

    Parameters
    ----------
    kinh    : key bộ kinh trong CONFIG, vd 'kinhtruongbo'
    author  : key bản dịch,            vd 'thichminhchau' hoặc 'sujato-vi'
    has_part: list các dict {"@id": "...#chapter"} — để trống thì bỏ qua field hasPart
    """
    bộ    = CONFIG[kinh]
    ver   = bộ["versions"][author]
    slug  = author                        # vd: 'thichminhchau'
    label = bộ["label"]                   # vd: 'Kinh Trường Bộ'

    page_url    = f"{BASE}/{kinh}/{slug}/"
    book_id     = f"{page_url}#book"
    parent_url  = f"{BASE}/{kinh}/"
    abstract_id = f"{parent_url}#book"

    # ── translator: hỗ trợ 1 người (dict) hoặc nhiều người (list) ──
    if ver.get("translator"):
        raw_tr = ver["translator"]
        if isinstance(raw_tr, list):
            translator_field = [
                {"@type": "Person", **t} for t in raw_tr
            ]
        else:
            translator_field = {"@type": "Person", **raw_tr}
    else:
        translator_field = None

    # ── Book node ──────────────────────────────────────────────────
    book = {
        "@type": "Book",
        "@id":   book_id,
        "mainEntityOfPage": {
            "@type": "WebPage",
            "@id":   page_url
        },
        "name":        ver["name"],
        "bookEdition": ver["bookEdition"],
        "url":         page_url,
        "inLanguage":  ver["inLanguage"],
        "isAccessibleForFree": True,
        "publisher":   {"@id": f"{BASE}/#org"},
        "image":       f"{BASE}/covers/{ver['image']}",
        "author": {
            "@type":  "Person",
            "name":   "Gotama Buddha",
            "sameAs": "https://en.wikipedia.org/wiki/Gautama_Buddha"
        },
    #    "translator":        translator_field,
        "translationOfWork": {"@id": abstract_id}
    }
    if translator_field:
        book[translator] = translator_field


    if has_part:
        book["hasPart"] = has_part
    else:
        index_file = f"../docs/{kinh}/{author}"
        book["hasPart"] =  build_has_part(index_file)


    # ── BreadcrumbList ─────────────────────────────────────────────
    breadcrumb = {
        "@type": "BreadcrumbList",
        "itemListElement": [
            {"@type": "ListItem", "position": 1, "name": "Trang chủ",  "item": f"{BASE}/"},
            {"@type": "ListItem", "position": 2, "name": label,         "item": parent_url},
            {"@type": "ListItem", "position": 3, "name": ver["breadcrumb3"], "item": page_url}
        ]
    }

    return {
        "@context": "https://schema.org",
        "@graph": [book, breadcrumb]
    }


# ── CHẠY ──────────────────────────────────────────────────────────────────────
kinh   = "kinhtruongbo"
author = "pali"   # đổi thành 'sujato-vi', 'sujato-en', …
#has_part = [{}] # tu build has_part

result = build_layer3_jsonld(kinh, author)

# JSON-LD pretty format
jsonld_result = json.dumps(result, ensure_ascii=False, indent=2)

# dữ liệu từ CONFIG
bộ   = CONFIG[kinh]
ver  = bộ["versions"][author]

label        = bộ["label"]
breadcrumb3  = ver["breadcrumb3"]
image        = ver["image"]
name         = ver["name"]
markdown_output = f"""---
title: {label} - {name}
head:
  - - script
    - type: application/ld+json
    - |
       {jsonld_result.replace(chr(10), chr(10) + '        ')}

---

<h1 style="text-align: center;">{label}</h1>
<h2 style="text-align: center;">{name}</h2>
<br>
<a href="/{kinh}/{author}/--mục đầu tiên">
<figure style="text-align: center;">
    <img src="/covers/{image}" style="max-width:400px;width:100%;display:block;margin:0 auto;" alt="{label} {name}">
</figure>
</a>

<br/>
<hr/>
<br/>
<h2 style="text-align: center;">Mục Lục</h2>
<br/>

<!--@include: ./meta/mucluc.md-->
"""

print(markdown_output)

# print(json.dumps(result, ensure_ascii=False, indent=2))
# Out:
# ---
# title: Kinh Trường Bộ - Kinh Trường Bộ — tiếng Pali
# head:
#   - - script
#     - type: application/ld+json
#     - |
#        {
#           "@context": "https://schema.org",
#           "@graph": [
#             {
#               "@type": "Book",
#               "@id": "https://kinhnikaya.org/kinhtruongbo/pali/#book",
#               "mainEntityOfPage": {
#                 "@type": "WebPage",
#                 "@id": "https://kinhnikaya.org/kinhtruongbo/pali/"
#               },
#               "name": "Kinh Trường Bộ — tiếng Pali",
#               "bookEdition": "Dīgha Nikāya",
#               "url": "https://kinhnikaya.org/kinhtruongbo/pali/",
#               "inLanguage": "pi",
#               "isAccessibleForFree": true,
#               "publisher": {
#                 "@id": "https://kinhnikaya.org/#org"
#               },
#               "image": "https://kinhnikaya.org/covers/kinhtruongbo.webp",
#               "author": {
#                 "@type": "Person",
#                 "name": "Gotama Buddha",
#                 "sameAs": "https://en.wikipedia.org/wiki/Gautama_Buddha"
#               },
#               "translationOfWork": {
#                 "@id": "https://kinhnikaya.org/kinhtruongbo/#book"
#               },
#               "hasPart": [
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtruongbo/pali/dn-001-brahmajalasutta#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtruongbo/pali/dn-002-samannaphalasutta#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtruongbo/pali/dn-003-ambatthasutta#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtruongbo/pali/dn-004-sonadandasutta#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtruongbo/pali/dn-005-kutadantasutta#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtruongbo/pali/dn-006-mahalisutta#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtruongbo/pali/dn-007-jaliyasutta#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtruongbo/pali/dn-008-mahasihanadasutta#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtruongbo/pali/dn-009-potthapadasutta#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtruongbo/pali/dn-010-subhasutta#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtruongbo/pali/dn-011-kevattasutta#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtruongbo/pali/dn-012-lohiccasutta#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtruongbo/pali/dn-013-tevijjasutta#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtruongbo/pali/dn-014-mahapadanasutta#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtruongbo/pali/dn-015-mahanidanasutta#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtruongbo/pali/dn-016-mahaparinibbanasutta#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtruongbo/pali/dn-017-mahasudassanasutta#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtruongbo/pali/dn-018-janavasabhasutta#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtruongbo/pali/dn-019-mahagovindasutta#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtruongbo/pali/dn-020-mahasamayasutta#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtruongbo/pali/dn-021-sakkapanhasutta#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtruongbo/pali/dn-022-mahasatipatthanasutta#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtruongbo/pali/dn-023-payasisutta#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtruongbo/pali/dn-024-pathikasutta#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtruongbo/pali/dn-025-udumbarikasutta#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtruongbo/pali/dn-026-cakkavattisutta#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtruongbo/pali/dn-027-aggannasutta#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtruongbo/pali/dn-028-sampasadaniyasutta#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtruongbo/pali/dn-029-pasadikasutta#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtruongbo/pali/dn-030-lakkhanasutta#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtruongbo/pali/dn-031-singalasutta#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtruongbo/pali/dn-032-atanatiyasutta#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtruongbo/pali/dn-033-sangitisutta#chapter"
#                 },
#                 {
#                   "@id": "https://kinhnikaya.org/kinhtruongbo/pali/dn-034-dasuttarasutta#chapter"
#                 }
#               ]
#             },
#             {
#               "@type": "BreadcrumbList",
#               "itemListElement": [
#                 {
#                   "@type": "ListItem",
#                   "position": 1,
#                   "name": "Trang chủ",
#                   "item": "https://kinhnikaya.org/"
#                 },
#                 {
#                   "@type": "ListItem",
#                   "position": 2,
#                   "name": "Kinh Trường Bộ",
#                   "item": "https://kinhnikaya.org/kinhtruongbo/"
#                 },
#                 {
#                   "@type": "ListItem",
#                   "position": 3,
#                   "name": "Pali",
#                   "item": "https://kinhnikaya.org/kinhtruongbo/pali/"
#                 }
#               ]
#             }
#           ]
#         }
#
# ---
#
# <h1 style="text-align: center;">Kinh Trường Bộ</h1>
# <h2 style="text-align: center;">Kinh Trường Bộ — tiếng Pali</h2>
# <br>
# <a href="/kinhtruongbo/pali/--mục đầu tiên">
# <figure style="text-align: center;">
#     <img src="/covers/kinhtruongbo.webp" style="max-width:400px;width:100%;display:block;margin:0 auto;" alt="Kinh Trường Bộ Kinh Trường Bộ — tiếng Pali">
# </figure>
# </a>
#
# <br/>
# <hr/>
# <br/>
# <h2 style="text-align: center;">Mục Lục</h2>
# <br/>
#
# <!--@include: ./meta/mucluc.md-->
