# %%
import os
import re

def generate_filelist(folder_path, listname, folder_out):
    """
    filelist.js using for generate next/back button config in config.js
    mucluc.md using for generate table of contents

    Generates a JavaScript filelist from Markdown files in a folder.

    Args:
        folder_path: The path to the folder containing the Markdown files.
        listname: The name to use for the JavaScript constant and export.

    Returns:
        None.  Writes the output to a file named 'filelist.js' in the input folder.
    """
    os.makedirs(os.path.join(folder_path, 'meta'), exist_ok=True)


    file_list = []
    _lst = sorted([f for f in os.listdir(folder_path) if f.endswith('.md')])
    for filename in _lst:
        # print(filename)
        file_path = os.path.join(folder_path, filename)
        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                first_line = f.readline().strip()
                # Match lines starting with '#' followed by a space and capture the rest.
                match = re.match(r"^#\s+(.*)", first_line)
                if match:
                    title = match.group(1).strip()
                    # Create file_item dict and handle exceptions
                    file_item = {
                        "text": title,
                        "link": os.path.join(folder_out, filename).replace("\\", "/")  # handle Windows path
                    }
                    file_list.append(file_item)
                    print(file_item)
                else:
                    print(f"Warning: No title found in {filename}, see `9headerformat.ipynb`")


        except FileNotFoundError:
            print(f"Error: File not found: {file_path}")
        except Exception as e:
            print(f"Error reading or processing {filename}: {e}")

    # Sort the file list alphabetically by 'text'
    # file_list.sort(key=lambda x: x['text'])

    # Generate the JavaScript code.
    js_code = f"const {listname} = [\n"
    for item in file_list:
        js_code += f'  {{ text: "{item["text"]}", link: "{item["link"]}" }},\n'
    js_code += "];\n"
    js_code += f"export default {listname};\n"

    meta_path = folder_path+"/meta"
    # Write the JavaScript code to filelist.js
    output_file_path = os.path.join(meta_path, "filelist.js")
    try:
        with open(output_file_path, 'w', encoding='utf-8') as outfile:
            outfile.write(js_code)
        print(f"Successfully generated filelist.js in {meta_path}")
    except Exception as e:
        print(f"Error writing to filelist.js: {e}")

    # Generate the Markdown table of contents (mucluc.md)
    md_toc = ""
    for item in file_list:
        md_toc += f'- [{item["text"]}]({item["link"]})\n'

    # Write the Markdown TOC to mucluc.md
    output_md_path = os.path.join(meta_path, "mucluc.md")
    try:
        with open(output_md_path, 'w', encoding='utf-8') as outfile:
            outfile.write(md_toc)
        print(f"Successfully generated mucluc.md in {folder_path}")
    except Exception as e:
        print(f"Error writing to mucluc.md: {e}")

    # Generate index.md
    output_index_path = os.path.join(folder_path, "index.md")
    try:
        with open(output_index_path, 'w', encoding='utf-8') as outfile:
            outfile.write("<!--@include: ./meta/mucluc.md-->")
        print(f"Successfully generated index.md in {folder_path}")
    except Exception as e:
        print(f"Error writing to index.md: {e}")


    print(f"Created {output_file_path} for vite config.js create next-prev link")
    print(f"Created {output_md_path} for for mucluc.md ")




## step 3 - MAKE MUCLUC-NAVFILE


alang = ""
kinh = "kinhtieubo"
author="thichminhchau"
if alang != "":
    # folder contain list of file
    #folder_for_scan = f"../docs/{kinh}/{author}-{alang}/intro"
    folder_for_scan = f"../docs/{kinh}/{author}-{alang}"
    # output variable in filelist.js
    print_listname = f"{kinh}_{author}_{alang}"
    # output variable in filelist.js
    #print_folder_path = f'/{kinh}/{author}-{alang}/intro'
    print_folder_path = f'/{kinh}/{author}-{alang}'
else:
    folder_for_scan = f"../docs/{kinh}/{author}"
    # output variable in filelist.js
    print_listname = f"{kinh}_{author}"
    # output variable in filelist.js
    print_folder_path = f'/{kinh}/{author}'

# folder_for_scan = f"../docs/plato/vi/intro"
# print_listname = f"plato"
# print_folder_path = f'/docs/plato/vi/intro'

if not os.path.isdir(folder_for_scan):
    print(f"Error: The provided folder path '{folder_for_scan}' is not a valid directory.")
else:
    generate_filelist(folder_for_scan, print_listname, print_folder_path)
    print("Remember add mucluc.md to url-able path; and add filelist.js to config.ts for next-prev button")
# Out:
# Warning: No title found in index.md, see `9headerformat.ipynb`
# {'text': 'TẬP 1 – KINH TIỂU TỤNG', 'link': '/kinhtieubo/thichminhchau/kn-001-tap-1-kinh-tieu-tung.md'}
# {'text': 'TẬP 2 – KINH PHÁP CÚ', 'link': '/kinhtieubo/thichminhchau/kn-002-tap-2-kinh-phap-cu.md'}
# {'text': 'TẬP 3 – KINH PHẬT TỰ THUYẾT', 'link': '/kinhtieubo/thichminhchau/kn-003-tap-3-kinh-phat-tu-thuyet.md'}
# {'text': 'Chương 1: Phẩm Bồ Ðề', 'link': '/kinhtieubo/thichminhchau/kn-004-tap-3-chuong-1-pham-bo-de.md'}
# {'text': 'Chương 2: Phẩm Muccalinda', 'link': '/kinhtieubo/thichminhchau/kn-005-tap-3-chuong-2-pham-muccalinda.md'}
# {'text': 'Chương 3: Phẩm Nanda', 'link': '/kinhtieubo/thichminhchau/kn-006-tap-3-chuong-3-pham-nanda.md'}
# {'text': 'Chương 4: Phẩm Meghiya', 'link': '/kinhtieubo/thichminhchau/kn-007-tap-3-chuong-4-pham-meghiya.md'}
# {'text': 'Chương 5: Phẩm Trưởng Lão Sona', 'link': '/kinhtieubo/thichminhchau/kn-008-tap-3-chuong-5-pham-truong-lao-sona.md'}
# {'text': 'Chương 6: Phẩm Sanh Ra Ðã Mù', 'link': '/kinhtieubo/thichminhchau/kn-009-tap-3-chuong-6-pham-sanh-ra-da-mu.md'}
# {'text': 'Chương 7: Phẩm Nhỏ', 'link': '/kinhtieubo/thichminhchau/kn-010-tap-3-chuong-7-pham-nho.md'}
# {'text': 'Chương 8: Phẩm Pataligamiya', 'link': '/kinhtieubo/thichminhchau/kn-011-tap-3-chuong-8-pham-pataligamiya.md'}
# {'text': 'TẬP 4 – KINH PHẬT THUYẾT NHƯ VẬY', 'link': '/kinhtieubo/thichminhchau/kn-012-tap-4-kinh-phat-thuyet-nhu-vay.md'}
# {'text': 'Chương Một – Một Pháp', 'link': '/kinhtieubo/thichminhchau/kn-013-tap-4-chuong-1-tap-mot-phap.md'}
# {'text': 'Chương Hai – Hai Pháp', 'link': '/kinhtieubo/thichminhchau/kn-014-tap-4-chuong-2-tap-hai-phap.md'}
# {'text': 'Chương Ba – Ba Pháp', 'link': '/kinhtieubo/thichminhchau/kn-015-tap-4-chuong-3-tap-ba-phap.md'}
# {'text': 'Phẩm 16 – Ðại Phẩm', 'link': '/kinhtieubo/thichminhchau/kn-069-tap-9-pham-16-dai-pham.md'}
# {'text': 'TẬP 10 – CHUYỆN TIỀN THÂN ĐỨC PHẬT', 'link': '/kinhtieubo/thichminhchau/kn-070-tap-10-chuyen-tien-than-duc-phat.md'}
# {'text': 'PHẦN 1 – CHƯƠNG I', 'link': '/kinhtieubo/thichminhchau/kn-071-tap-10-p1-chuong-i.md'}
# {'text': '[01] PHẨM APANNAKA', 'link': '/kinhtieubo/thichminhchau/kn-072-tap-10-p1-pham-apannaka.md'}
# {'text': '[02] PHẨM GIỚI', 'link': '/kinhtieubo/thichminhchau/kn-073-tap-10-p1-pham-gioi.md'}
# {'text': '[03] PHẨM KURUNGA', 'link': '/kinhtieubo/thichminhchau/kn-074-tap-10-p1-pham-kurunga.md'}
# {'text': '[04] PHẨM KULAVAKA', 'link': '/kinhtieubo/thichminhchau/kn-075-tap-10-p1-pham-kulavaka.md'}
# {'text': '[05] PHẨM LỢI ÁI', 'link': '/kinhtieubo/thichminhchau/kn-076-tap-10-p1-pham-loi-ai.md'}
# {'text': '[06] PHẨM ÀSIMSA', 'link': '/kinhtieubo/thichminhchau/kn-077-tap-10-p1-pham-asimsa.md'}
# {'text': '[07] PHẨM NỮ NHÂN', 'link': '/kinhtieubo/thichminhchau/kn-078-tap-10-p1-pham-nu-nhan.md'}
# {'text': '[08] PHẨM VARANA', 'link': '/kinhtieubo/thichminhchau/kn-079-tap-10-p1-pham-varana.md'}
# {'text': '[09] PHẨM APAYIMHA', 'link': '/kinhtieubo/thichminhchau/kn-080-tap-10-p1-pham-apayimha.md'}
# {'text': '[10] PHẨM LITTA', 'link': '/kinhtieubo/thichminhchau/kn-081-tap-10-p1-pham-litta.md'}
# {'text': '[11] PHẨM PAROSSATA', 'link': '/kinhtieubo/thichminhchau/kn-082-tap-10-p1-pham-parossata.md'}
# {'text': '[12] PHẨM HAMSA', 'link': '/kinhtieubo/thichminhchau/kn-083-tap-10-p1-pham-hamsa.md'}
# {'text': '[13] PHẨM KUSANÀLI', 'link': '/kinhtieubo/thichminhchau/kn-084-tap-10-p1-pham-kusanali.md'}
# {'text': '[14] PHẨM ASAMPADÀNA', 'link': '/kinhtieubo/thichminhchau/kn-085-tap-10-p1-pham-asampadana.md'}
# {'text': '[15] PHẨM KAKANTAKA', 'link': '/kinhtieubo/thichminhchau/kn-086-tap-10-p1-pham-kakantaka.md'}
# {'text': 'PHẦN 2 – CHƯƠNG 2', 'link': '/kinhtieubo/thichminhchau/kn-087-tap-10-p2-chuong-2.md'}
# {'text': '[01] PHẨM DALHA', 'link': '/kinhtieubo/thichminhchau/kn-088-tap-10-p2-pham-dalha.md'}
# {'text': '[02] PHẨM SANTAHAVA', 'link': '/kinhtieubo/thichminhchau/kn-089-tap-10-p2-pham-santahava.md'}
# {'text': '[03] PHẨM THIỆN PHÁP', 'link': '/kinhtieubo/thichminhchau/kn-090-tap-10-p2-pham-thien-phap.md'}
