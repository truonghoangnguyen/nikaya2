# %%
import os
import re

def generate_filelist(folder_path, listname, folder_out):
    """
    filelist.js using for generate next/back button config in config.js
    mucluc.md using for generate table of contents

    Generates a JavaScript filelist from Markdown files in a folder.

    Args:
        folder_path: The path to the folder containing the Markdown files.
        listname: The name to use for the JavaScript constant and export.

    Returns:
        None.  Writes the output to a file named 'filelist.js' in the input folder.
    """

    file_list = []
    _lst = sorted([f for f in os.listdir(folder_path) if f.endswith('.md')])
    for filename in _lst:
        # print(filename)
        file_path = os.path.join(folder_path, filename)
        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                first_line = f.readline().strip()
                # Match lines starting with '#' followed by a space and capture the rest.
                match = re.match(r"^#\s+(.*)", first_line)
                if match:
                    title = match.group(1).strip()
                    # Create file_item dict and handle exceptions
                    file_item = {
                        "text": title,
                        "link": os.path.join(folder_out, filename).replace("\\", "/")  # handle Windows path
                    }
                    file_list.append(file_item)
                    print(file_item)
                else:
                    print(f"Warning: No title found in {filename}, see `9headerformat.ipynb`")


        except FileNotFoundError:
            print(f"Error: File not found: {file_path}")
        except Exception as e:
            print(f"Error reading or processing {filename}: {e}")

    # Sort the file list alphabetically by 'text'
    # file_list.sort(key=lambda x: x['text'])

    # Generate the JavaScript code.
    js_code = f"const {listname} = [\n"
    for item in file_list:
        js_code += f'  {{ text: "{item["text"]}", link: "{item["link"]}" }},\n'
    js_code += "];\n"
    js_code += f"export default {listname};\n"

    # Write the JavaScript code to filelist.js
    output_file_path = os.path.join(folder_path, "filelist.js")
    try:
        with open(output_file_path, 'w', encoding='utf-8') as outfile:
            outfile.write(js_code)
        print(f"Successfully generated filelist.js in {folder_path}")
    except Exception as e:
        print(f"Error writing to filelist.js: {e}")

    # Generate the Markdown table of contents (mucluc.md)
    md_toc = ""
    for item in file_list:
        md_toc += f'- [{item["text"]}]({item["link"]})\n'

    # Write the Markdown TOC to mucluc.md
    output_md_path = os.path.join(folder_path, "mucluc.md")
    try:
        with open(output_md_path, 'w', encoding='utf-8') as outfile:
            outfile.write(md_toc)
        print(f"Successfully generated mucluc.md in {folder_path}")
    except Exception as e:
        print(f"Error writing to mucluc.md: {e}")

    print(f"Created {output_file_path} for vite config.js create next-prev link")
    print(f"Created {output_md_path} for for mucluc.md ")




## step 3 - MAKE MUCLUC-NAVFILE


alang = "vi"
kinh = "kinhtangchi"
author="sujato"

# folder contain list of file
folder_for_scan = f"../docs/{kinh}/{author}-{alang}/3"
# output variable in filelist.js
print_listname = f"{kinh}_{author}_{alang}"
# output variable in filelist.js
print_folder_path = f'/{kinh}/{author}-{alang}'

# folder_path = "../docs/kinhtangchi/thichminhchau/"
# listname = "kinhtangchi_thichminhchau"
# folder_out = '/kinhtangchi/thichminhchau/'

if not os.path.isdir(folder_for_scan):
    print(f"Error: The provided folder path '{folder_for_scan}' is not a valid directory.")
else:
    generate_filelist(folder_for_scan, print_listname, print_folder_path)
    print("Remember add mucluc.md to url-able path; and add filelist.js to config.ts for next-prev button")
# Out:
# {'text': 'The Chapter on Powers of a Trainee', 'link': '/kinhtangchi/sujato-vi/05-001-the-chapter-on-powers-of-a-trainee.md'}
# {'text': 'The Chapter on Powers', 'link': '/kinhtangchi/sujato-vi/05-002-the-chapter-on-powers.md'}
# {'text': 'The Chapter on Five Factors', 'link': '/kinhtangchi/sujato-vi/05-003-the-chapter-on-five-factors.md'}
# {'text': 'The Chapter with Sumanā', 'link': '/kinhtangchi/sujato-vi/05-004-the-chapter-with-sumana.md'}
# {'text': 'The Chapter with King Muṇḍa', 'link': '/kinhtangchi/sujato-vi/05-005-the-chapter-with-king-munda.md'}
# {'text': 'The Chapter on Hindrances', 'link': '/kinhtangchi/sujato-vi/05-006-the-chapter-on-hindrances.md'}
# {'text': 'The Chapter on Perceptions', 'link': '/kinhtangchi/sujato-vi/05-007-the-chapter-on-perceptions.md'}
# {'text': 'The Chapter on a Warrior', 'link': '/kinhtangchi/sujato-vi/05-008-the-chapter-on-a-warrior.md'}
# {'text': 'The Chapter on Senior Mendicants', 'link': '/kinhtangchi/sujato-vi/05-009-the-chapter-on-senior-mendicants.md'}
# {'text': 'The Chapter with Kakudha', 'link': '/kinhtangchi/sujato-vi/05-010-the-chapter-with-kakudha.md'}
# {'text': 'The Chapter on Living Comfortably', 'link': '/kinhtangchi/sujato-vi/05-011-the-chapter-on-living-comfortably.md'}
# {'text': 'The Chapter at Andhakavinda', 'link': '/kinhtangchi/sujato-vi/05-012-the-chapter-at-andhakavinda.md'}
# {'text': 'The Chapter on Sick', 'link': '/kinhtangchi/sujato-vi/05-013-the-chapter-on-sick.md'}
# {'text': 'The Chapter on Kings', 'link': '/kinhtangchi/sujato-vi/05-014-the-chapter-on-kings.md'}
# {'text': 'The Chapter at Tikaṇḍakī', 'link': '/kinhtangchi/sujato-vi/05-015-the-chapter-at-tikandaki.md'}
# {'text': 'The Chapter on the True Teaching', 'link': '/kinhtangchi/sujato-vi/05-016-the-chapter-on-the-true-teaching.md'}
# {'text': 'The Chapter on Resentment', 'link': '/kinhtangchi/sujato-vi/05-017-the-chapter-on-resentment.md'}
# {'text': 'The Chapter on a Lay Follower', 'link': '/kinhtangchi/sujato-vi/05-018-the-chapter-on-a-lay-follower.md'}
# {'text': 'The Chapter on Wilderness Dwellers', 'link': '/kinhtangchi/sujato-vi/05-019-the-chapter-on-wilderness-dwellers.md'}
# {'text': 'The Chapter on Brahmins', 'link': '/kinhtangchi/sujato-vi/05-020-the-chapter-on-brahmins.md'}
# {'text': 'The Chapter with Kimbila', 'link': '/kinhtangchi/sujato-vi/05-021-the-chapter-with-kimbila.md'}
# {'text': 'The Chapter on Abuse', 'link': '/kinhtangchi/sujato-vi/05-022-the-chapter-on-abuse.md'}
# {'text': 'The Chapter on Long Wandering', 'link': '/kinhtangchi/sujato-vi/05-023-the-chapter-on-long-wandering.md'}
# {'text': 'The Chapter on a Resident Mendicant', 'link': '/kinhtangchi/sujato-vi/05-024-the-chapter-on-a-resident-mendicant.md'}
# {'text': 'The Chapter on Bad Conduct', 'link': '/kinhtangchi/sujato-vi/05-025-the-chapter-on-bad-conduct.md'}
# {'text': 'The Chapter on Ordination', 'link': '/kinhtangchi/sujato-vi/05-026-the-chapter-on-ordination.md'}
# {'text': 'The Chapter on Worthy of Offerings', 'link': '/kinhtangchi/sujato-vi/06-001-the-chapter-on-worthy-of-offerings.md'}
# {'text': 'The Chapter on Warm-hearted', 'link': '/kinhtangchi/sujato-vi/06-002-the-chapter-on-warm-hearted.md'}
# {'text': 'The Chapter on Unsurpassable', 'link': '/kinhtangchi/sujato-vi/06-003-the-chapter-on-unsurpassable.md'}
# {'text': 'The Chapter on Deities', 'link': '/kinhtangchi/sujato-vi/06-004-the-chapter-on-deities.md'}
# {'text': 'The Chapter with Dhammika', 'link': '/kinhtangchi/sujato-vi/06-005-the-chapter-with-dhammika.md'}
# {'text': 'The Great Chapter', 'link': '/kinhtangchi/sujato-vi/06-006-the-great-chapter.md'}
# {'text': 'The Chapter on Deities', 'link': '/kinhtangchi/sujato-vi/06-007-the-chapter-on-deities.md'}
# {'text': 'The Chapter on Perfection', 'link': '/kinhtangchi/sujato-vi/06-008-the-chapter-on-perfection.md'}
# {'text': 'The Chapter on Coolness', 'link': '/kinhtangchi/sujato-vi/06-009-the-chapter-on-coolness.md'}
# {'text': 'The Chapter on Benefit', 'link': '/kinhtangchi/sujato-vi/06-010-the-chapter-on-benefit.md'}
# {'text': 'The Chapter on Triads', 'link': '/kinhtangchi/sujato-vi/06-011-the-chapter-on-triads.md'}
# {'text': 'The Chapter on the Ascetic Life', 'link': '/kinhtangchi/sujato-vi/06-012-the-chapter-on-the-ascetic-life.md'}
# Successfully generated filelist.js in ../docs/kinhtangchi/sujato-vi/3
# Successfully generated mucluc.md in ../docs/kinhtangchi/sujato-vi/3
# Created ../docs/kinhtangchi/sujato-vi/3/filelist.js for vite config.js create next-prev link
# Created ../docs/kinhtangchi/sujato-vi/3/mucluc.md for for mucluc.md
# Remember add mucluc.md to url-able path; and add filelist.js to config.ts for next-prev button
