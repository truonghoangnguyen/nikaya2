# %%
import os
import re

def generate_filelist(folder_path, listname, folder_out):
    """
    filelist.js using for generate next/back button config in config.js
    mucluc.md using for generate table of contents

    Generates a JavaScript filelist from Markdown files in a folder.

    Args:
        folder_path: The path to the folder containing the Markdown files.
        listname: The name to use for the JavaScript constant and export.

    Returns:
        None.  Writes the output to a file named 'filelist.js' in the input folder.
    """

    file_list = []
    _lst = sorted([f for f in os.listdir(folder_path) if f.endswith('.md')])
    for filename in _lst:
        # print(filename)
        file_path = os.path.join(folder_path, filename)
        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                first_line = f.readline().strip()
                # Match lines starting with '#' followed by a space and capture the rest.
                match = re.match(r"^#\s+(.*)", first_line)
                if match:
                    title = match.group(1).strip()
                    # Create file_item dict and handle exceptions
                    file_item = {
                        "text": title,
                        "link": os.path.join(folder_out, filename).replace("\\", "/")  # handle Windows path
                    }
                    file_list.append(file_item)
                    print(file_item)
                else:
                    print(f"Warning: No title found in {filename}, see `9headerformat.ipynb`")


        except FileNotFoundError:
            print(f"Error: File not found: {file_path}")
        except Exception as e:
            print(f"Error reading or processing {filename}: {e}")

    # Sort the file list alphabetically by 'text'
    # file_list.sort(key=lambda x: x['text'])

    # Generate the JavaScript code.
    js_code = f"const {listname} = [\n"
    for item in file_list:
        js_code += f'  {{ text: "{item["text"]}", link: "{item["link"]}" }},\n'
    js_code += "];\n"
    js_code += f"export default {listname};\n"

    # Write the JavaScript code to filelist.js
    output_file_path = os.path.join(folder_path, "filelist.js")
    try:
        with open(output_file_path, 'w', encoding='utf-8') as outfile:
            outfile.write(js_code)
        print(f"Successfully generated filelist.js in {folder_path}")
    except Exception as e:
        print(f"Error writing to filelist.js: {e}")

    # Generate the Markdown table of contents (mucluc.md)
    md_toc = ""
    for item in file_list:
        md_toc += f'- [{item["text"]}]({item["link"]})\n'

    # Write the Markdown TOC to mucluc.md
    output_md_path = os.path.join(folder_path, "mucluc.md")
    try:
        with open(output_md_path, 'w', encoding='utf-8') as outfile:
            outfile.write(md_toc)
        print(f"Successfully generated mucluc.md in {folder_path}")
    except Exception as e:
        print(f"Error writing to mucluc.md: {e}")

    print(f"Created {output_file_path} for vite config.js create next-prev link")
    print(f"Created {output_md_path} for for mucluc.md ")




## step 3 - MAKE MUCLUC-NAVFILE


alang = "vi"
kinh = "kinhtuongung"
author="sujato"

# folder contain list of file
folder_for_scan = f"../docs/{kinh}/{author}-{alang}"
# output variable in filelist.js
print_listname = f"{kinh}_{author}_{alang}"
# output variable in filelist.js
print_folder_path = f'/{kinh}/{author}-{alang}'

folder_for_scan = f"../docs/jill-stroke/vi"
print_listname = f"jill"
print_folder_path = f'/docs/jill-stroke/vi'

if not os.path.isdir(folder_for_scan):
    print(f"Error: The provided folder path '{folder_for_scan}' is not a valid directory.")
else:
    generate_filelist(folder_for_scan, print_listname, print_folder_path)
    print("Remember add mucluc.md to url-able path; and add filelist.js to config.ts for next-prev button")
# Out:
# {'text': "**My Stroke of Insight:** **A Brain Scientist's Personal Journey**", 'link': '/docs/jill-stroke/vi/01-my-stroke-of-insight-a-brain-scientist-s-personal-journey.md'}
# {'text': 'LỜI GIỚI THIỆU', 'link': '/docs/jill-stroke/vi/02-introduction.md'}
# {'text': 'JILL TRƯỚC CƠN ĐỘT QUỴ', 'link': '/docs/jill-stroke/vi/03-one-jill-s-pre-stroke-life.md'}
# {'text': '2. Một Khoa học đơn giản', 'link': '/docs/jill-stroke/vi/04-2-simple-science.md'}
# {'text': '3. Sự bất đối xứng của hai bán cầu đại não', 'link': '/docs/jill-stroke/vi/05-3-hemispheres-asymmetries.md'}
# {'text': '4. Buổi sáng của cơn đột quỵ', 'link': '/docs/jill-stroke/vi/06-4-morning-of-the-stroke.md'}
# {'text': '5. Dàn xếp cuộc giải cứu của chính mình', 'link': '/docs/jill-stroke/vi/07-5-orchestrating-my-rescue.md'}
# {'text': '6. Sự Trở Về Cõi Tĩnh Lặng', 'link': '/docs/jill-stroke/vi/08-6-my-return-to-the-still.md'}
# {'text': '7. Trần Trụi Đến Tận Xương', 'link': '/docs/jill-stroke/vi/09-7-bare-to-the-bone.md'}
# {'text': '8. Chăm sóc Chuyên sâu Thần kinh', 'link': '/docs/jill-stroke/vi/10-8-neurological-intensive-care.md'}
# {'text': '9. Ngày Thứ Hai: Buổi Sáng Sau Cơn Bệnh', 'link': '/docs/jill-stroke/vi/11-9-day-two-the-morning-after.md'}
# {'text': '10. Ngày thứ ba: G.G. đến', 'link': '/docs/jill-stroke/vi/12-10-day-three-g-g-comes-to-town.md'}
# {'text': '11. Hồi Phục và Chuẩn bị cho Ca Phẫu thuật', 'link': '/docs/jill-stroke/vi/13-11-healing-and-preparing-for-surgery.md'}
# {'text': '12. Phẫu thuật Mở Hộp sọ Định vị', 'link': '/docs/jill-stroke/vi/14-12-stereotactic-craniotomy.md'}
# {'text': '14. Những Cột Mốc trên Hành Trình Hồi Phục', 'link': '/docs/jill-stroke/vi/15-14-milestones-for-recovery.md'}
# {'text': '15. Cú Đột Quỵ Thấu Suốt', 'link': '/docs/jill-stroke/vi/16-15-my-stroke-of-insight.md'}
# {'text': '16. Tâm trí Não phải và Não trái của Tôi', 'link': '/docs/jill-stroke/vi/17-16-my-right-and-left-mind.md'}
# {'text': '17. Làm Chủ Sức Mạnh Của Mình', 'link': '/docs/jill-stroke/vi/18-17-own-your-power.md'}
# {'text': '18. Tế Bào Và Mạch Tư Duy Đa Chiều', 'link': '/docs/jill-stroke/vi/19-18-cells-and-multidimensional-circuitry.md'}
# {'text': '19. Tìm Lại Bình Yên Sâu Thẳm Bên Trong', 'link': '/docs/jill-stroke/vi/20-19-finding-your-deep-inner-peace.md'}
# {'text': '20. Vun trồng Khu vườn', 'link': '/docs/jill-stroke/vi/21-20-tending-the-garden.md'}
# {'text': 'Phụ lục A', 'link': '/docs/jill-stroke/vi/22-appendix-a.md'}
# {'text': 'Phụ lục B', 'link': '/docs/jill-stroke/vi/23-appendix-b.md'}
# Warning: No title found in mucluc.md, see `9headerformat.ipynb`
# Successfully generated filelist.js in ../docs/jill-stroke/vi
# Successfully generated mucluc.md in ../docs/jill-stroke/vi
# Created ../docs/jill-stroke/vi/filelist.js for vite config.js create next-prev link
# Created ../docs/jill-stroke/vi/mucluc.md for for mucluc.md
# Remember add mucluc.md to url-able path; and add filelist.js to config.ts for next-prev button
