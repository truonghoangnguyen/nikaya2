# %%
import os
import re

def generate_filelist(folder_path, listname, folder_out):
    """
    filelist.js using for generate next/back button config in config.js
    mucluc.md using for generate table of contents

    Generates a JavaScript filelist from Markdown files in a folder.

    Args:
        folder_path: The path to the folder containing the Markdown files.
        listname: The name to use for the JavaScript constant and export.

    Returns:
        None.  Writes the output to a file named 'filelist.js' in the input folder.
    """
    os.makedirs(os.path.join(folder_path, 'meta'), exist_ok=True)


    file_list = []
    _lst = sorted([f for f in os.listdir(folder_path) if f.endswith('.md')])
    for filename in _lst:
        # print(filename)
        file_path = os.path.join(folder_path, filename)
        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                first_line = f.readline().strip()
                # Match lines starting with '#' followed by a space and capture the rest.
                match = re.match(r"^#\s+(.*)", first_line)
                if match:
                    title = match.group(1).strip()
                    # Create file_item dict and handle exceptions
                    file_item = {
                        "text": title,
                        "link": os.path.join(folder_out, filename).replace("\\", "/")  # handle Windows path
                    }
                    file_list.append(file_item)
                    print(file_item)
                else:
                    print(f"Warning: No title found in {filename}, see `9headerformat.ipynb`")


        except FileNotFoundError:
            print(f"Error: File not found: {file_path}")
        except Exception as e:
            print(f"Error reading or processing {filename}: {e}")

    # Sort the file list alphabetically by 'text'
    # file_list.sort(key=lambda x: x['text'])

    # Generate the JavaScript code.
    js_code = f"const {listname} = [\n"
    for item in file_list:
        js_code += f'  {{ text: "{item["text"]}", link: "{item["link"]}" }},\n'
    js_code += "];\n"
    js_code += f"export default {listname};\n"

    meta_path = folder_path+"/meta"
    # Write the JavaScript code to filelist.js
    output_file_path = os.path.join(meta_path, "filelist.js")
    try:
        with open(output_file_path, 'w', encoding='utf-8') as outfile:
            outfile.write(js_code)
        print(f"Successfully generated filelist.js in {meta_path}")
    except Exception as e:
        print(f"Error writing to filelist.js: {e}")

    # Generate the Markdown table of contents (mucluc.md)
    md_toc = ""
    for item in file_list:
        md_toc += f'- [{item["text"]}]({item["link"]})\n'

    # Write the Markdown TOC to mucluc.md
    output_md_path = os.path.join(meta_path, "mucluc.md")
    try:
        with open(output_md_path, 'w', encoding='utf-8') as outfile:
            outfile.write(md_toc)
        print(f"Successfully generated mucluc.md in {folder_path}")
    except Exception as e:
        print(f"Error writing to mucluc.md: {e}")

    # Generate index.md
    output_index_path = os.path.join(folder_path, "index.md")
    try:
        with open(output_index_path, 'w', encoding='utf-8') as outfile:
            outfile.write("<!--@include: ./meta/mucluc.md-->")
        print(f"Successfully generated index.md in {folder_path}")
    except Exception as e:
        print(f"Error writing to index.md: {e}")


    print(f"Created {output_file_path} for vite config.js create next-prev link")
    print(f"Created {output_md_path} for for mucluc.md ")




## step 3 - MAKE MUCLUC-NAVFILE


alang = ""
kinh = "kinhtieubo"
author="pali"
if alang != "":
    # folder contain list of file
    #folder_for_scan = f"../docs/{kinh}/{author}-{alang}/intro"
    folder_for_scan = f"../docs/{kinh}/{author}-{alang}"
    # output variable in filelist.js
    print_listname = f"{kinh}_{author}_{alang}"
    # output variable in filelist.js
    #print_folder_path = f'/{kinh}/{author}-{alang}/intro'
    print_folder_path = f'/{kinh}/{author}-{alang}'
else:
    folder_for_scan = f"../docs/{kinh}/{author}"
    # output variable in filelist.js
    print_listname = f"{kinh}_{author}"
    # output variable in filelist.js
    print_folder_path = f'/{kinh}/{author}'

kinh_lst = [
   'iti'
]

for k in range(1, 9):
  folder_for_scan = f"../docs/kinhtieubo/pali/ud/vagga{k}"
  print_listname = f"kn_ud_vagga{k}"
  print_folder_path = f'/kinhtieubo/pali/ud/vagga{k}'

  if not os.path.isdir(folder_for_scan):
      print(f"Error: The provided folder path '{folder_for_scan}' is not a valid directory.")
  else:
      generate_filelist(folder_for_scan, print_listname, print_folder_path)
      print("Remember add mucluc.md to url-able path; and add filelist.js to config.ts for next-prev button")




# folder_for_scan = f"../docs/kinhtieubo/pali/bv"
# print_listname = f"kn_bv"
# print_folder_path = f'/kinhtieubo/pali/bv'

# if not os.path.isdir(folder_for_scan):
#     print(f"Error: The provided folder path '{folder_for_scan}' is not a valid directory.")
# else:
#     generate_filelist(folder_for_scan, print_listname, print_folder_path)
#     print("Remember add mucluc.md to url-able path; and add filelist.js to config.ts for next-prev button")
# Out:
# {'text': 'UD 1.1. Paṭhamabodhisutta', 'link': '/kinhtieubo/pali/ud/vagga1/ud-1-1-pathamabodhisutta.md'}
# {'text': 'UD 1.10. Bāhiyasutta', 'link': '/kinhtieubo/pali/ud/vagga1/ud-1-10-bahiyasutta.md'}
# {'text': 'UD 1.2. Dutiyabodhisutta', 'link': '/kinhtieubo/pali/ud/vagga1/ud-1-2-dutiyabodhisutta.md'}
# {'text': 'UD 1.3. Tatiyabodhisutta', 'link': '/kinhtieubo/pali/ud/vagga1/ud-1-3-tatiyabodhisutta.md'}
# {'text': 'UD 1.4. Huṁhuṅkasutta', 'link': '/kinhtieubo/pali/ud/vagga1/ud-1-4-humhunkasutta.md'}
# {'text': 'UD 1.5. Brāhmaṇasutta', 'link': '/kinhtieubo/pali/ud/vagga1/ud-1-5-brahmanasutta.md'}
# {'text': 'UD 1.6. Mahākassapasutta', 'link': '/kinhtieubo/pali/ud/vagga1/ud-1-6-mahakassapasutta.md'}
# {'text': 'UD 1.7. Ajakalāpakasutta', 'link': '/kinhtieubo/pali/ud/vagga1/ud-1-7-ajakalapakasutta.md'}
# {'text': 'UD 1.8. Saṅgāmajisutta', 'link': '/kinhtieubo/pali/ud/vagga1/ud-1-8-sangamajisutta.md'}
# {'text': 'UD 1.9. Jaṭilasutta', 'link': '/kinhtieubo/pali/ud/vagga1/ud-1-9-jatilasutta.md'}
# Successfully generated filelist.js in ../docs/kinhtieubo/pali/ud/vagga1/meta
# Successfully generated mucluc.md in ../docs/kinhtieubo/pali/ud/vagga1
# Successfully generated index.md in ../docs/kinhtieubo/pali/ud/vagga1
# Created ../docs/kinhtieubo/pali/ud/vagga1/meta/filelist.js for vite config.js create next-prev link
# Created ../docs/kinhtieubo/pali/ud/vagga1/meta/mucluc.md for for mucluc.md
# Remember add mucluc.md to url-able path; and add filelist.js to config.ts for next-prev button
# {'text': 'UD 2.1. Mucalindasutta', 'link': '/kinhtieubo/pali/ud/vagga2/ud-2-1-mucalindasutta.md'}
# {'text': 'UD 2.10. Bhaddiyasutta', 'link': '/kinhtieubo/pali/ud/vagga2/ud-2-10-bhaddiyasutta.md'}
# {'text': 'UD 2.2. Rājasutta', 'link': '/kinhtieubo/pali/ud/vagga2/ud-2-2-rajasutta.md'}
# {'text': 'UD 2.3. Daṇḍasutta', 'link': '/kinhtieubo/pali/ud/vagga2/ud-2-3-dandasutta.md'}
# {'text': 'UD 2.4. Sakkārasutta', 'link': '/kinhtieubo/pali/ud/vagga2/ud-2-4-sakkarasutta.md'}
# {'text': 'UD 2.5. Upāsakasutta', 'link': '/kinhtieubo/pali/ud/vagga2/ud-2-5-upasakasutta.md'}
# {'text': 'UD 2.6. Gabbhinīsutta', 'link': '/kinhtieubo/pali/ud/vagga2/ud-2-6-gabbhinisutta.md'}
# {'text': 'UD 2.7. Ekaputtakasutta', 'link': '/kinhtieubo/pali/ud/vagga2/ud-2-7-ekaputtakasutta.md'}
# {'text': 'UD 2.8. Suppavāsāsutta', 'link': '/kinhtieubo/pali/ud/vagga2/ud-2-8-suppavasasutta.md'}
# {'text': 'UD 2.9. Visākhāsutta', 'link': '/kinhtieubo/pali/ud/vagga2/ud-2-9-visakhasutta.md'}
# Successfully generated filelist.js in ../docs/kinhtieubo/pali/ud/vagga2/meta
# Successfully generated mucluc.md in ../docs/kinhtieubo/pali/ud/vagga2
# Successfully generated index.md in ../docs/kinhtieubo/pali/ud/vagga2
# Created ../docs/kinhtieubo/pali/ud/vagga2/meta/filelist.js for vite config.js create next-prev link
# Created ../docs/kinhtieubo/pali/ud/vagga2/meta/mucluc.md for for mucluc.md
# Remember add mucluc.md to url-able path; and add filelist.js to config.ts for next-prev button
# {'text': 'UD 3.1. Kammavipākajasutta', 'link': '/kinhtieubo/pali/ud/vagga3/ud-3-1-kammavipakajasutta.md'}
# {'text': 'UD 3.10. Lokasutta', 'link': '/kinhtieubo/pali/ud/vagga3/ud-3-10-lokasutta.md'}
# {'text': 'UD 3.2. Nandasutta', 'link': '/kinhtieubo/pali/ud/vagga3/ud-3-2-nandasutta.md'}
# {'text': 'UD 3.3. Yasojasutta', 'link': '/kinhtieubo/pali/ud/vagga3/ud-3-3-yasojasutta.md'}
# {'text': 'UD 3.4. Sāriputtasutta', 'link': '/kinhtieubo/pali/ud/vagga3/ud-3-4-sariputtasutta.md'}
# {'text': 'UD 3.5. Mahāmoggallānasutta', 'link': '/kinhtieubo/pali/ud/vagga3/ud-3-5-mahamoggallanasutta.md'}
# {'text': 'UD 3.6. Pilindavacchasutta', 'link': '/kinhtieubo/pali/ud/vagga3/ud-3-6-pilindavacchasutta.md'}
# {'text': 'UD 3.7. Sakkudānasutta', 'link': '/kinhtieubo/pali/ud/vagga3/ud-3-7-sakkudanasutta.md'}
# {'text': 'UD 3.8. Piṇḍapātikasutta', 'link': '/kinhtieubo/pali/ud/vagga3/ud-3-8-pindapatikasutta.md'}
# {'text': 'UD 3.9. Sippasutta', 'link': '/kinhtieubo/pali/ud/vagga3/ud-3-9-sippasutta.md'}
# Successfully generated filelist.js in ../docs/kinhtieubo/pali/ud/vagga3/meta
# Successfully generated mucluc.md in ../docs/kinhtieubo/pali/ud/vagga3
# Successfully generated index.md in ../docs/kinhtieubo/pali/ud/vagga3
# Created ../docs/kinhtieubo/pali/ud/vagga3/meta/filelist.js for vite config.js create next-prev link
# Created ../docs/kinhtieubo/pali/ud/vagga3/meta/mucluc.md for for mucluc.md
# Remember add mucluc.md to url-able path; and add filelist.js to config.ts for next-prev button
# {'text': 'UD 4.1. Meghiyasutta', 'link': '/kinhtieubo/pali/ud/vagga4/ud-4-1-meghiyasutta.md'}
# {'text': 'UD 4.10. Sāriputtaupasamasutta', 'link': '/kinhtieubo/pali/ud/vagga4/ud-4-10-sariputtaupasamasutta.md'}
# {'text': 'UD 4.2. Uddhatasutta', 'link': '/kinhtieubo/pali/ud/vagga4/ud-4-2-uddhatasutta.md'}
# {'text': 'UD 4.3. Gopālakasutta', 'link': '/kinhtieubo/pali/ud/vagga4/ud-4-3-gopalakasutta.md'}
# {'text': 'UD 4.4. Yakkhapahārasutta', 'link': '/kinhtieubo/pali/ud/vagga4/ud-4-4-yakkhapaharasutta.md'}
# {'text': 'UD 4.5. Nāgasutta', 'link': '/kinhtieubo/pali/ud/vagga4/ud-4-5-nagasutta.md'}
# {'text': 'UD 4.6. Piṇḍolasutta', 'link': '/kinhtieubo/pali/ud/vagga4/ud-4-6-pindolasutta.md'}
# {'text': 'UD 4.7. Sāriputtasutta', 'link': '/kinhtieubo/pali/ud/vagga4/ud-4-7-sariputtasutta.md'}
# {'text': 'UD 4.8. Sundarīsutta', 'link': '/kinhtieubo/pali/ud/vagga4/ud-4-8-sundarisutta.md'}
# {'text': 'UD 4.9. Upasenasutta', 'link': '/kinhtieubo/pali/ud/vagga4/ud-4-9-upasenasutta.md'}
# Successfully generated filelist.js in ../docs/kinhtieubo/pali/ud/vagga4/meta
# Successfully generated mucluc.md in ../docs/kinhtieubo/pali/ud/vagga4
# Successfully generated index.md in ../docs/kinhtieubo/pali/ud/vagga4
# Created ../docs/kinhtieubo/pali/ud/vagga4/meta/filelist.js for vite config.js create next-prev link
# Created ../docs/kinhtieubo/pali/ud/vagga4/meta/mucluc.md for for mucluc.md
# Remember add mucluc.md to url-able path; and add filelist.js to config.ts for next-prev button
# {'text': 'UD 5.1. Piyatarasutta', 'link': '/kinhtieubo/pali/ud/vagga5/ud-5-1-piyatarasutta.md'}
# {'text': 'UD 5.10. Cūḷapanthakasutta', 'link': '/kinhtieubo/pali/ud/vagga5/ud-5-10-culapanthakasutta.md'}
# {'text': 'UD 5.2. Appāyukasutta', 'link': '/kinhtieubo/pali/ud/vagga5/ud-5-2-appayukasutta.md'}
# {'text': 'UD 5.3. Suppabuddhakuṭṭhisutta', 'link': '/kinhtieubo/pali/ud/vagga5/ud-5-3-suppabuddhakutthisutta.md'}
# {'text': 'UD 5.4. Kumārakasutta', 'link': '/kinhtieubo/pali/ud/vagga5/ud-5-4-kumarakasutta.md'}
# {'text': 'UD 5.5. Uposathasutta', 'link': '/kinhtieubo/pali/ud/vagga5/ud-5-5-uposathasutta.md'}
# {'text': 'UD 5.6. Soṇasutta', 'link': '/kinhtieubo/pali/ud/vagga5/ud-5-6-sonasutta.md'}
# {'text': 'UD 5.7. Kaṅkhārevatasutta', 'link': '/kinhtieubo/pali/ud/vagga5/ud-5-7-kankharevatasutta.md'}
# {'text': 'UD 5.8. Saṅghabhedasutta', 'link': '/kinhtieubo/pali/ud/vagga5/ud-5-8-sanghabhedasutta.md'}
# {'text': 'UD 5.9. Sadhāyamānasutta', 'link': '/kinhtieubo/pali/ud/vagga5/ud-5-9-sadhayamanasutta.md'}
# Successfully generated filelist.js in ../docs/kinhtieubo/pali/ud/vagga5/meta
# Successfully generated mucluc.md in ../docs/kinhtieubo/pali/ud/vagga5
# Successfully generated index.md in ../docs/kinhtieubo/pali/ud/vagga5
# Created ../docs/kinhtieubo/pali/ud/vagga5/meta/filelist.js for vite config.js create next-prev link
# Created ../docs/kinhtieubo/pali/ud/vagga5/meta/mucluc.md for for mucluc.md
# Remember add mucluc.md to url-able path; and add filelist.js to config.ts for next-prev button
# {'text': 'UD 6.1. Āyusaṅkhārossajjanasutta', 'link': '/kinhtieubo/pali/ud/vagga6/ud-6-1-ayusankharossajjanasutta.md'}
# {'text': 'UD 6.10. Uppajjantisutta', 'link': '/kinhtieubo/pali/ud/vagga6/ud-6-10-uppajjantisutta.md'}
# {'text': 'UD 6.2. Sattajaṭilasutta', 'link': '/kinhtieubo/pali/ud/vagga6/ud-6-2-sattajatilasutta.md'}
# {'text': 'UD 6.3. Paccavekkhaṇasutta', 'link': '/kinhtieubo/pali/ud/vagga6/ud-6-3-paccavekkhanasutta.md'}
# {'text': 'UD 6.4. Paṭhamanānātitthiyasutta', 'link': '/kinhtieubo/pali/ud/vagga6/ud-6-4-pathamananatitthiyasutta.md'}
# {'text': 'UD 6.5. Dutiyanānātitthiyasutta', 'link': '/kinhtieubo/pali/ud/vagga6/ud-6-5-dutiyananatitthiyasutta.md'}
# {'text': 'UD 6.6. Tatiyanānātitthiyasutta', 'link': '/kinhtieubo/pali/ud/vagga6/ud-6-6-tatiyananatitthiyasutta.md'}
# {'text': 'UD 6.7. Subhūtisutta', 'link': '/kinhtieubo/pali/ud/vagga6/ud-6-7-subhutisutta.md'}
# {'text': 'UD 6.8. Gaṇikāsutta', 'link': '/kinhtieubo/pali/ud/vagga6/ud-6-8-ganikasutta.md'}
# {'text': 'UD 6.9. Upātidhāvantisutta', 'link': '/kinhtieubo/pali/ud/vagga6/ud-6-9-upatidhavantisutta.md'}
# Successfully generated filelist.js in ../docs/kinhtieubo/pali/ud/vagga6/meta
# Successfully generated mucluc.md in ../docs/kinhtieubo/pali/ud/vagga6
# Successfully generated index.md in ../docs/kinhtieubo/pali/ud/vagga6
# Created ../docs/kinhtieubo/pali/ud/vagga6/meta/filelist.js for vite config.js create next-prev link
# Created ../docs/kinhtieubo/pali/ud/vagga6/meta/mucluc.md for for mucluc.md
# Remember add mucluc.md to url-able path; and add filelist.js to config.ts for next-prev button
# {'text': 'UD 7.1. Paṭhamalakuṇḍakabhaddiyasutta', 'link': '/kinhtieubo/pali/ud/vagga7/ud-7-1-pathamalakundakabhaddiyasutta.md'}
# {'text': 'UD 7.10. Utenasutta', 'link': '/kinhtieubo/pali/ud/vagga7/ud-7-10-utenasutta.md'}
# {'text': 'UD 7.2. Dutiyalakuṇḍakabhaddiyasutta', 'link': '/kinhtieubo/pali/ud/vagga7/ud-7-2-dutiyalakundakabhaddiyasutta.md'}
# {'text': 'UD 7.3. Paṭhamasattasutta', 'link': '/kinhtieubo/pali/ud/vagga7/ud-7-3-pathamasattasutta.md'}
# {'text': 'UD 7.4. Dutiyasattasutta', 'link': '/kinhtieubo/pali/ud/vagga7/ud-7-4-dutiyasattasutta.md'}
# {'text': 'UD 7.5. Aparalakuṇḍakabhaddiyasutta', 'link': '/kinhtieubo/pali/ud/vagga7/ud-7-5-aparalakundakabhaddiyasutta.md'}
# {'text': 'UD 7.6. Taṇhāsaṅkhayasutta', 'link': '/kinhtieubo/pali/ud/vagga7/ud-7-6-tanhasankhayasutta.md'}
# {'text': 'UD 7.7. Papañcakhayasutta', 'link': '/kinhtieubo/pali/ud/vagga7/ud-7-7-papancakhayasutta.md'}
# {'text': 'UD 7.8. Kaccānasutta', 'link': '/kinhtieubo/pali/ud/vagga7/ud-7-8-kaccanasutta.md'}
# {'text': 'UD 7.9. Udapānasutta', 'link': '/kinhtieubo/pali/ud/vagga7/ud-7-9-udapanasutta.md'}
# Successfully generated filelist.js in ../docs/kinhtieubo/pali/ud/vagga7/meta
# Successfully generated mucluc.md in ../docs/kinhtieubo/pali/ud/vagga7
# Successfully generated index.md in ../docs/kinhtieubo/pali/ud/vagga7
# Created ../docs/kinhtieubo/pali/ud/vagga7/meta/filelist.js for vite config.js create next-prev link
# Created ../docs/kinhtieubo/pali/ud/vagga7/meta/mucluc.md for for mucluc.md
# Remember add mucluc.md to url-able path; and add filelist.js to config.ts for next-prev button
# {'text': 'UD 8.1. Paṭhamanibbānapaṭisaṁyuttasutta', 'link': '/kinhtieubo/pali/ud/vagga8/ud-8-1-pathamanibbanapatisamyuttasutta.md'}
# {'text': 'UD 8.10. Dutiyadabbasutta', 'link': '/kinhtieubo/pali/ud/vagga8/ud-8-10-dutiyadabbasutta.md'}
# {'text': 'UD 8.2. Dutiyanibbānapaṭisaṁyuttasutta', 'link': '/kinhtieubo/pali/ud/vagga8/ud-8-2-dutiyanibbanapatisamyuttasutta.md'}
# {'text': 'UD 8.3. Tatiyanibbānapaṭisaṁyuttasutta', 'link': '/kinhtieubo/pali/ud/vagga8/ud-8-3-tatiyanibbanapatisamyuttasutta.md'}
# {'text': 'UD 8.4. Catutthanibbānapaṭisaṁyuttasutta', 'link': '/kinhtieubo/pali/ud/vagga8/ud-8-4-catutthanibbanapatisamyuttasutta.md'}
# {'text': 'UD 8.5. Cundasutta', 'link': '/kinhtieubo/pali/ud/vagga8/ud-8-5-cundasutta.md'}
# {'text': 'UD 8.6. Pāṭaligāmiyasutta', 'link': '/kinhtieubo/pali/ud/vagga8/ud-8-6-pataligamiyasutta.md'}
# {'text': 'UD 8.7. Dvidhāpathasutta', 'link': '/kinhtieubo/pali/ud/vagga8/ud-8-7-dvidhapathasutta.md'}
# {'text': 'UD 8.8. Visākhāsutta', 'link': '/kinhtieubo/pali/ud/vagga8/ud-8-8-visakhasutta.md'}
# {'text': 'UD 8.9. Paṭhamadabbasutta', 'link': '/kinhtieubo/pali/ud/vagga8/ud-8-9-pathamadabbasutta.md'}
# Successfully generated filelist.js in ../docs/kinhtieubo/pali/ud/vagga8/meta
# Successfully generated mucluc.md in ../docs/kinhtieubo/pali/ud/vagga8
# Successfully generated index.md in ../docs/kinhtieubo/pali/ud/vagga8
# Created ../docs/kinhtieubo/pali/ud/vagga8/meta/filelist.js for vite config.js create next-prev link
# Created ../docs/kinhtieubo/pali/ud/vagga8/meta/mucluc.md for for mucluc.md
# Remember add mucluc.md to url-able path; and add filelist.js to config.ts for next-prev button
