# %%
import os
import re

def generate_filelist(folder_path, listname, folder_out):
    """
    filelist.js using for generate next/back button config in config.js
    mucluc.md using for generate table of contents

    Generates a JavaScript filelist from Markdown files in a folder.

    Args:
        folder_path: The path to the folder containing the Markdown files.
        listname: The name to use for the JavaScript constant and export.

    Returns:
        None.  Writes the output to a file named 'filelist.js' in the input folder.
    """

    file_list = []
    _lst = sorted([f for f in os.listdir(folder_path) if f.endswith('.md')])
    for filename in _lst:
        # print(filename)
        file_path = os.path.join(folder_path, filename)
        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                first_line = f.readline().strip()
                # Match lines starting with '#' followed by a space and capture the rest.
                match = re.match(r"^#\s+(.*)", first_line)
                if match:
                    title = match.group(1).strip()
                    # Create file_item dict and handle exceptions
                    file_item = {
                        "text": title,
                        "link": os.path.join(folder_out, filename).replace("\\", "/")  # handle Windows path
                    }
                    file_list.append(file_item)
                    print(file_item)
                else:
                    print(f"Warning: No title found in {filename}, see `9headerformat.ipynb`")


        except FileNotFoundError:
            print(f"Error: File not found: {file_path}")
        except Exception as e:
            print(f"Error reading or processing {filename}: {e}")

    # Sort the file list alphabetically by 'text'
    # file_list.sort(key=lambda x: x['text'])

    # Generate the JavaScript code.
    js_code = f"const {listname} = [\n"
    for item in file_list:
        js_code += f'  {{ text: "{item["text"]}", link: "{item["link"]}" }},\n'
    js_code += "];\n"
    js_code += f"export default {listname};\n"

    # Write the JavaScript code to filelist.js
    output_file_path = os.path.join(folder_path, "filelist.js")
    try:
        with open(output_file_path, 'w', encoding='utf-8') as outfile:
            outfile.write(js_code)
        print(f"Successfully generated filelist.js in {folder_path}")
    except Exception as e:
        print(f"Error writing to filelist.js: {e}")

    # Generate the Markdown table of contents (mucluc.md)
    md_toc = ""
    for item in file_list:
        md_toc += f'- [{item["text"]}]({item["link"]})\n'

    # Write the Markdown TOC to mucluc.md
    output_md_path = os.path.join(folder_path, "mucluc.md")
    try:
        with open(output_md_path, 'w', encoding='utf-8') as outfile:
            outfile.write(md_toc)
        print(f"Successfully generated mucluc.md in {folder_path}")
    except Exception as e:
        print(f"Error writing to mucluc.md: {e}")

    print(f"Created {output_file_path} for vite config.js create next-prev link")
    print(f"Created {output_md_path} for for mucluc.md ")




## step 3 - MAKE MUCLUC-NAVFILE


alang = "vi"
kinh = "kinhtrungbo"
author="pali"

# folder contain list of file
folder_for_scan = f"../docs/{kinh}/{author}-{alang}"
# output variable in filelist.js
print_listname = f"{kinh}_{author}_{alang}"
# output variable in filelist.js
print_folder_path = f'/{kinh}/{author}-{alang}'

# folder_for_scan = f"../docs/jill-brain/vi"
# print_listname = f"jill"
# print_folder_path = f'/docs/jill-brain/vi'

if not os.path.isdir(folder_for_scan):
    print(f"Error: The provided folder path '{folder_for_scan}' is not a valid directory.")
else:
    generate_filelist(folder_for_scan, print_listname, print_folder_path)
    print("Remember add mucluc.md to url-able path; and add filelist.js to config.ts for next-prev button")
# Out:
# Warning: No title found in 002-kinh-tat-ca-cac-lau-hoac.md, see `9headerformat.ipynb`
# Warning: No title found in 043-dai-kinh-phuong-quang.md, see `9headerformat.ipynb`
# {'text': '118. KINH NHẬP TỨC, XUẤT TỨC NIỆM', 'link': '/kinhtrungbo/pali-vi/118-kinh-nhap-tuc-xuat-tuc-niem.md'}
# {'text': 'MN 1. KINH VỀ NGUYÊN LÝ CỐT LÕI (Mūlapariyāyasutta)', 'link': '/kinhtrungbo/pali-vi/mn-001.md'}
# {'text': 'Sabbāsavasutta', 'link': '/kinhtrungbo/pali-vi/mn-002.md'}
# {'text': 'Dhammadāyādasutta', 'link': '/kinhtrungbo/pali-vi/mn-003.md'}
# {'text': 'Bhayabheravasutta', 'link': '/kinhtrungbo/pali-vi/mn-004.md'}
# {'text': 'Anaṅgaṇasutta', 'link': '/kinhtrungbo/pali-vi/mn-005.md'}
# {'text': 'Ākaṅkheyyasutta', 'link': '/kinhtrungbo/pali-vi/mn-006.md'}
# {'text': 'Vatthasutta Variant: Vatthasutta → vatthūpamasuttaṁ (bj, sya-all, pts1ed)', 'link': '/kinhtrungbo/pali-vi/mn-007.md'}
# {'text': 'Sallekhasutta', 'link': '/kinhtrungbo/pali-vi/mn-008.md'}
# {'text': 'Sammādiṭṭhisutta', 'link': '/kinhtrungbo/pali-vi/mn-009.md'}
# {'text': 'Satipaṭṭhānasutta', 'link': '/kinhtrungbo/pali-vi/mn-010.md'}
# {'text': 'Cūḷasīhanādasutta', 'link': '/kinhtrungbo/pali-vi/mn-011.md'}
# {'text': 'Mahāsīhanādasutta', 'link': '/kinhtrungbo/pali-vi/mn-012.md'}
# {'text': 'Mahādukkhakkhandhasutta', 'link': '/kinhtrungbo/pali-vi/mn-013.md'}
# {'text': 'Cūḷadukkhakkhandhasutta', 'link': '/kinhtrungbo/pali-vi/mn-014.md'}
# {'text': 'Anumānasutta', 'link': '/kinhtrungbo/pali-vi/mn-015.md'}
# {'text': 'Cetokhilasutta Variant: Cetokhilasutta → cetokhīlasuttaṁ (sya1ed, sya2ed, pts1ed)', 'link': '/kinhtrungbo/pali-vi/mn-016.md'}
# {'text': 'Vanapatthasutta', 'link': '/kinhtrungbo/pali-vi/mn-017.md'}
# {'text': 'Madhupiṇḍikasutta', 'link': '/kinhtrungbo/pali-vi/mn-018.md'}
# {'text': 'Dvedhāvitakkasutta', 'link': '/kinhtrungbo/pali-vi/mn-019.md'}
# {'text': 'Vitakkasaṇṭhānasutta', 'link': '/kinhtrungbo/pali-vi/mn-020.md'}
# {'text': 'Kakacūpamasutta', 'link': '/kinhtrungbo/pali-vi/mn-021.md'}
# {'text': 'Alagaddūpamasutta', 'link': '/kinhtrungbo/pali-vi/mn-022.md'}
# {'text': 'Vammikasutta', 'link': '/kinhtrungbo/pali-vi/mn-023.md'}
# {'text': 'Rathavinītasutta', 'link': '/kinhtrungbo/pali-vi/mn-024.md'}
# {'text': 'Nivāpasutta', 'link': '/kinhtrungbo/pali-vi/mn-025.md'}
# {'text': 'Pāsarāsisutta Variant: Pāsarāsisutta → ariyapariyesanasuttaṁ (bj, pts1ed)', 'link': '/kinhtrungbo/pali-vi/mn-026.md'}
# {'text': 'Cūḷahatthipadopamasutta', 'link': '/kinhtrungbo/pali-vi/mn-027.md'}
# {'text': 'Mahāhatthipadopamasutta', 'link': '/kinhtrungbo/pali-vi/mn-028.md'}
# {'text': 'Mahāsāropamasutta', 'link': '/kinhtrungbo/pali-vi/mn-029.md'}
# {'text': 'Cūḷasāropamasutta', 'link': '/kinhtrungbo/pali-vi/mn-030.md'}
# {'text': 'Cūḷagosiṅgasutta', 'link': '/kinhtrungbo/pali-vi/mn-031.md'}
# {'text': 'Mahāgosiṅgasutta', 'link': '/kinhtrungbo/pali-vi/mn-032.md'}
# {'text': 'Mahāgopālakasutta', 'link': '/kinhtrungbo/pali-vi/mn-033.md'}
# {'text': 'Cūḷagopālakasutta', 'link': '/kinhtrungbo/pali-vi/mn-034.md'}
# {'text': 'Cūḷasaccakasutta', 'link': '/kinhtrungbo/pali-vi/mn-035.md'}
# {'text': 'Mahāsaccakasutta', 'link': '/kinhtrungbo/pali-vi/mn-036.md'}
# {'text': 'Cūḷataṇhāsaṅkhayasutta', 'link': '/kinhtrungbo/pali-vi/mn-037.md'}
# {'text': 'Mahātaṇhāsaṅkhayasutta', 'link': '/kinhtrungbo/pali-vi/mn-038.md'}
# {'text': 'Mahāassapurasutta', 'link': '/kinhtrungbo/pali-vi/mn-039.md'}
# {'text': 'Cūḷaassapurasutta', 'link': '/kinhtrungbo/pali-vi/mn-040.md'}
# {'text': 'Sāleyyakasutta', 'link': '/kinhtrungbo/pali-vi/mn-041.md'}
# {'text': 'Verañjakasutta', 'link': '/kinhtrungbo/pali-vi/mn-042.md'}
# {'text': 'Mahāvedallasutta', 'link': '/kinhtrungbo/pali-vi/mn-043.md'}
# {'text': 'Cūḷavedallasutta', 'link': '/kinhtrungbo/pali-vi/mn-044.md'}
# {'text': 'Cūḷadhammasamādānasutta', 'link': '/kinhtrungbo/pali-vi/mn-045.md'}
# {'text': 'Mahādhammasamādānasutta', 'link': '/kinhtrungbo/pali-vi/mn-046.md'}
# {'text': 'Vīmaṁsakasutta', 'link': '/kinhtrungbo/pali-vi/mn-047.md'}
# {'text': 'Kosambiyasutta', 'link': '/kinhtrungbo/pali-vi/mn-048.md'}
# {'text': 'Brahmanimantanikasutta', 'link': '/kinhtrungbo/pali-vi/mn-049.md'}
# {'text': 'Māratajjanīyasutta', 'link': '/kinhtrungbo/pali-vi/mn-050.md'}
# {'text': 'Kandarakasutta', 'link': '/kinhtrungbo/pali-vi/mn-051.md'}
# {'text': 'Aṭṭhakanāgarasutta', 'link': '/kinhtrungbo/pali-vi/mn-052.md'}
# {'text': 'Sekhasutta Variant: Sekhasutta → sekhapaṭipadāsuttaṁ (sya-all)', 'link': '/kinhtrungbo/pali-vi/mn-053.md'}
# {'text': 'Potaliyasutta', 'link': '/kinhtrungbo/pali-vi/mn-054.md'}
# {'text': 'Jīvakasutta', 'link': '/kinhtrungbo/pali-vi/mn-055.md'}
# {'text': 'Upālisutta Variant: Upālisutta → upālivādasuttaṁ (sya-all)', 'link': '/kinhtrungbo/pali-vi/mn-056.md'}
# {'text': 'Kukkuravatikasutta', 'link': '/kinhtrungbo/pali-vi/mn-057.md'}
# {'text': 'Abhayarājakumārasutta', 'link': '/kinhtrungbo/pali-vi/mn-058.md'}
# {'text': 'Bahuvedanīyasutta', 'link': '/kinhtrungbo/pali-vi/mn-059.md'}
# {'text': 'Apaṇṇakasutta', 'link': '/kinhtrungbo/pali-vi/mn-060.md'}
# {'text': 'Ambalaṭṭhikarāhulovādasutta', 'link': '/kinhtrungbo/pali-vi/mn-061.md'}
# {'text': 'Mahārāhulovādasutta', 'link': '/kinhtrungbo/pali-vi/mn-062.md'}
# {'text': 'Cūḷamālukyasutta', 'link': '/kinhtrungbo/pali-vi/mn-063.md'}
# {'text': 'Mahāmālukyasutta', 'link': '/kinhtrungbo/pali-vi/mn-064.md'}
# {'text': 'Bhaddālisutta', 'link': '/kinhtrungbo/pali-vi/mn-065.md'}
# {'text': 'Laṭukikopamasutta', 'link': '/kinhtrungbo/pali-vi/mn-066.md'}
# {'text': 'Cātumasutta', 'link': '/kinhtrungbo/pali-vi/mn-067.md'}
# {'text': 'Naḷakapānasutta', 'link': '/kinhtrungbo/pali-vi/mn-068.md'}
# {'text': 'Goliyānisutta Variant: Goliyānisutta → gulissānisuttaṁ (bj); golissānisuttaṁ (sya-all)', 'link': '/kinhtrungbo/pali-vi/mn-069.md'}
# {'text': 'Kīṭāgirisutta', 'link': '/kinhtrungbo/pali-vi/mn-070.md'}
# {'text': 'Tevijjavacchasutta', 'link': '/kinhtrungbo/pali-vi/mn-071.md'}
# {'text': 'Aggivacchasutta', 'link': '/kinhtrungbo/pali-vi/mn-072.md'}
# {'text': 'Mahāvacchasutta', 'link': '/kinhtrungbo/pali-vi/mn-073.md'}
# {'text': 'Dīghanakhasutta', 'link': '/kinhtrungbo/pali-vi/mn-074.md'}
# {'text': 'Māgaṇḍiyasutta Variant: Māgaṇḍiyasutta → māgandiyasuttaṁ (bj)', 'link': '/kinhtrungbo/pali-vi/mn-075.md'}
# {'text': 'Sandakasutta', 'link': '/kinhtrungbo/pali-vi/mn-076.md'}
# {'text': 'Mahāsakuludāyisutta', 'link': '/kinhtrungbo/pali-vi/mn-077.md'}
# {'text': 'Samaṇamuṇḍikasutta', 'link': '/kinhtrungbo/pali-vi/mn-078.md'}
# {'text': 'Cūḷasakuludāyisutta', 'link': '/kinhtrungbo/pali-vi/mn-079.md'}
# {'text': 'Vekhanasasutta Variant: Vekhanasasutta → vekhanassasuttaṁ (bj); vekhaṇasasuttaṁ (sya-all)', 'link': '/kinhtrungbo/pali-vi/mn-080.md'}
# {'text': 'Ghaṭikārasutta', 'link': '/kinhtrungbo/pali-vi/mn-081.md'}
# {'text': 'Raṭṭhapālasutta', 'link': '/kinhtrungbo/pali-vi/mn-082.md'}
# {'text': 'Maghadevasutta Variant: Maghadevasutta → makhādevasuttaṁ (bj)', 'link': '/kinhtrungbo/pali-vi/mn-083.md'}
# {'text': 'Madhurasutta', 'link': '/kinhtrungbo/pali-vi/mn-084.md'}
# {'text': 'Bodhirājakumārasutta', 'link': '/kinhtrungbo/pali-vi/mn-085.md'}
# {'text': 'Aṅgulimālasutta', 'link': '/kinhtrungbo/pali-vi/mn-086.md'}
# {'text': 'Piyajātikasutta', 'link': '/kinhtrungbo/pali-vi/mn-087.md'}
# {'text': 'Bāhitikasutta Variant: Bāhitikasutta → bāhitiyasuttaṁ (sya-all)', 'link': '/kinhtrungbo/pali-vi/mn-088.md'}
# {'text': 'Dhammacetiyasutta', 'link': '/kinhtrungbo/pali-vi/mn-089.md'}
# {'text': 'Kaṇṇakatthalasutta', 'link': '/kinhtrungbo/pali-vi/mn-090.md'}
# {'text': 'Brahmāyusutta', 'link': '/kinhtrungbo/pali-vi/mn-091.md'}
# {'text': 'Selasutta', 'link': '/kinhtrungbo/pali-vi/mn-092.md'}
# {'text': 'Assalāyanasutta', 'link': '/kinhtrungbo/pali-vi/mn-093.md'}
# {'text': 'Ghoṭamukhasutta', 'link': '/kinhtrungbo/pali-vi/mn-094.md'}
# {'text': 'Caṅkīsutta', 'link': '/kinhtrungbo/pali-vi/mn-095.md'}
# {'text': 'Esukārīsutta', 'link': '/kinhtrungbo/pali-vi/mn-096.md'}
# {'text': 'Dhanañjānisutta', 'link': '/kinhtrungbo/pali-vi/mn-097.md'}
# {'text': 'Vāseṭṭhasutta', 'link': '/kinhtrungbo/pali-vi/mn-098.md'}
# {'text': 'Subhasutta', 'link': '/kinhtrungbo/pali-vi/mn-099.md'}
# {'text': 'Saṅgāravasutta', 'link': '/kinhtrungbo/pali-vi/mn-100.md'}
# {'text': 'Devadahasutta', 'link': '/kinhtrungbo/pali-vi/mn-101.md'}
# {'text': 'Pañcattayasutta', 'link': '/kinhtrungbo/pali-vi/mn-102.md'}
# {'text': 'Kintisutta', 'link': '/kinhtrungbo/pali-vi/mn-103.md'}
# {'text': 'Sāmagāmasutta', 'link': '/kinhtrungbo/pali-vi/mn-104.md'}
# {'text': 'Sunakkhattasutta', 'link': '/kinhtrungbo/pali-vi/mn-105.md'}
# {'text': 'Āneñjasappāyasutta', 'link': '/kinhtrungbo/pali-vi/mn-106.md'}
# {'text': 'Gaṇakamoggallānasutta', 'link': '/kinhtrungbo/pali-vi/mn-107.md'}
# {'text': 'Gopakamoggallānasutta', 'link': '/kinhtrungbo/pali-vi/mn-108.md'}
# {'text': 'Mahāpuṇṇamasutta', 'link': '/kinhtrungbo/pali-vi/mn-109.md'}
# {'text': 'Cūḷapuṇṇamasutta', 'link': '/kinhtrungbo/pali-vi/mn-110.md'}
# {'text': 'Anupadasutta', 'link': '/kinhtrungbo/pali-vi/mn-111.md'}
# {'text': 'Chabbisodhanasutta', 'link': '/kinhtrungbo/pali-vi/mn-112.md'}
# {'text': 'Sappurisasutta', 'link': '/kinhtrungbo/pali-vi/mn-113.md'}
# {'text': 'Sevitabbāsevitabbasutta', 'link': '/kinhtrungbo/pali-vi/mn-114.md'}
# {'text': 'Bahudhātukasutta', 'link': '/kinhtrungbo/pali-vi/mn-115.md'}
# {'text': 'Isigilisutta', 'link': '/kinhtrungbo/pali-vi/mn-116.md'}
# {'text': 'Mahācattārīsakasutta', 'link': '/kinhtrungbo/pali-vi/mn-117.md'}
# {'text': 'Ānāpānassatisutta', 'link': '/kinhtrungbo/pali-vi/mn-118.md'}
# {'text': 'Kāyagatāsatisutta', 'link': '/kinhtrungbo/pali-vi/mn-119.md'}
# {'text': 'Saṅkhārupapattisutta', 'link': '/kinhtrungbo/pali-vi/mn-120.md'}
# {'text': 'Cūḷasuññatasutta', 'link': '/kinhtrungbo/pali-vi/mn-121.md'}
# {'text': 'Mahāsuññatasutta', 'link': '/kinhtrungbo/pali-vi/mn-122.md'}
# {'text': 'Acchariyaabbhutasutta', 'link': '/kinhtrungbo/pali-vi/mn-123.md'}
# {'text': 'Bākulasutta Variant: Bākulasutta → bakkulasuttaṁ (bj, pts1ed); bakkulatheracchariyabbhūtasuttaṁ (cck, sya1ed); bakkulattheracchariyabbhūtasuttaṁ (sya2ed)', 'link': '/kinhtrungbo/pali-vi/mn-124.md'}
# {'text': 'Dantabhūmisutta', 'link': '/kinhtrungbo/pali-vi/mn-125.md'}
# {'text': 'Bhūmijasutta', 'link': '/kinhtrungbo/pali-vi/mn-126.md'}
# {'text': 'Anuruddhasutta', 'link': '/kinhtrungbo/pali-vi/mn-127.md'}
# {'text': 'Upakkilesasutta', 'link': '/kinhtrungbo/pali-vi/mn-128.md'}
# {'text': 'Bālapaṇḍitasutta', 'link': '/kinhtrungbo/pali-vi/mn-129.md'}
# {'text': 'Devadūtasutta', 'link': '/kinhtrungbo/pali-vi/mn-130.md'}
# {'text': 'Bhaddekarattasutta', 'link': '/kinhtrungbo/pali-vi/mn-131.md'}
# {'text': 'Ānandabhaddekarattasutta', 'link': '/kinhtrungbo/pali-vi/mn-132.md'}
# {'text': 'Mahākaccānabhaddekarattasutta', 'link': '/kinhtrungbo/pali-vi/mn-133.md'}
# {'text': 'Lomasakaṅgiyabhaddekarattasutta', 'link': '/kinhtrungbo/pali-vi/mn-134.md'}
# {'text': 'Cūḷakammavibhaṅgasutta', 'link': '/kinhtrungbo/pali-vi/mn-135.md'}
# {'text': 'Mahākammavibhaṅgasutta', 'link': '/kinhtrungbo/pali-vi/mn-136.md'}
# {'text': 'Saḷāyatanavibhaṅgasutta', 'link': '/kinhtrungbo/pali-vi/mn-137.md'}
# {'text': 'Uddesavibhaṅgasutta', 'link': '/kinhtrungbo/pali-vi/mn-138.md'}
# {'text': 'Araṇavibhaṅgasutta', 'link': '/kinhtrungbo/pali-vi/mn-139.md'}
# {'text': 'Dhātuvibhaṅgasutta', 'link': '/kinhtrungbo/pali-vi/mn-140.md'}
# {'text': 'Saccavibhaṅgasutta', 'link': '/kinhtrungbo/pali-vi/mn-141.md'}
# {'text': 'Dakkhiṇāvibhaṅgasutta', 'link': '/kinhtrungbo/pali-vi/mn-142.md'}
# {'text': 'Anāthapiṇḍikovādasutta', 'link': '/kinhtrungbo/pali-vi/mn-143.md'}
# {'text': 'Channovādasutta', 'link': '/kinhtrungbo/pali-vi/mn-144.md'}
# {'text': 'Puṇṇovādasutta', 'link': '/kinhtrungbo/pali-vi/mn-145.md'}
# {'text': 'Nandakovādasutta', 'link': '/kinhtrungbo/pali-vi/mn-146.md'}
# {'text': 'Cūḷarāhulovādasutta', 'link': '/kinhtrungbo/pali-vi/mn-147.md'}
# {'text': 'Chachakkasutta', 'link': '/kinhtrungbo/pali-vi/mn-148.md'}
# {'text': 'Mahāsaḷāyatanikasutta', 'link': '/kinhtrungbo/pali-vi/mn-149.md'}
# {'text': 'Nagaravindeyyasutta', 'link': '/kinhtrungbo/pali-vi/mn-150.md'}
# {'text': 'Piṇḍapātapārisuddhisutta', 'link': '/kinhtrungbo/pali-vi/mn-151.md'}
# {'text': 'Indriyabhāvanāsutta', 'link': '/kinhtrungbo/pali-vi/mn-152.md'}
# Successfully generated filelist.js in ../docs/kinhtrungbo/pali-vi
# Successfully generated mucluc.md in ../docs/kinhtrungbo/pali-vi
# Created ../docs/kinhtrungbo/pali-vi/filelist.js for vite config.js create next-prev link
# Created ../docs/kinhtrungbo/pali-vi/mucluc.md for for mucluc.md
# Remember add mucluc.md to url-able path; and add filelist.js to config.ts for next-prev button
