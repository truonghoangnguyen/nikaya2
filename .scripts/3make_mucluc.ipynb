# %%
import os
import re

def generate_filelist(folder_path, listname, folder_out):
    """
    filelist.js using for generate next/back button config in config.js
    mucluc.md using for generate table of contents

    Generates a JavaScript filelist from Markdown files in a folder.

    Args:
        folder_path: The path to the folder containing the Markdown files.
        listname: The name to use for the JavaScript constant and export.

    Returns:
        None.  Writes the output to a file named 'filelist.js' in the input folder.
    """

    file_list = []
    _lst = sorted([f for f in os.listdir(folder_path) if f.endswith('.md')])
    for filename in _lst:
        # print(filename)
        file_path = os.path.join(folder_path, filename)
        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                first_line = f.readline().strip()
                # Match lines starting with '#' followed by a space and capture the rest.
                match = re.match(r"^#\s+(.*)", first_line)
                if match:
                    title = match.group(1).strip()
                    # Create file_item dict and handle exceptions
                    file_item = {
                        "text": title,
                        "link": os.path.join(folder_out, filename).replace("\\", "/")  # handle Windows path
                    }
                    file_list.append(file_item)
                    print(file_item)
                else:
                    print(f"Warning: No title found in {filename}, see `9headerformat.ipynb`")


        except FileNotFoundError:
            print(f"Error: File not found: {file_path}")
        except Exception as e:
            print(f"Error reading or processing {filename}: {e}")

    # Sort the file list alphabetically by 'text'
    # file_list.sort(key=lambda x: x['text'])

    # Generate the JavaScript code.
    js_code = f"const {listname} = [\n"
    for item in file_list:
        js_code += f'  {{ text: "{item["text"]}", link: "{item["link"]}" }},\n'
    js_code += "];\n"
    js_code += f"export default {listname};\n"

    # Write the JavaScript code to filelist.js
    output_file_path = os.path.join(folder_path, "filelist.js")
    try:
        with open(output_file_path, 'w', encoding='utf-8') as outfile:
            outfile.write(js_code)
        print(f"Successfully generated filelist.js in {folder_path}")
    except Exception as e:
        print(f"Error writing to filelist.js: {e}")

    # Generate the Markdown table of contents (mucluc.md)
    md_toc = ""
    for item in file_list:
        md_toc += f'- [{item["text"]}]({item["link"]})\n'

    # Write the Markdown TOC to mucluc.md
    output_md_path = os.path.join(folder_path, "mucluc.md")
    try:
        with open(output_md_path, 'w', encoding='utf-8') as outfile:
            outfile.write(md_toc)
        print(f"Successfully generated mucluc.md in {folder_path}")
    except Exception as e:
        print(f"Error writing to mucluc.md: {e}")

    print(f"Created {output_file_path} for vite config.js create next-prev link")
    print(f"Created {output_md_path} for for mucluc.md ")




## step 3 - MAKE MUCLUC-NAVFILE


alang = "en"
kinh = "kinhtangchi"
author="sujato"

# folder contain list of file
folder_for_scan = f"../docs/{kinh}/{author}-{alang}/1/"
# output variable in filelist.js
print_listname = f"{kinh}_{author}_{alang}"
# output variable in filelist.js
print_folder_path = f'/{kinh}/{author}-{alang}'

# folder_for_scan = "../docs/kinhtangchi/thichminhchau/1/"
# print_listname = "kinhtangchi_thichminhchau"
# print_folder_path = '/kinhtangchi/thichminhchau/'

if not os.path.isdir(folder_for_scan):
    print(f"Error: The provided folder path '{folder_for_scan}' is not a valid directory.")
else:
    generate_filelist(folder_for_scan, print_listname, print_folder_path)
    print("Remember add mucluc.md to url-able path; and add filelist.js to config.ts for next-prev button")
# Out:
# {'text': 'The Chapter on Wealth', 'link': '/kinhtangchi/sujato-en/07-001-the-chapter-on-wealth.md'}
# {'text': 'The Chapter on Tendencies', 'link': '/kinhtangchi/sujato-en/07-002-the-chapter-on-tendencies.md'}
# {'text': 'The Chapter on the Vajji Seven', 'link': '/kinhtangchi/sujato-en/07-003-the-chapter-on-the-vajji-seven.md'}
# {'text': 'The Chapter on Deities', 'link': '/kinhtangchi/sujato-en/07-004-the-chapter-on-deities.md'}
# {'text': 'The Chapter on a Great Sacrifice', 'link': '/kinhtangchi/sujato-en/07-005-the-chapter-on-a-great-sacrifice.md'}
# {'text': 'The Chapter on the Undeclared Points', 'link': '/kinhtangchi/sujato-en/07-006-the-chapter-on-the-undeclared-points.md'}
# {'text': 'The Great Chapter', 'link': '/kinhtangchi/sujato-en/07-007-the-great-chapter.md'}
# {'text': 'The Chapter on the Monastic Law', 'link': '/kinhtangchi/sujato-en/07-008-the-chapter-on-the-monastic-law.md'}
# {'text': 'The Chapter on Ascetics', 'link': '/kinhtangchi/sujato-en/07-009-the-chapter-on-ascetics.md'}
# {'text': 'The Chapter on Love', 'link': '/kinhtangchi/sujato-en/08-001-the-chapter-on-love.md'}
# {'text': 'The Great Chapter', 'link': '/kinhtangchi/sujato-en/08-002-the-great-chapter.md'}
# {'text': 'The Chapter on Householders', 'link': '/kinhtangchi/sujato-en/08-003-the-chapter-on-householders.md'}
# {'text': 'The Chapter on Giving', 'link': '/kinhtangchi/sujato-en/08-004-the-chapter-on-giving.md'}
# {'text': 'The Chapter on Sabbath', 'link': '/kinhtangchi/sujato-en/08-005-the-chapter-on-sabbath.md'}
# {'text': 'The Chapter on Gotamī', 'link': '/kinhtangchi/sujato-en/08-006-the-chapter-on-gotami.md'}
# {'text': 'The Chapter on Earthquakes', 'link': '/kinhtangchi/sujato-en/08-007-the-chapter-on-earthquakes.md'}
# {'text': 'The Chapter on Pairs', 'link': '/kinhtangchi/sujato-en/08-008-the-chapter-on-pairs.md'}
# {'text': 'The Chapter on Mindfulness', 'link': '/kinhtangchi/sujato-en/08-009-the-chapter-on-mindfulness.md'}
# Warning: No title found in 08-010-the-chapter-on-similarity.md, see `9headerformat.ipynb`
# {'text': 'The Chapter on Awakening', 'link': '/kinhtangchi/sujato-en/09-001-the-chapter-on-awakening.md'}
# {'text': "The Chapter on the Lion's Roar", 'link': '/kinhtangchi/sujato-en/09-002-the-chapter-on-the-lion-s-roar.md'}
# {'text': 'The Chapter on Abodes of Sentient Beings', 'link': '/kinhtangchi/sujato-en/09-003-the-chapter-on-abodes-of-sentient-beings.md'}
# {'text': 'The Great Chapter', 'link': '/kinhtangchi/sujato-en/09-004-the-great-chapter.md'}
# {'text': 'The Chapter on Similarity', 'link': '/kinhtangchi/sujato-en/09-005-the-chapter-on-similarity.md'}
# {'text': 'The Chapter on a Safe Place', 'link': '/kinhtangchi/sujato-en/09-006-the-chapter-on-a-safe-place.md'}
# {'text': 'The Chapter on Mindfulness Meditation', 'link': '/kinhtangchi/sujato-en/09-007-the-chapter-on-mindfulness-meditation.md'}
# {'text': 'The Chapter on Right Efforts', 'link': '/kinhtangchi/sujato-en/09-008-the-chapter-on-right-efforts.md'}
# {'text': 'The Chapter on Bases of Psychic Power', 'link': '/kinhtangchi/sujato-en/09-009-the-chapter-on-bases-of-psychic-power.md'}
# {'text': 'Abbreviated Texts Beginning With Greed', 'link': '/kinhtangchi/sujato-en/09-010-the-chapter-on-bases-of-psychic-power2.md'}
# Warning: No title found in mucluc.md, see `9headerformat.ipynb`
# Successfully generated filelist.js in ../docs/kinhtangchi/sujato-en/1/
# Successfully generated mucluc.md in ../docs/kinhtangchi/sujato-en/1/
# Created ../docs/kinhtangchi/sujato-en/1/filelist.js for vite config.js create next-prev link
# Created ../docs/kinhtangchi/sujato-en/1/mucluc.md for for mucluc.md
# Remember add mucluc.md to url-able path; and add filelist.js to config.ts for next-prev button
