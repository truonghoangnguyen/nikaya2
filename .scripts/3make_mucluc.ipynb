# %%
import os
import re

def generate_filelist(folder_path, listname, folder_out):
    """
    filelist.js using for generate next/back button config in config.js
    mucluc.md using for generate table of contents

    Generates a JavaScript filelist from Markdown files in a folder.

    Args:
        folder_path: The path to the folder containing the Markdown files.
        listname: The name to use for the JavaScript constant and export.

    Returns:
        None.  Writes the output to a file named 'filelist.js' in the input folder.
    """
    os.makedirs(os.path.join(folder_path, 'meta'), exist_ok=True)


    file_list = []
    _lst = sorted([f for f in os.listdir(folder_path) if f.endswith('.md')])
    for filename in _lst:
        # print(filename)
        file_path = os.path.join(folder_path, filename)
        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                first_line = f.readline().strip()
                # Match lines starting with '#' followed by a space and capture the rest.
                match = re.match(r"^#\s+(.*)", first_line)
                if match:
                    title = match.group(1).strip()
                    # Create file_item dict and handle exceptions
                    file_item = {
                        "text": title,
                        "link": os.path.join(folder_out, filename).replace("\\", "/")  # handle Windows path
                    }
                    file_list.append(file_item)
                    print(file_item)
                else:
                    print(f"Warning: No title found in {filename}, see `9headerformat.ipynb`")


        except FileNotFoundError:
            print(f"Error: File not found: {file_path}")
        except Exception as e:
            print(f"Error reading or processing {filename}: {e}")

    # Sort the file list alphabetically by 'text'
    # file_list.sort(key=lambda x: x['text'])

    # Generate the JavaScript code.
    js_code = f"const {listname} = [\n"
    for item in file_list:
        js_code += f'  {{ text: "{item["text"]}", link: "{item["link"]}" }},\n'
    js_code += "];\n"
    js_code += f"export default {listname};\n"

    meta_path = folder_path+"/meta"
    # Write the JavaScript code to filelist.js
    output_file_path = os.path.join(meta_path, "filelist.js")
    try:
        with open(output_file_path, 'w', encoding='utf-8') as outfile:
            outfile.write(js_code)
        print(f"Successfully generated filelist.js in {meta_path}")
    except Exception as e:
        print(f"Error writing to filelist.js: {e}")

    # Generate the Markdown table of contents (mucluc.md)
    md_toc = ""
    for item in file_list:
        md_toc += f'- [{item["text"]}]({item["link"]})\n'

    # Write the Markdown TOC to mucluc.md
    output_md_path = os.path.join(meta_path, "mucluc.md")
    try:
        with open(output_md_path, 'w', encoding='utf-8') as outfile:
            outfile.write(md_toc)
        print(f"Successfully generated mucluc.md in {folder_path}")
    except Exception as e:
        print(f"Error writing to mucluc.md: {e}")

    # Generate index.md
    output_index_path = os.path.join(folder_path, "index.md")
    try:
        with open(output_index_path, 'w', encoding='utf-8') as outfile:
            outfile.write("<!--@include: ./meta/mucluc.md-->")
        print(f"Successfully generated index.md in {folder_path}")
    except Exception as e:
        print(f"Error writing to index.md: {e}")


    print(f"Created {output_file_path} for vite config.js create next-prev link")
    print(f"Created {output_md_path} for for mucluc.md ")




## step 3 - MAKE MUCLUC-NAVFILE


alang = "vi"
kinh = "kinhtuongung"
author="pali"
if alang != "":
    # folder contain list of file
    #folder_for_scan = f"../docs/{kinh}/{author}-{alang}/intro"
    folder_for_scan = f"../docs/{kinh}/{author}-{alang}"
    # output variable in filelist.js
    print_listname = f"{kinh}_{author}_{alang}"
    # output variable in filelist.js
    #print_folder_path = f'/{kinh}/{author}-{alang}/intro'
    print_folder_path = f'/{kinh}/{author}-{alang}'
else:
    folder_for_scan = f"../docs/{kinh}/{author}"
    # output variable in filelist.js
    print_listname = f"{kinh}_{author}"
    # output variable in filelist.js
    print_folder_path = f'/{kinh}/{author}'

# folder_for_scan = f"../docs/jill-brain/vi"
# print_listname = f"jill"
# print_folder_path = f'/docs/jill-brain/vi'

if not os.path.isdir(folder_for_scan):
    print(f"Error: The provided folder path '{folder_for_scan}' is not a valid directory.")
else:
    generate_filelist(folder_for_scan, print_listname, print_folder_path)
    print("Remember add mucluc.md to url-able path; and add filelist.js to config.ts for next-prev button")
# Out:
# {'text': 'Devatāsaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-001-devatasamyutta.md'}
# {'text': 'Devaputtasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-002-devaputtasamyutta.md'}
# {'text': 'Kosalasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-003-kosalasamyutta.md'}
# {'text': 'Mārasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-004-marasamyutta.md'}
# {'text': 'Bhikkhunīsaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-005-bhikkhunisamyutta.md'}
# {'text': 'Brahmasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-006-brahmasamyutta.md'}
# {'text': 'Brāhmaṇasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-007-brahmanasamyutta.md'}
# {'text': 'Vaṅgīsasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-008-vangisasamyutta.md'}
# {'text': 'Vanasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-009-vanasamyutta.md'}
# {'text': 'Yakkhasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-010-yakkhasamyutta.md'}
# {'text': 'Sakkasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-011-sakkasamyutta.md'}
# {'text': 'Nidānasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-012-nidanasamyutta.md'}
# {'text': 'Abhisamayasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-013-abhisamayasamyutta.md'}
# {'text': 'Dhātusaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-014-dhatusamyutta.md'}
# {'text': 'Anamataggasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-015-anamataggasamyutta.md'}
# {'text': 'Kassapasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-016-kassapasamyutta.md'}
# {'text': 'Lābhasakkārasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-017-labhasakkarasamyutta.md'}
# {'text': 'Rāhulasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-018-rahulasamyutta.md'}
# {'text': 'Lakkhaṇasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-019-lakkhanasamyutta.md'}
# {'text': 'Opammasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-020-opammasamyutta.md'}
# {'text': 'Bhikkhusaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-021-bhikkhusamyutta.md'}
# {'text': 'Khandhasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-022-khandhasamyutta.md'}
# {'text': 'Rādhasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-023-radhasamyutta.md'}
# {'text': 'Diṭṭhisaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-024-ditthisamyutta.md'}
# {'text': 'Okkantasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-025-okkantasamyutta.md'}
# {'text': 'Uppādasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-026-uppadasamyutta.md'}
# {'text': 'Kilesasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-027-kilesasamyutta.md'}
# {'text': 'Sāriputtasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-028-sariputtasamyutta.md'}
# {'text': 'Nāgasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-029-nagasamyutta.md'}
# {'text': 'Supaṇṇasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-030-supannasamyutta.md'}
# {'text': 'Gandhabbakāyasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-031-gandhabbakayasamyutta.md'}
# {'text': 'Valāhakasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-032-valahakasamyutta.md'}
# {'text': 'Vacchagottasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-033-vacchagottasamyutta.md'}
# {'text': 'Jhānasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-034-jhanasamyutta.md'}
# {'text': 'Saḷāyatanasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-035-salayatanasamyutta.md'}
# {'text': 'Vedanāsaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-036-vedanasamyutta.md'}
# {'text': 'Mātugāmasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-037-matugamasamyutta.md'}
# {'text': 'Jambukhādakasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-038-jambukhadakasamyutta.md'}
# {'text': 'Sāmaṇḍakasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-039-samandakasamyutta.md'}
# {'text': 'Moggallānasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-040-moggallanasamyutta.md'}
# {'text': 'Cittasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-041-cittasamyutta.md'}
# {'text': 'Gāmaṇisaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-042-gamanisamyutta.md'}
# {'text': 'Asaṅkhatasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-043-asankhatasamyutta.md'}
# {'text': 'Abyākatasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-044-abyakatasamyutta.md'}
# {'text': 'Maggasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-045-maggasamyutta.md'}
# {'text': 'Bojjhaṅgasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-046-bojjhangasamyutta.md'}
# {'text': 'Satipaṭṭhānasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-047-satipatthanasamyutta.md'}
# {'text': 'Indriyasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-048-indriyasamyutta.md'}
# {'text': 'Sammappadhānasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-049-sammappadhanasamyutta.md'}
# {'text': 'Balasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-050-balasamyutta.md'}
# {'text': 'Iddhipādasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-051-iddhipadasamyutta.md'}
# {'text': 'Anuruddhasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-052-anuruddhasamyutta.md'}
# {'text': 'Jhānasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-053-jhanasamyutta.md'}
# {'text': 'Ānāpānasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-054-anapanasamyutta.md'}
# {'text': 'Sotāpattisaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-055-sotapattisamyutta.md'}
# {'text': 'Saccasaṁyutta', 'link': '/kinhtuongung/pali-vi/sn-056-saccasamyutta.md'}
# Successfully generated filelist.js in ../docs/kinhtuongung/pali-vi/meta
# Successfully generated mucluc.md in ../docs/kinhtuongung/pali-vi
# Successfully generated index.md in ../docs/kinhtuongung/pali-vi
# Created ../docs/kinhtuongung/pali-vi/meta/filelist.js for vite config.js create next-prev link
# Created ../docs/kinhtuongung/pali-vi/meta/mucluc.md for for mucluc.md
# Remember add mucluc.md to url-able path; and add filelist.js to config.ts for next-prev button
