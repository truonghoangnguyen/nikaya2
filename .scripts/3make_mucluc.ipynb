# %%
import os
import re

def generate_filelist(folder_path, listname, folder_out):
    """
    filelist.js using for generate next/back button config in config.js
    mucluc.md using for generate table of contents

    Generates a JavaScript filelist from Markdown files in a folder.

    Args:
        folder_path: The path to the folder containing the Markdown files.
        listname: The name to use for the JavaScript constant and export.

    Returns:
        None.  Writes the output to a file named 'filelist.js' in the input folder.
    """
    os.makedirs(os.path.join(folder_path, 'meta'), exist_ok=True)


    file_list = []
    _lst = sorted([f for f in os.listdir(folder_path) if f.endswith('.md')])
    for filename in _lst:
        # print(filename)
        file_path = os.path.join(folder_path, filename)
        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                first_line = f.readline().strip()
                # Match lines starting with '#' followed by a space and capture the rest.
                match = re.match(r"^#\s+(.*)", first_line)
                if match:
                    title = match.group(1).strip()
                    # Create file_item dict and handle exceptions
                    file_item = {
                        "text": title,
                        "link": os.path.join(folder_out, filename).replace("\\", "/")  # handle Windows path
                    }
                    file_list.append(file_item)
                    print(file_item)
                else:
                    print(f"Warning: No title found in {filename}, see `9headerformat.ipynb`")


        except FileNotFoundError:
            print(f"Error: File not found: {file_path}")
        except Exception as e:
            print(f"Error reading or processing {filename}: {e}")

    # Sort the file list alphabetically by 'text'
    # file_list.sort(key=lambda x: x['text'])

    # Generate the JavaScript code.
    js_code = f"const {listname} = [\n"
    for item in file_list:
        js_code += f'  {{ text: "{item["text"]}", link: "{item["link"]}" }},\n'
    js_code += "];\n"
    js_code += f"export default {listname};\n"

    meta_path = folder_path+"/meta"
    # Write the JavaScript code to filelist.js
    output_file_path = os.path.join(meta_path, "filelist.js")
    try:
        with open(output_file_path, 'w', encoding='utf-8') as outfile:
            outfile.write(js_code)
        print(f"Successfully generated filelist.js in {meta_path}")
    except Exception as e:
        print(f"Error writing to filelist.js: {e}")

    # Generate the Markdown table of contents (mucluc.md)
    md_toc = ""
    for item in file_list:
        md_toc += f'- [{item["text"]}]({item["link"]})\n'

    # Write the Markdown TOC to mucluc.md
    output_md_path = os.path.join(meta_path, "mucluc.md")
    try:
        with open(output_md_path, 'w', encoding='utf-8') as outfile:
            outfile.write(md_toc)
        print(f"Successfully generated mucluc.md in {folder_path}")
    except Exception as e:
        print(f"Error writing to mucluc.md: {e}")

    # Generate index.md
    output_index_path = os.path.join(folder_path, "index.md")
    try:
        with open(output_index_path, 'w', encoding='utf-8') as outfile:
            outfile.write("<!--@include: ./meta/mucluc.md-->")
        print(f"Successfully generated index.md in {folder_path}")
    except Exception as e:
        print(f"Error writing to index.md: {e}")


    print(f"Created {output_file_path} for vite config.js create next-prev link")
    print(f"Created {output_md_path} for for mucluc.md ")




## step 3 - MAKE MUCLUC-NAVFILE


alang = ""
kinh = "kinhtruongbo"
author="pali"
if alang != "":
    # folder contain list of file
    #folder_for_scan = f"../docs/{kinh}/{author}-{alang}/intro"
    folder_for_scan = f"../docs/{kinh}/{author}-{alang}"
    # output variable in filelist.js
    print_listname = f"{kinh}_{author}_{alang}"
    # output variable in filelist.js
    #print_folder_path = f'/{kinh}/{author}-{alang}/intro'
    print_folder_path = f'/{kinh}/{author}-{alang}'
else:
    folder_for_scan = f"../docs/{kinh}/{author}"
    # output variable in filelist.js
    print_listname = f"{kinh}_{author}"
    # output variable in filelist.js
    print_folder_path = f'/{kinh}/{author}'

# folder_for_scan = f"../docs/plato/vi/intro"
# print_listname = f"plato"
# print_folder_path = f'/docs/plato/vi/intro'

if not os.path.isdir(folder_for_scan):
    print(f"Error: The provided folder path '{folder_for_scan}' is not a valid directory.")
else:
    generate_filelist(folder_for_scan, print_listname, print_folder_path)
    print("Remember add mucluc.md to url-able path; and add filelist.js to config.ts for next-prev button")
# Out:
# {'text': 'Brahmajālasutta', 'link': '/kinhtruongbo/pali/dn-001-brahmajalasutta.md'}
# {'text': 'Sāmaññaphalasutta', 'link': '/kinhtruongbo/pali/dn-002-samannaphalasutta.md'}
# {'text': 'Ambaṭṭhasutta', 'link': '/kinhtruongbo/pali/dn-003-ambatthasutta.md'}
# {'text': 'Soṇadaṇḍasutta', 'link': '/kinhtruongbo/pali/dn-004-sonadandasutta.md'}
# {'text': 'Kūṭadantasutta', 'link': '/kinhtruongbo/pali/dn-005-kutadantasutta.md'}
# {'text': 'Mahālisutta', 'link': '/kinhtruongbo/pali/dn-006-mahalisutta.md'}
# {'text': 'Jāliyasutta', 'link': '/kinhtruongbo/pali/dn-007-jaliyasutta.md'}
# {'text': 'Mahāsīhanādasutta', 'link': '/kinhtruongbo/pali/dn-008-mahasihanadasutta.md'}
# {'text': 'Poṭṭhapādasutta', 'link': '/kinhtruongbo/pali/dn-009-potthapadasutta.md'}
# {'text': 'Subhasutta', 'link': '/kinhtruongbo/pali/dn-010-subhasutta.md'}
# {'text': 'Kevaṭṭasutta', 'link': '/kinhtruongbo/pali/dn-011-kevattasutta.md'}
# {'text': 'Lohiccasutta', 'link': '/kinhtruongbo/pali/dn-012-lohiccasutta.md'}
# {'text': 'Tevijjasutta', 'link': '/kinhtruongbo/pali/dn-013-tevijjasutta.md'}
# {'text': 'Mahāpadānasutta', 'link': '/kinhtruongbo/pali/dn-014-mahapadanasutta.md'}
# {'text': 'Mahānidānasutta', 'link': '/kinhtruongbo/pali/dn-015-mahanidanasutta.md'}
# {'text': 'Mahāparinibbānasutta', 'link': '/kinhtruongbo/pali/dn-016-mahaparinibbanasutta.md'}
# {'text': 'Mahāsudassanasutta', 'link': '/kinhtruongbo/pali/dn-017-mahasudassanasutta.md'}
# {'text': 'Janavasabhasutta', 'link': '/kinhtruongbo/pali/dn-018-janavasabhasutta.md'}
# {'text': 'Mahāgovindasutta', 'link': '/kinhtruongbo/pali/dn-019-mahagovindasutta.md'}
# {'text': 'Mahāsamayasutta', 'link': '/kinhtruongbo/pali/dn-020-mahasamayasutta.md'}
# {'text': 'Sakkapañhasutta', 'link': '/kinhtruongbo/pali/dn-021-sakkapanhasutta.md'}
# {'text': 'Mahāsatipaṭṭhānasutta', 'link': '/kinhtruongbo/pali/dn-022-mahasatipatthanasutta.md'}
# {'text': 'Pāyāsisutta', 'link': '/kinhtruongbo/pali/dn-023-payasisutta.md'}
# {'text': 'Pāthikasutta', 'link': '/kinhtruongbo/pali/dn-024-pathikasutta.md'}
# {'text': 'Udumbarikasutta', 'link': '/kinhtruongbo/pali/dn-025-udumbarikasutta.md'}
# {'text': 'Cakkavattisutta', 'link': '/kinhtruongbo/pali/dn-026-cakkavattisutta.md'}
# {'text': 'Aggaññasutta', 'link': '/kinhtruongbo/pali/dn-027-aggannasutta.md'}
# {'text': 'Sampasādanīyasutta', 'link': '/kinhtruongbo/pali/dn-028-sampasadaniyasutta.md'}
# {'text': 'Pāsādikasutta', 'link': '/kinhtruongbo/pali/dn-029-pasadikasutta.md'}
# {'text': 'Lakkhaṇasutta', 'link': '/kinhtruongbo/pali/dn-030-lakkhanasutta.md'}
# {'text': 'Siṅgālasutta', 'link': '/kinhtruongbo/pali/dn-031-singalasutta.md'}
# {'text': 'Āṭānāṭiyasutta', 'link': '/kinhtruongbo/pali/dn-032-atanatiyasutta.md'}
# {'text': 'Saṅgītisutta', 'link': '/kinhtruongbo/pali/dn-033-sangitisutta.md'}
# {'text': 'Dasuttarasutta', 'link': '/kinhtruongbo/pali/dn-034-dasuttarasutta.md'}
# Successfully generated filelist.js in ../docs/kinhtruongbo/pali/meta
# Successfully generated mucluc.md in ../docs/kinhtruongbo/pali
# Successfully generated index.md in ../docs/kinhtruongbo/pali
# Created ../docs/kinhtruongbo/pali/meta/filelist.js for vite config.js create next-prev link
# Created ../docs/kinhtruongbo/pali/meta/mucluc.md for for mucluc.md
# Remember add mucluc.md to url-able path; and add filelist.js to config.ts for next-prev button
