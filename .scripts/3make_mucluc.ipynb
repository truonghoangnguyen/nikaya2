# %%
import os
import re

def generate_filelist(folder_path, listname, folder_out):
    """
    filelist.js using for generate next/back button config in config.js
    mucluc.md using for generate table of contents

    Generates a JavaScript filelist from Markdown files in a folder.

    Args:
        folder_path: The path to the folder containing the Markdown files.
        listname: The name to use for the JavaScript constant and export.

    Returns:
        None.  Writes the output to a file named 'filelist.js' in the input folder.
    """
    os.makedirs(os.path.join(folder_path, 'meta'), exist_ok=True)


    file_list = []
    _lst = sorted([f for f in os.listdir(folder_path) if f.endswith('.md')])
    for filename in _lst:
        # print(filename)
        file_path = os.path.join(folder_path, filename)
        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                first_line = f.readline().strip()
                # Match lines starting with '#' followed by a space and capture the rest.
                match = re.match(r"^#\s+(.*)", first_line)
                if match:
                    title = match.group(1).strip()
                    # Create file_item dict and handle exceptions
                    file_item = {
                        "text": title,
                        "link": os.path.join(folder_out, filename).replace("\\", "/")  # handle Windows path
                    }
                    file_list.append(file_item)
                    print(file_item)
                else:
                    print(f"Warning: No title found in {filename}, see `9headerformat.ipynb`")


        except FileNotFoundError:
            print(f"Error: File not found: {file_path}")
        except Exception as e:
            print(f"Error reading or processing {filename}: {e}")

    # Sort the file list alphabetically by 'text'
    # file_list.sort(key=lambda x: x['text'])

    # Generate the JavaScript code.
    js_code = f"const {listname} = [\n"
    for item in file_list:
        js_code += f'  {{ text: "{item["text"]}", link: "{item["link"]}" }},\n'
    js_code += "];\n"
    js_code += f"export default {listname};\n"

    meta_path = folder_path+"/meta"
    # Write the JavaScript code to filelist.js
    output_file_path = os.path.join(meta_path, "filelist.js")
    try:
        with open(output_file_path, 'w', encoding='utf-8') as outfile:
            outfile.write(js_code)
        print(f"Successfully generated filelist.js in {meta_path}")
    except Exception as e:
        print(f"Error writing to filelist.js: {e}")

    # Generate the Markdown table of contents (mucluc.md)
    md_toc = ""
    for item in file_list:
        md_toc += f'- [{item["text"]}]({item["link"]})\n'

    # Write the Markdown TOC to mucluc.md
    output_md_path = os.path.join(meta_path, "mucluc.md")
    try:
        with open(output_md_path, 'w', encoding='utf-8') as outfile:
            outfile.write(md_toc)
        print(f"Successfully generated mucluc.md in {folder_path}")
    except Exception as e:
        print(f"Error writing to mucluc.md: {e}")

    # Generate index.md
    output_index_path = os.path.join(folder_path, "index.md")
    try:
        with open(output_index_path, 'w', encoding='utf-8') as outfile:
            outfile.write("<!--@include: ./meta/mucluc.md-->")
        print(f"Successfully generated index.md in {folder_path}")
    except Exception as e:
        print(f"Error writing to index.md: {e}")


    print(f"Created {output_file_path} for vite config.js create next-prev link")
    print(f"Created {output_md_path} for for mucluc.md ")




## step 3 - MAKE MUCLUC-NAVFILE


alang = "vi"
kinh = "kinhtuongung"
author="sujato"

# folder contain list of file
folder_for_scan = f"../docs/{kinh}/{author}-{alang}"
# output variable in filelist.js
print_listname = f"{kinh}_{author}_{alang}"
# output variable in filelist.js
print_folder_path = f'/{kinh}/{author}-{alang}'

# folder_for_scan = f"../docs/jill-brain/vi"
# print_listname = f"jill"
# print_folder_path = f'/docs/jill-brain/vi'

if not os.path.isdir(folder_for_scan):
    print(f"Error: The provided folder path '{folder_for_scan}' is not a valid directory.")
else:
    generate_filelist(folder_for_scan, print_listname, print_folder_path)
    print("Remember add mucluc.md to url-able path; and add filelist.js to config.ts for next-prev button")
# Out:
# Warning: No title found in index.md, see `9headerformat.ipynb`
# {'text': 'Tương Ưng Chư Thiên', 'link': '/kinhtuongung/sujato-vi/sn-01-linked-discourses-with-deities.md'}
# {'text': 'Tương Ưng về Chư Thiên', 'link': '/kinhtuongung/sujato-vi/sn-02-linked-discourses-on-gods.md'}
# {'text': 'Các Bài Kinh Liên Quan Đến Vua Pasenadi xứ Kosala', 'link': '/kinhtuongung/sujato-vi/sn-03-linked-discourses-with-king-pasenadi-of-kosala.md'}
# {'text': 'Các Kinh Tương Ưng Với Māra', 'link': '/kinhtuongung/sujato-vi/sn-04-linked-discourses-with-mara.md'}
# {'text': 'Các Kinh Tương Ưng Với Chư Tỷ Kheo Ni', 'link': '/kinhtuongung/sujato-vi/sn-05-linked-discourses-with-nuns.md'}
# {'text': '6. Tương Ưng với Phạm Thiên', 'link': '/kinhtuongung/sujato-vi/sn-06-linked-discourses-with-brahma-gods.md'}
# {'text': 'Tương Ưng với Bà-la-môn', 'link': '/kinhtuongung/sujato-vi/sn-07-linked-discourses-with-brahmins.md'}
# {'text': 'Tương Ưng với Vaṅgīsa', 'link': '/kinhtuongung/sujato-vi/sn-08-linked-discourses-with-vangisa.md'}
# {'text': 'Các Bài Kinh Tương Ưng trong Rừng', 'link': '/kinhtuongung/sujato-vi/sn-09-linked-discourses-in-the-woods.md'}
# {'text': 'Tương Ưng Dạ Xoa (Spirits)', 'link': '/kinhtuongung/sujato-vi/sn-10-linked-discourses-with-spirits.md'}
# {'text': 'Tương Ưng với Sakka', 'link': '/kinhtuongung/sujato-vi/sn-11-linked-discourses-with-sakka.md'}
# {'text': 'Các Bài Kinh Tương Ưng về Nhân Duyên', 'link': '/kinhtuongung/sujato-vi/sn-12-linked-discourses-on-causation.md'}
# {'text': 'Tương Ưng về Sự Thông Hiểu', 'link': '/kinhtuongung/sujato-vi/sn-13-linked-discourses-on-comprehension.md'}
# {'text': 'Các Bài Kinh Liên Quan Về Các Giới', 'link': '/kinhtuongung/sujato-vi/sn-14-linked-discourses-on-the-elements.md'}
# {'text': 'Tương Ưng Về Sự Khởi Đầu Không Thể Biết', 'link': '/kinhtuongung/sujato-vi/sn-15-linked-discourses-on-the-unknowable-beginning.md'}
# {'text': 'Tương Ưng Kassapa', 'link': '/kinhtuongung/sujato-vi/sn-16-linked-discourses-with-kassapa.md'}
# {'text': 'Tương Ưng về Lợi Dưỡng và Danh Vọng', 'link': '/kinhtuongung/sujato-vi/sn-17-linked-discourses-on-gains-and-honor.md'}
# {'text': 'Tương Ưng Rāhula', 'link': '/kinhtuongung/sujato-vi/sn-18-linked-discourses-with-rahula.md'}
# {'text': 'Tương Ưng với Lakkhaṇa', 'link': '/kinhtuongung/sujato-vi/sn-19-linked-discourses-with-lakkhana.md'}
# {'text': 'Tương Ưng với Ví Dụ', 'link': '/kinhtuongung/sujato-vi/sn-20-linked-discourses-with-similes.md'}
# {'text': 'Tương Ưng Chư Tăng', 'link': '/kinhtuongung/sujato-vi/sn-21-linked-discourses-with-monks.md'}
# {'text': 'Tương Ưng Uẩn', 'link': '/kinhtuongung/sujato-vi/sn-22-linked-discourses-on-the-aggregates.md'}
# {'text': 'Tương Ưng với Rādha', 'link': '/kinhtuongung/sujato-vi/sn-23-linked-discourses-with-radha.md'}
# {'text': 'Tương Ưng Quan Điểm', 'link': '/kinhtuongung/sujato-vi/sn-24-linked-discourses-on-views.md'}
# {'text': 'Tương Ưng về Sự Đạt Đến Chân Lý', 'link': '/kinhtuongung/sujato-vi/sn-25-linked-discourses-on-arrival-at-the-truth.md'}
# {'text': 'Tương Ưng Về Sự Sinh Khởi', 'link': '/kinhtuongung/sujato-vi/sn-26-linked-discourses-on-arising.md'}
# {'text': 'Tương Ưng Về Ô Nhiễm', 'link': '/kinhtuongung/sujato-vi/sn-27-linked-discourses-on-corruptions.md'}
# {'text': 'Tương Ưng Xá Lợi Phất', 'link': '/kinhtuongung/sujato-vi/sn-28-linked-discourses-with-sariputta.md'}
# {'text': 'Các Bài Kinh Liên Quan Về Loài Rồng', 'link': '/kinhtuongung/sujato-vi/sn-29-linked-discourses-on-dragons.md'}
# {'text': 'Tương Ưng về Kim Sí Điểu', 'link': '/kinhtuongung/sujato-vi/sn-30-linked-discourses-on-phoenixes.md'}
# {'text': 'Tương Ưng Bộ Kinh về Càn-thát-bà', 'link': '/kinhtuongung/sujato-vi/sn-31-linked-discourses-on-centaurs.md'}
# {'text': 'Tương Ưng về Các Vị Thần Mây', 'link': '/kinhtuongung/sujato-vi/sn-32-linked-discourses-on-cloud-gods.md'}
# {'text': 'Tương Ưng Vacchagotta', 'link': '/kinhtuongung/sujato-vi/sn-33-linked-discourses-with-vacchagotta.md'}
# {'text': 'Tương Ưng về Thiền Định', 'link': '/kinhtuongung/sujato-vi/sn-34-linked-discourses-on-absorption.md'}
# {'text': 'Tương Ưng về Sáu Trường Giác Quan', 'link': '/kinhtuongung/sujato-vi/sn-35-linked-discourses-on-the-six-sense-fields.md'}
# {'text': 'Tương Ưng Về Cảm Giác', 'link': '/kinhtuongung/sujato-vi/sn-36-linked-discourses-on-feelings.md'}
# {'text': 'Các Bài Kinh Liên Quan Đến Phụ Nữ', 'link': '/kinhtuongung/sujato-vi/sn-37-linked-discourses-on-females.md'}
# {'text': 'Các Bài Kinh Tương Ưng với Jambukhādaka', 'link': '/kinhtuongung/sujato-vi/sn-38-linked-discourses-with-jambukhadaka.md'}
# {'text': 'Các Bài Kinh Liên Quan đến Sāmaṇḍaka', 'link': '/kinhtuongung/sujato-vi/sn-39-linked-discourses-with-samandaka.md'}
# {'text': 'Tương Ưng với Mục Kiền Liên (MOGGALÀNA)', 'link': '/kinhtuongung/sujato-vi/sn-40-linked-discourses-with-moggallana.md'}
# {'text': 'Tương Ưng đến Gia Chủ Citta', 'link': '/kinhtuongung/sujato-vi/sn-41-linked-discourses-with-citta-the-householder.md'}
# {'text': 'Tương Ưng Các Vị Trưởng Làng', 'link': '/kinhtuongung/sujato-vi/sn-42-linked-discourses-with-chiefs.md'}
# {'text': 'Tương Ưng về Thực Tại Tuyệt Đối', 'link': '/kinhtuongung/sujato-vi/sn-43-linked-discourses-on-the-unconditioned.md'}
# {'text': 'Tương Ưng về không được tuyên bố.', 'link': '/kinhtuongung/sujato-vi/sn-44-linked-discourses-on-the-undeclared.md'}
# {'text': 'Các Bài Kinh Liên Quan đến Con Đường Tám Nhánh', 'link': '/kinhtuongung/sujato-vi/sn-45-linked-discourses-on-the-eightfold-path.md'}
# {'text': 'Các Bài Kinh Liên Quan đến Các Yếu Tố Giác Ngộ', 'link': '/kinhtuongung/sujato-vi/sn-46-linked-discourses-on-the-awakening-factors.md'}
# {'text': 'Các Bài Kinh Tương Ưng về Thiền Niệm Xứ', 'link': '/kinhtuongung/sujato-vi/sn-47-linked-discourses-on-mindfulness-meditation.md'}
# {'text': 'Tương Ưng về các Năng lực Tinh Thần (indriya)', 'link': '/kinhtuongung/sujato-vi/sn-48-linked-discourses-on-the-faculties.md'}
# {'text': 'Tương Ưng Kinh về Các Nỗ Lực Chân Chính', 'link': '/kinhtuongung/sujato-vi/sn-49-linked-discourses-on-the-right-efforts.md'}
# {'text': 'Tương Ưng về Năm Sức Mạnh', 'link': '/kinhtuongung/sujato-vi/sn-50-linked-discourses-on-the-five-powers.md'}
# {'text': '51. Tương Ưng Các Cửa Thần Thông', 'link': '/kinhtuongung/sujato-vi/sn-51-linked-discourses-on-the-bases-of-psychic-power.md'}
# {'text': 'Tương Ưng Bộ Kinh với Anuruddha', 'link': '/kinhtuongung/sujato-vi/sn-52-linked-discourses-with-anuruddha.md'}
# {'text': 'Kinh Tương Ưng về Thiền Định', 'link': '/kinhtuongung/sujato-vi/sn-53-linked-discourses-on-absorption.md'}
# {'text': 'Tương Ưng về Thiền Hơi Thở', 'link': '/kinhtuongung/sujato-vi/sn-54-linked-discourses-on-breath-meditation.md'}
# {'text': 'Tương Ưng về Nhập Lưu', 'link': '/kinhtuongung/sujato-vi/sn-55-linked-discourses-on-stream-entry.md'}
# {'text': 'Các Bài Kinh Liên Quan Về Sự Thật', 'link': '/kinhtuongung/sujato-vi/sn-56-linked-discourses-on-the-truths.md'}
# Successfully generated filelist.js in ../docs/kinhtuongung/sujato-vi/meta
# Successfully generated mucluc.md in ../docs/kinhtuongung/sujato-vi
# Successfully generated index.md in ../docs/kinhtuongung/sujato-vi
# Created ../docs/kinhtuongung/sujato-vi/meta/filelist.js for vite config.js create next-prev link
# Created ../docs/kinhtuongung/sujato-vi/meta/mucluc.md for for mucluc.md
# Remember add mucluc.md to url-able path; and add filelist.js to config.ts for next-prev button
